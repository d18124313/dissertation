# %%
## @see https://www.kaggle.com/toorkp/churn-wsdm/data

# %%
# %load_ext autoreload
# %autoreload

# %%
import numpy as np
import pandas as pd
import time
import gc; gc.enable()
import time
import sys

from sklearn import model_selection
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_curve, auc, confusion_matrix, f1_score, log_loss, confusion_matrix
from sklearn.neural_network import MLPClassifier

from scipy.stats import randint as sp_randint

from collections import Counter
from numpy.random import RandomState
from imblearn.over_sampling import SMOTENC
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

pd.options.display.float_format = "{:.2f}".format
np.set_printoptions(precision=4)

import matplotlib.pyplot as plt
# %matplotlib inline

sys.path.append('modules')

from shared_functions import *
# Out:
# /home/anaconda/envs/py373/lib/python3.7/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
base_dataset = pd.read_hdf('/home/dissertation/data/dfs_dataset.h5', 'dfs_dataset')
# base_dataset.drop(['transaction_date_min', 'transaction_date_max'], axis = 1, inplace=True)
# base_dataset['city'] = base_dataset.city.astype(str)
# base_dataset['registered_via'] = base_dataset.registered_via.astype(str)
base_dataset = base_dataset.reset_index()
base_dataset.head()
# Out:
#    index                                          msno  is_churn  bd  gender  \
# 0      0  ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=         1  28    male
# 1      1  f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=         1  20    male
# 2      2  zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=         1  18    male
# 3      3  8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1   0     NaN
# 4      4  K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         1  35  female
#
#    registration_init_time city registered_via  \
# 0                20131223    5              3
# 1                20131223   13              3
# 2                20131227   13              3
# 3                20140109    1              7
# 4                20140125   13              7
#
#    SUM(transactions.payment_plan_days)  SUM(transactions.plan_list_price)  \
# 0                                60.00                             298.00
# 1                               127.00                             627.00
# 2                               540.00                            2682.00
# 3                               487.00                            2384.00
# 4                               630.00                            2529.00
#
#    ...  MEAN(transactions.daily_price)  COUNT(transactions)  \
# 0  ...                             inf                 6.00
# 1  ...                            4.18                 5.00
# 2  ...                            4.97                18.00
# 3  ...                             inf                19.00
# 4  ...                             inf                24.00
#
#    PERCENT_TRUE(transactions.is_auto_renew)  \
# 0                                      0.83
# 1                                      0.00
# 2                                      0.00
# 3                                      0.95
# 4                                      1.00
#
#    PERCENT_TRUE(transactions.is_cancel)  \
# 0                                  0.17
# 1                                  0.00
# 2                                  0.00
# 3                                  0.16
# 4                                  0.08
#
#    NUM_UNIQUE(transactions.payment_method_id)  \
# 0                                        2.00
# 1                                        3.00
# 2                                        1.00
# 3                                        2.00
# 4                                        1.00
#
#    MODE(transactions.payment_method_id)  DAY(registration_init_time_dt)  \
# 0                                 31.00                              23
# 1                                 38.00                              23
# 2                                 38.00                              27
# 3                                 41.00                               9
# 4                                 41.00                              25
#
#    YEAR(registration_init_time_dt)  MONTH(registration_init_time_dt)  \
# 0                             2013                                12
# 1                             2013                                12
# 2                             2013                                12
# 3                             2014                                 1
# 4                             2014                                 1
#
#    WEEKDAY(registration_init_time_dt)
# 0                                   0
# 1                                   0
# 2                                   4
# 3                                   3
# 4                                   5
#
# [5 rows x 65 columns]

# %%
## Simple Data Prep 
base_dataset = base_dataset.drop(labels =['msno', 'bd', 'index', 'gender'], axis=1)

## TEMP TEMP TEMP ##
for col in base_dataset.head().filter(regex='daily').columns:
    base_dataset.drop(col, axis=1, inplace=True)

## Simply drops records with NA ast this stage
base_dataset = clean_dataset(base_dataset)

print(base_dataset.shape)
base_dataset.head()
# Out:
# (797369, 49)
#    is_churn  registration_init_time city registered_via  \
# 0         1                20131223    5              3
# 1         1                20131223   13              3
# 2         1                20131227   13              3
# 3         1                20140109    1              7
# 4         1                20140125   13              7
#
#    SUM(transactions.payment_plan_days)  SUM(transactions.plan_list_price)  \
# 0                                60.00                             298.00
# 1                               127.00                             627.00
# 2                               540.00                            2682.00
# 3                               487.00                            2384.00
# 4                               630.00                            2529.00
#
#    SUM(transactions.actual_amount_paid)  SUM(transactions.transaction_date)  \
# 0                                894.00                        120923653.00
# 1                                627.00                        100812365.00
# 2                               2682.00                        362862440.00
# 3                               2682.00                        382888820.00
# 4                               2956.00                        483713706.00
#
#    SUM(transactions.membership_expire_date)  \
# 0                              120924153.00
# 1                              100812869.00
# 2                              362881912.00
# 3                              383039868.00
# 4                              483807163.00
#
#    SUM(transactions.price_difference)  ...  \
# 0                              428.00  ...
# 1                                0.00  ...
# 2                                0.00  ...
# 3                              214.00  ...
# 4                              341.00  ...
#
#    MEAN(transactions.price_difference)  COUNT(transactions)  \
# 0                                71.33                 6.00
# 1                                 0.00                 5.00
# 2                                 0.00                18.00
# 3                                11.26                19.00
# 4                                14.21                24.00
#
#    PERCENT_TRUE(transactions.is_auto_renew)  \
# 0                                      0.83
# 1                                      0.00
# 2                                      0.00
# 3                                      0.95
# 4                                      1.00
#
#    PERCENT_TRUE(transactions.is_cancel)  \
# 0                                  0.17
# 1                                  0.00
# 2                                  0.00
# 3                                  0.16
# 4                                  0.08
#
#    NUM_UNIQUE(transactions.payment_method_id)  \
# 0                                        2.00
# 1                                        3.00
# 2                                        1.00
# 3                                        2.00
# 4                                        1.00
#
#    MODE(transactions.payment_method_id)  DAY(registration_init_time_dt)  \
# 0                                 31.00                              23
# 1                                 38.00                              23
# 2                                 38.00                              27
# 3                                 41.00                               9
# 4                                 41.00                              25
#
#    YEAR(registration_init_time_dt)  MONTH(registration_init_time_dt)  \
# 0                             2013                                12
# 1                             2013                                12
# 2                             2013                                12
# 3                             2014                                 1
# 4                             2014                                 1
#
#    WEEKDAY(registration_init_time_dt)
# 0                                   0
# 1                                   0
# 2                                   4
# 3                                   3
# 4                                   5
#
# [5 rows x 49 columns]

# %%
import sklearn 
sklearn.metrics.SCORERS.keys()

# %%
## WHAT METRIC SHOULD BE OPTIMSED AS PART OF CV

# %%
RANDOM_STATE = 42 
CV_ITER = 3
SCORING_METRIC = 'recall'

## Each entry in the list is a Tuple of
##   [ModelName, Model, HyperParams, ScoringMetric]
classifiers = [
    ('NB', GaussianNB(), {}, SCORING_METRIC),
    ('DT', DecisionTreeClassifier(), {}, SCORING_METRIC),
    ('RF', RandomForestClassifier(n_jobs =-1), {}, SCORING_METRIC),
    ('LR', LogisticRegression(solver = 'liblinear'), {}, SCORING_METRIC),
    ('AB', AdaBoostClassifier(), {}, SCORING_METRIC),
    ('MLP', MLPClassifier(), {}, SCORING_METRIC),
        ('RF2', RandomForestClassifier(n_jobs =-1), 
                    {'search_type': 'RANDOM_SEARCH_CV',
                     "criterion": ["entropy","gini"], 
                     "n_estimators": sp_randint(100,200),
                     "max_depth":sp_randint(10,30), 
                     "min_samples_leaf":sp_randint(10,50),
                     "min_samples_split":sp_randint(10,100),
                     "class_weight":[None, "balanced"]},
           SCORING_METRIC), 
]

# %%
all_metrics = pd.DataFrame()
all_metrics
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
sample_dataset = base_dataset.sample(100000)

# %%
sample_dataset.head()
# Out:
#         is_churn  registration_init_time city registered_via  \
# 369955         0                20150406    5              3
# 261624         0                20151029    1              7
# 468797         0                20160808   14              7
# 513431         0                20120201    1              7
# 48784          1                20160812   10              9
#
#         SUM(transactions.payment_plan_days)  \
# 369955                               690.00
# 261624                               480.00
# 468797                               210.00
# 513431                               750.00
# 48784                                 90.00
#
#         SUM(transactions.plan_list_price)  \
# 369955                            3780.00
# 261624                            1584.00
# 468797                             693.00
# 513431                            3725.00
# 48784                              447.00
#
#         SUM(transactions.actual_amount_paid)  \
# 369955                               3780.00
# 261624                               1584.00
# 468797                                693.00
# 513431                               3874.00
# 48784                                 447.00
#
#         SUM(transactions.transaction_date)  \
# 369955                        463625727.00
# 261624                        322570684.00
# 468797                        141145356.00
# 513431                        524076056.00
# 48784                          60492138.00
#
#         SUM(transactions.membership_expire_date)  \
# 369955                              463645610.00
# 261624                              322581086.00
# 468797                              141154856.00
# 513431                              524096282.00
# 48784                                60492439.00
#
#         SUM(transactions.price_difference)  ...  \
# 369955                                0.00  ...
# 261624                                0.00  ...
# 468797                                0.00  ...
# 513431                              107.00  ...
# 48784                                 0.00  ...
#
#         MEAN(transactions.price_difference)  COUNT(transactions)  \
# 369955                                 0.00                23.00
# 261624                                 0.00                16.00
# 468797                                 0.00                 7.00
# 513431                                 4.12                26.00
# 48784                                  0.00                 3.00
#
#         PERCENT_TRUE(transactions.is_auto_renew)  \
# 369955                                      0.48
# 261624                                      1.00
# 468797                                      1.00
# 513431                                      1.00
# 48784                                       0.00
#
#         PERCENT_TRUE(transactions.is_cancel)  \
# 369955                                  0.00
# 261624                                  0.00
# 468797                                  0.00
# 513431                                  0.00
# 48784                                   0.00
#
#         NUM_UNIQUE(transactions.payment_method_id)  \
# 369955                                        1.00
# 261624                                        1.00
# 468797                                        1.00
# 513431                                        1.00
# 48784                                         1.00
#
#         MODE(transactions.payment_method_id)  DAY(registration_init_time_dt)  \
# 369955                                 36.00                               6
# 261624                                 41.00                              29
# 468797                                 41.00                               8
# 513431                                 41.00                               1
# 48784                                  38.00                              12
#
#         YEAR(registration_init_time_dt)  MONTH(registration_init_time_dt)  \
# 369955                             2015                                 4
# 261624                             2015                                10
# 468797                             2016                                 8
# 513431                             2012                                 2
# 48784                              2016                                 8
#
#         WEEKDAY(registration_init_time_dt)
# 369955                                   0
# 261624                                   3
# 468797                                   0
# 513431                                   2
# 48784                                    4
#
# [5 rows x 49 columns]

# %% [markdown]
# ### Experiment 1.1 Baseline - Default Settings - No sampling

# %%
# %%time
sampler = ('None', DummySampler())

exp_metrics = perform_experiment(base_dataset, classifiers, sampler, 1, RANDOM_STATE, cv_iter=CV_ITER, 
                                 cat_col = ['city','registered_via'])

all_metrics = all_metrics.append(exp_metrics)
# Out:
# Model Build Iteration 0
# /home/anaconda/envs/py373/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
# PRE-SAMPLING: (558158, 48) (558158,) Counter({0: 514716, 1: 43442})
# POST-SAMPLING: (558158, 48) (558158,) Counter({0: 514716, 1: 43442})
# Applying normalisation to train and test sets
# Categorical columns in dataset ['city', 'registered_via']
# Categorical columns in dataset ['city', 'registered_via']
# X_train:  (558158, 83) (558158, 1)
# X_test:  (239211, 83) (239211, 1)
# Building NB classifier
# No params set, using Standard training
# Performing 3-fold CV on test set using recall metric
# P_Recall: 0.006; N_Recall: 1.0
# Building DT classifier
# No params set, using Standard training
# Performing 3-fold CV on test set using recall metric
# P_Recall: 0.472; N_Recall: 0.955
# Building RF classifier
# No params set, using Standard training
# Performing 3-fold CV on test set using recall metric
# P_Recall: 0.398; N_Recall: 0.989
# Building LR classifier
# No params set, using Standard training
# Performing 3-fold CV on test set using recall metric
# /home/anaconda/envs/py373/lib/python3.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/anaconda/envs/py373/lib/python3.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# P_Recall: 0.0; N_Recall: 1.0
# Building AB classifier
# No params set, using Standard training
# Performing 3-fold CV on test set using recall metric
# P_Recall: 0.311; N_Recall: 0.993
# Building MLP classifier
# No params set, using Standard training
# Performing 3-fold CV on test set using recall metric
# P_Recall: 1.0; N_Recall: 0.0
# Building RF2 classifier
# Optimising using RandomizedSearchCV
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV] class_weight=None, criterion=entropy, max_depth=15, min_samples_leaf=38, min_samples_split=41, n_estimators=109
# [CV] class_weight=None, criterion=entropy, max_depth=15, min_samples_leaf=38, min_samples_split=41, n_estimators=109
# [CV] class_weight=None, criterion=entropy, max_depth=15, min_samples_leaf=38, min_samples_split=41, n_estimators=109
# [CV] class_weight=None, criterion=entropy, max_depth=20, min_samples_leaf=11, min_samples_split=25, n_estimators=138
# [CV] class_weight=None, criterion=entropy, max_depth=20, min_samples_leaf=11, min_samples_split=25, n_estimators=138
# [CV] class_weight=None, criterion=entropy, max_depth=20, min_samples_leaf=11, min_samples_split=25, n_estimators=138
# [CV] class_weight=balanced, criterion=entropy, max_depth=26, min_samples_leaf=38, min_samples_split=85, n_estimators=182
# [CV] class_weight=balanced, criterion=entropy, max_depth=26, min_samples_leaf=38, min_samples_split=85, n_estimators=182
# [CV]  class_weight=None, criterion=entropy, max_depth=15, min_samples_leaf=38, min_samples_split=41, n_estimators=109, total= 4.4min
# [CV] class_weight=balanced, criterion=entropy, max_depth=26, min_samples_leaf=38, min_samples_split=85, n_estimators=182
# [CV]  class_weight=None, criterion=entropy, max_depth=15, min_samples_leaf=38, min_samples_split=41, n_estimators=109, total= 4.5min
# [CV] class_weight=balanced, criterion=entropy, max_depth=27, min_samples_leaf=43, min_samples_split=52, n_estimators=148
# [CV]  class_weight=None, criterion=entropy, max_depth=15, min_samples_leaf=38, min_samples_split=41, n_estimators=109, total= 4.6min
# [CV] class_weight=balanced, criterion=entropy, max_depth=27, min_samples_leaf=43, min_samples_split=52, n_estimators=148
# [CV]  class_weight=None, criterion=entropy, max_depth=20, min_samples_leaf=11, min_samples_split=25, n_estimators=138, total= 7.0min
# [CV] class_weight=balanced, criterion=entropy, max_depth=27, min_samples_leaf=43, min_samples_split=52, n_estimators=148
# [CV]  class_weight=None, criterion=entropy, max_depth=20, min_samples_leaf=11, min_samples_split=25, n_estimators=138, total= 7.0min
# [CV] class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=14, min_samples_split=98, n_estimators=116
# [CV]  class_weight=None, criterion=entropy, max_depth=20, min_samples_leaf=11, min_samples_split=25, n_estimators=138, total= 7.1min
# [CV] class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=14, min_samples_split=98, n_estimators=116
# [CV]  class_weight=balanced, criterion=entropy, max_depth=26, min_samples_leaf=38, min_samples_split=85, n_estimators=182, total= 8.5min
# [CV] class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=14, min_samples_split=98, n_estimators=116
# [CV]  class_weight=balanced, criterion=entropy, max_depth=26, min_samples_leaf=38, min_samples_split=85, n_estimators=182, total= 8.6min
# [CV] class_weight=None, criterion=entropy, max_depth=27, min_samples_leaf=47, min_samples_split=12, n_estimators=111
# [CV]  class_weight=balanced, criterion=entropy, max_depth=27, min_samples_leaf=43, min_samples_split=52, n_estimators=148, total= 7.0min
# [CV] class_weight=None, criterion=entropy, max_depth=27, min_samples_leaf=47, min_samples_split=12, n_estimators=111
# [CV]  class_weight=balanced, criterion=entropy, max_depth=27, min_samples_leaf=43, min_samples_split=52, n_estimators=148, total= 7.3min
# [CV] class_weight=None, criterion=entropy, max_depth=27, min_samples_leaf=47, min_samples_split=12, n_estimators=111
# [CV]  class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=14, min_samples_split=98, n_estimators=116, total= 5.1min
# [CV] class_weight=balanced, criterion=entropy, max_depth=14, min_samples_leaf=13, min_samples_split=75, n_estimators=108
# [CV]  class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=14, min_samples_split=98, n_estimators=116, total= 5.2min
# [CV] class_weight=balanced, criterion=entropy, max_depth=14, min_samples_leaf=13, min_samples_split=75, n_estimators=108
# [CV]  class_weight=balanced, criterion=entropy, max_depth=26, min_samples_leaf=38, min_samples_split=85, n_estimators=182, total= 8.7min
# [CV] class_weight=balanced, criterion=entropy, max_depth=14, min_samples_leaf=13, min_samples_split=75, n_estimators=108
# [CV]  class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=14, min_samples_split=98, n_estimators=116, total= 5.2min
# [CV] class_weight=balanced, criterion=entropy, max_depth=15, min_samples_leaf=32, min_samples_split=57, n_estimators=124
# [CV]  class_weight=balanced, criterion=entropy, max_depth=27, min_samples_leaf=43, min_samples_split=52, n_estimators=148, total= 7.0min
# [CV] class_weight=balanced, criterion=entropy, max_depth=15, min_samples_leaf=32, min_samples_split=57, n_estimators=124
# [CV]  class_weight=None, criterion=entropy, max_depth=27, min_samples_leaf=47, min_samples_split=12, n_estimators=111, total= 5.4min
# [CV] class_weight=balanced, criterion=entropy, max_depth=15, min_samples_leaf=32, min_samples_split=57, n_estimators=124
# [CV]  class_weight=balanced, criterion=entropy, max_depth=14, min_samples_leaf=13, min_samples_split=75, n_estimators=108, total= 4.5min
# [CV] class_weight=None, criterion=gini, max_depth=15, min_samples_leaf=33, min_samples_split=83, n_estimators=120
# [CV]  class_weight=balanced, criterion=entropy, max_depth=14, min_samples_leaf=13, min_samples_split=75, n_estimators=108, total= 4.5min
# [CV] class_weight=None, criterion=gini, max_depth=15, min_samples_leaf=33, min_samples_split=83, n_estimators=120
# [CV]  class_weight=None, criterion=entropy, max_depth=27, min_samples_leaf=47, min_samples_split=12, n_estimators=111, total= 5.4min
# [CV] class_weight=None, criterion=gini, max_depth=15, min_samples_leaf=33, min_samples_split=83, n_estimators=120
# [CV]  class_weight=None, criterion=entropy, max_depth=27, min_samples_leaf=47, min_samples_split=12, n_estimators=111, total= 5.4min
# [CV] class_weight=balanced, criterion=gini, max_depth=14, min_samples_leaf=25, min_samples_split=98, n_estimators=159
# [CV]  class_weight=balanced, criterion=entropy, max_depth=14, min_samples_leaf=13, min_samples_split=75, n_estimators=108, total= 4.5min
# [CV] class_weight=balanced, criterion=gini, max_depth=14, min_samples_leaf=25, min_samples_split=98, n_estimators=159
# [CV]  class_weight=balanced, criterion=entropy, max_depth=15, min_samples_leaf=32, min_samples_split=57, n_estimators=124, total= 5.3min
# [CV] class_weight=balanced, criterion=gini, max_depth=14, min_samples_leaf=25, min_samples_split=98, n_estimators=159
# [CV]  class_weight=balanced, criterion=entropy, max_depth=15, min_samples_leaf=32, min_samples_split=57, n_estimators=124, total= 5.3min
# [CV]  class_weight=balanced, criterion=entropy, max_depth=15, min_samples_leaf=32, min_samples_split=57, n_estimators=124, total= 5.4min
# [CV]  class_weight=None, criterion=gini, max_depth=15, min_samples_leaf=33, min_samples_split=83, n_estimators=120, total= 4.6min
# [CV]  class_weight=None, criterion=gini, max_depth=15, min_samples_leaf=33, min_samples_split=83, n_estimators=120, total= 4.7min
# [CV]  class_weight=None, criterion=gini, max_depth=15, min_samples_leaf=33, min_samples_split=83, n_estimators=120, total= 4.6min
# [CV]  class_weight=balanced, criterion=gini, max_depth=14, min_samples_leaf=25, min_samples_split=98, n_estimators=159, total= 4.9min
# [CV]  class_weight=balanced, criterion=gini, max_depth=14, min_samples_leaf=25, min_samples_split=98, n_estimators=159, total= 4.6min
# [CV]  class_weight=balanced, criterion=gini, max_depth=14, min_samples_leaf=25, min_samples_split=98, n_estimators=159, total= 3.3min
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed: 23.7min finished
# CLF: {'class_weight': 'balanced', 'criterion': 'gini', 'max_depth': 14, 'min_samples_leaf': 25, 'min_samples_split': 98, 'n_estimators': 159}
# Performing 3-fold CV on test set using recall metric
# P_Recall: 0.765; N_Recall: 0.875
# CPU times: user 15min 12s, sys: 1min 22s, total: 16min 34s
# Wall time: 29min 19s

# %%
all_metrics.sort_values('f1_score', ascending=False)
# Out:
#                classifier sampling_method      tn     fn     tp      fp  \
# 0  RandomForestClassifier            None  218173  11202   7416    2420
# 0  RandomForestClassifier            None  192909   4379  14239   27684
# 0  DecisionTreeClassifier            None  210615   9838   8780    9978
# 0      AdaBoostClassifier            None  219021  12820   5798    1572
# 0           MLPClassifier            None       2      2  18616  220591
# 0              GaussianNB            None  220556  18501    117      37
# 0      LogisticRegression            None  220593  18618      0       0
#
#    accuracy  precision  recall  f1_score  log_loss  time_taken  aucroc  auprc  \
# 0      0.94       0.75    0.40      0.52      1.97       26.43    0.83   0.58
# 0      0.87       0.34    0.76      0.47      4.63     1509.65    0.89   0.61
# 0      0.92       0.47    0.47      0.47      2.86       20.99    0.69   0.42
# 0      0.94       0.79    0.31      0.45      2.08       82.15    0.86   0.51
# 0      0.08       0.08    1.00      0.14     31.85       17.63    0.50   0.54
# 0      0.92       0.76    0.01      0.01      2.68        1.73    0.68   0.19
# 0      0.92       0.00    0.00      0.00      2.69        2.85    0.61   0.16
#
#    bal_acc  cv_score_mean  cv_score_std  model_churn_cost  sample
# 0     0.69           0.38          0.01        3477700.00       0
# 0     0.82           0.75          0.01        3546875.00       0
# 0     0.71           0.46          0.01        3616900.00       0
# 0     0.65           0.31          0.02        3718450.00       0
# 0     0.50           0.00          0.00       12426250.00       0
# 0     0.50           0.01          0.00        4635875.00       0
# 0     0.50           0.00          0.00        4654500.00       0

# %%
y_test.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-2820df361543> in <module>
# ----> 1 y_test.value_counts()
#
# NameError: name 'y_test' is not defined

# %%
218173+11202+7416+2420
# Out:
# 239211

# %%
CLF: {'class_weight': 'balanced', 'criterion': 'gini', 'max_depth': 25, 'min_samples_leaf': 39, 'min_samples_split': 75, 'n_estimators': 162}
Performing 3-fold CV on test set
P_Recall: 0.747; N_Recall: 0.853

# %% [markdown]
# ### Experiment 1.2 Baseline - Default Settings - Oversampled training set 100%

# %%
# %%time
sampler = ('ROS 1:1', RandomOverSampler(random_state=RANDOM_STATE))

exp_metrics = perform_experiment(base_dataset, classifiers, sampler, 1, RANDOM_STATE, cv_iter=CV_ITER, cat_col = ['city','registered_via', 'gender'])

all_metrics = all_metrics.append(exp_metrics)

# %% [markdown]
# ### Experiment 1.3 Baseline - Default Settings - Undersampled training set

# %%
sampler = ('RUS 1:1', RandomUnderSampler(random_state=RANDOM_STATE))

exp_metrics = perform_experiment(base_dataset, classifiers, sampler, 1, RANDOM_STATE, cv_iter=CV_ITER, cat_col = ['city','registered_via', 'gender'])

all_metrics = all_metrics.append(exp_metrics)

# %% [markdown]
# ### Experiment 1.4 Baseline - Default Settings - Over sampling - 33% of majority size

# %%
sampler = ('ROS 3:1', RandomOverSampler(random_state=RANDOM_STATE, sampling_strategy = 1/3))

exp_metrics = perform_experiment(base_dataset, classifiers, sampler, 1, RANDOM_STATE, cv_iter=CV_ITER, cat_col = ['city','registered_via', 'gender'])

all_metrics = all_metrics.append(exp_metrics)

# %% [markdown]
# ### Experiment 1.5 Baseline - Default Settings - Over sampling - 66% of majority size

# %%
sampler = ('ROS 3:2', RandomOverSampler(random_state=RANDOM_STATE, sampling_strategy = 2/3))

exp_metrics = perform_experiment(base_dataset, classifiers, sampler, 1, RANDOM_STATE, cv_iter=CV_ITER, cat_col = ['city','registered_via', 'gender'])

all_metrics = all_metrics.append(exp_metrics)

# %% [markdown]
# ### Experiment 1.6 Baseline - Default Settings - Over sampling - 50% of majority size

# %%
sampler = ('ROS 2:1', RandomOverSampler(random_state=RANDOM_STATE, sampling_strategy = 1/2))

exp_metrics = perform_experiment(base_dataset, classifiers, sampler, 1, RANDOM_STATE, cv_iter=CV_ITER, cat_col = ['city','registered_via', 'gender'])

all_metrics = all_metrics.append(exp_metrics)

# %% [markdown]
# ### Experiment 1.7 Baseline Default Settings SMOTE-NC

# %%
sampler = ('SMOTE_NC', SMOTENC(random_state=RANDOM_STATE, categorical_features=[0,1,2,3,4,5,6,7,8,13,14], n_jobs=8))

## Keep the following, essentially dropping the dt columns
cols = ['is_churn', 'city', 'gender', 'age_cat', 'registered_via', 'total_order',
       'payment_method_id_mode', 'payment_method_id_count',
       'payment_plan_days_mode', 'payment_plan_days_mean',
       'plan_list_price_mean', 'plan_lifetime_value', 'actual_amount_mean',
       'total_actual_amount', 'is_auto_renew_mode', 'cancel_times','transaction_date_delta']

exp_metrics = perform_experiment(base_dataset[cols], classifiers, sampler, 1, RANDOM_STATE, cv_iter=CV_ITER, cat_col = ['city','registered_via', 'gender'])

all_metrics = all_metrics.append(exp_metrics)

# %%
all_metrics.sort_values('model_churn_cost', ascending=True)

# %%
## Just try an SVM 
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier

# %%
# %%time
model_train_results = train_model(base_dataset, sampling_method = 'under', classifiers = [('SGDClassifier', SGDClassifier(loss='log'))])

# %%
## Print the feature importance 

feature_index = np.flip(np.argsort(model.feature_importances_), axis=0)
ordered_features = []
column_names = X_test.columns

for i in feature_index[0:10]:
    print(np.round(model.feature_importances_[i], 3), ' --> ', column_names[i])
    ordered_features.append(column_names[i])

# %%
## Print the permutation importance 

import eli5
from eli5.sklearn import PermutationImportance

_, X_test, _, y_test = prepare_train_test_split(model_dataset, 0)

perm = PermutationImportance(model, random_state=1).fit(X_test, y_test)

eli5.show_weights(perm, feature_names = X_test.columns.tolist())

# %%
#model_name, model = model_train_results[1][2]

for model_name, model in model_train_results[1]:
    probs = model.predict_proba(X_test)[:, 1]
    pr_data = plot_precision_recall(
        y_test, probs, title='PR Curve for {0}'.format(model_name))

# %%
probs = model.predict_proba(X_test)[:, 1]
pr_data = plot_precision_recall(
    y_test, probs, title='PR Curve for {0}'.format(model_name))

# %%
pr_data = plot_roc(
    y_test, probs, title='ROC Curve for {0}'.format(model_name))

# %%
print(plt.style.available)

# %%
model_dataset.head()

# %%
print("Original Data distribution")
print(model_dataset['is_churn'].value_counts())

# %%
# Display new class counts
print('Sci-Kit Learn : resample : Down Sampled data set')
train_downsample = undersampled_dataset(model_dataset, 'is_churn')

print(train_downsample['is_churn'].value_counts())
print("Num records = ", train_downsample.shape[0])
train_downsample.is_churn.value_counts().plot(kind='bar', title='Count (target)')

# %%
# Display new class counts
print('Sci-Kit Learn : resample : Up Sampled data set')
train_upsample = oversampled_dataset(model_dataset, 'is_churn')

print(train_upsample['is_churn'].value_counts())
print("Num records = ", train_upsample.shape[0])
train_upsample.is_churn.value_counts().plot(kind='bar', title='Count (target)')

# %%
probs = model.predict_proba(X_test)[:, 1]
pr_data = plot_precision_recall(
    y_test, probs, title='Precision-Recall Curve for Random Forest')

# %%
precision_above = pr_data.loc[pr_data['precision'] >= 0.25].copy()
precision_above.sort_values('recall', ascending=False, inplace=True)
precision_above.head()

# %%
threshold_required = 0.5
# Make predictions where probability is above threshold
preds = np.zeros(len(y_test))
preds[probs >= threshold_required] = 1

# Make and plot confusion matrix
cm = confusion_matrix(y_test, preds)
plot_confusion_matrix(cm, classes=['No Churn', 'Churn'],
                      title='Churn Confusion Matrix')

# %%
model_dataset.head()

# %%
fi = pd.DataFrame({'importance': model.feature_importances_}, index=model_dataset.iloc[:, 1:].columns).\
    sort_values('importance', ascending=False)
fi.head(10)
