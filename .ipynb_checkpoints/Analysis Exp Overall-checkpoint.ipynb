# %%
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import pandas as pd
import time
import gc; gc.enable()
import time
import sys

pd.options.display.float_format = "{:.3f}".format
np.set_printoptions(precision=4)

import matplotlib.pyplot as plt
# %matplotlib inline

sys.path.append('modules')

from shared_functions import *

import pickle
from datetime import datetime

# %%
# from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"

# %%
def load_results(file_name):
    data = None
    with open(file_name, 'rb') as f:
        # The protocol version used is detected automatically, so we do not
        # have to specify it.
        data = pickle.load(f)
    return data

def filter_top_model_results(top_models, all_model_results):
    filtered_data = list()
    for idx, row in top_models.iterrows():
        #print("row.label: " + row.label + ',' + row.classifier + ',' + row.sampling_method)
        for res in all_model_results:       
            for alg_results in res:
                if alg_results[0] == row.label and alg_results[1] == row.classifier and alg_results[2] == row.sampling_method:
                    #print("row.label: " + row.label + ',' + row.classifier + ',' + row.sampling_method + ',' + row.exp_key)
                    filtered_data.append(("{} - {} :: {}".format(row.exp_key, row.classifier, row.sampling_method), 
                                          alg_results))
    return filtered_data

def prepare_plot_data(model_results):
    plot_data = list()
    for res in model_results:       
        for label, alg_results in res:
            _, model_name, sampling_method, _, tpr, fpr, roc_auc, precision, recall, prc_auc = alg_results

            #if 'time_budget' in top_models.columns:
            #    plot_data.append(("{} :: {}".format(exp_key + '-' + model_name + '::' + row.time_budget, sampling_method), tpr, fpr, roc_auc, precision, recall, prc_auc))
            #else:
            plot_data.append((label, tpr, fpr, roc_auc, precision, recall, prc_auc))

    return plot_data

def rebuild_results(res):
    ## Gather all the metrics
    temp_metrics = pd.DataFrame()
    temp_results = list()
    for i in range(0, len(res)):
        temp_metrics = pd.concat([temp_metrics, res[i][1]])
        temp_results.append(res[i][2]) 
    
    return temp_metrics, temp_results

# %%
measurements = ['exp_key', 'label', 'classifier', 'sampling_method', \
                #'fp', 'fn',\
                'balanced_accuracy', 'recall', 'precision', \
                 #'f1_score',\
                'time_budget', 'aucroc', 'auprc',\
                'model_churn_cost']

measurements_alias = ['experiment', 'label', 'classifier', 'sampling', \
                      #'fp', 'fn',\
                      'bal_acc', 'recall', 'precision',\
                      # 'f1',\
                      'time_budget', 'auroc', 'auprc',\
                      'churn_cost']

# %%
measure_by = ['balanced_accuracy', 'recall', 'model_churn_cost']
measure_by_sort = [False, False, True]

# measure_by = ['balanced_accuracy']
# measure_by_sort = [False]

# measure_by = ['model_churn_cost']
# measure_by_sort = [True]

# measure_by = ['f1_score']
# measure_by_sort = [False]

# %% [markdown]
# ## Summarise performance of the best overall approaches

# %%
top_metrics = pd.DataFrame()
top_results = list()

experiments = {'Exp 1.1':'/home/dissertation/code/RESULTS_FINAL/Basic_DefaultHyper_2019-08-12.pickle',
               'Exp 2.1':'/home/dissertation/code/RESULTS_FINAL/Manual_GridSearch_2019-08-10.pickle',
               'Exp 2.2':'/home/dissertation/code/RESULTS_FINAL/Manual_RdmSearch_2019-08-10.pickle',
               'Exp 3.1':'/home/dissertation/code/RESULTS_FINAL/DFS_Default_2019-08-10.pickle',
               'Exp 3.2':'/home/dissertation/code/RESULTS_FINAL/DFS_RdmSearch_2019-08-18.pickle',
               'Exp 4.1':'/home/dissertation/code/RESULTS_FINAL/Basic_Asklearn_20190813.pickle',
               'Exp 4.2':'/home/dissertation/code/RESULTS_FINAL/Manual_Asklearn_20190816.pickle',
               'Exp 4.3':'/home/dissertation/code/RESULTS_FINAL/DFS_Asklearn_20190818.pickle',
              }
                      
for exp_key, exp_datafile in experiments.items():
    print(exp_key, exp_datafile)
    exp = load_results(exp_datafile)
    exp_metrics, exp_results = rebuild_results(exp)
    exp_metrics['exp_key'] = exp_key
    
    top_metrics = top_metrics.append(exp_metrics.sort_values(measure_by, ascending=measure_by_sort).head(1))
    
    top_results.append(filter_top_model_results(exp_metrics.sort_values(measure_by, ascending=measure_by_sort).head(1), exp_results))

# Convert train_time
top_metrics['train_time'] = (top_metrics['train_time']/60)
top_metrics['cv_time'] = (top_metrics['cv_time']/60)

# Convert model_churn_cost to EUR from TWD
top_metrics['model_churn_cost'] = np.round(top_metrics['model_churn_cost'] * 0.029).astype(int)
top_metrics['time_budget'] = top_metrics['train_time']
top_metrics.loc[top_metrics.classifier == 'AutoSklearnClassifier', 'time_budget'] = top_metrics[top_metrics.classifier == 'AutoSklearnClassifier'].label.str.replace('[^0-9]', '', regex=True)

top_metrics
# Out:
# Exp 1.1 /home/dissertation/code/RESULTS_FINAL/Basic_DefaultHyper_2019-08-12.pickle
# Exp 2.1 /home/dissertation/code/RESULTS_FINAL/Manual_GridSearch_2019-08-10.pickle
# Exp 2.2 /home/dissertation/code/RESULTS_FINAL/Manual_RdmSearch_2019-08-10.pickle
# Exp 3.1 /home/dissertation/code/RESULTS_FINAL/DFS_Default_2019-08-10.pickle
# Exp 3.2 /home/dissertation/code/RESULTS_FINAL/DFS_RdmSearch_2019-08-18.pickle
# Exp 4.1 /home/dissertation/code/RESULTS_FINAL/Basic_Asklearn_20190813.pickle
# Exp 4.2 /home/dissertation/code/RESULTS_FINAL/Manual_Asklearn_20190816.pickle
# Exp 4.3 /home/dissertation/code/RESULTS_FINAL/DFS_Asklearn_20190818.pickle
#                                 label              classifier sampling_method  \
# 0                XGB_basic_5cv_recall           XGBClassifier         ROS 1:1
# 0                  RF_grid_5cv_recall  RandomForestClassifier         ROS 2:1
# 0                RF_random_5cv_recall  RandomForestClassifier         ROS 2:1
# 0             XGB_dfsbasic_5cv_recall           XGBClassifier         ROS 1:1
# 0             RF_dfsrandom_5cv_recall  RandomForestClassifier         RUS 1:1
# 0  ASKLEARN_15_askbasic_Nonecv_recall   AutoSklearnClassifier         RUS 1:1
# 0  ASKLEARN_50_askbasic_Nonecv_recall   AutoSklearnClassifier         RUS 1:1
# 0  ASKLEARN_55_askbasic_Nonecv_recall   AutoSklearnClassifier         RUS 1:1
#
#        tn    fn     tp     fp  accuracy  precision  recall  ...  cv_time  \
# 0  204794  6209  17852  28632     0.865      0.384   0.742  ...    0.691
# 0  204030  6283  17778  29396     0.861      0.377   0.739  ...    0.902
# 0  199480  5681  18380  33946     0.846      0.351   0.764  ...    0.704
# 0  217765  5172  18889  15661     0.919      0.547   0.785  ...    2.677
# 0  216325  4447  19614  17101     0.916      0.534   0.815  ...    2.634
# 0  198852  4833  19228  34574     0.847      0.357   0.799  ...    0.000
# 0  190881  4757  19304  42545     0.816      0.312   0.802  ...    0.000
# 0  216861  4071  19990  16565     0.920      0.547   0.831  ...    0.000
#
#    aucroc  auprc  balanced_accuracy  cv_score_mean  cv_score_std  \
# 0   0.881  0.624              0.810          0.389         0.005
# 0   0.887  0.605              0.806          0.707         0.003
# 0   0.886  0.600              0.809          0.740         0.010
# 0   0.946  0.748              0.859          0.647         0.039
# 0   0.951  0.752              0.871          0.854         0.014
# 0   0.898  0.645              0.826             -1            -1
# 0   0.883  0.583              0.810             -1            -1
# 0   0.954  0.769              0.880             -1            -1
#
#    model_churn_cost  sample  exp_key time_budget
# 0            224834       0  Exp 1.1       2.677
# 0            227908       0  Exp 2.1     100.315
# 0            234120       0  Exp 2.2      40.997
# 0            175189       0  Exp 3.1      11.267
# 0            170955       0  Exp 3.2       9.356
# 0            226104       0  Exp 4.1          15
# 0            248339       0  Exp 4.2          50
# 0            165039       0  Exp 4.3          55
#
# [8 rows x 24 columns]

# %% [markdown]
# ### The best/worst performing models as measured by ....

# %%
### print("Getting best results for {} / ordered ascending? {}".format(measure_by, measure_by_sort))

temp = top_metrics.sort_values(measure_by, ascending=measure_by_sort)

temp = temp[measurements]
temp['classifier'] = temp['classifier'].apply(lambda v: str(v).replace('Classifier', ''))
temp.columns = measurements_alias
temp

#print(temp.drop(columns=['classifier'], axis=1).to_latex(index=False))
# Out:
#   experiment                               label    classifier sampling  \
# 0    Exp 4.3  ASKLEARN_55_askbasic_Nonecv_recall   AutoSklearn  RUS 1:1
# 0    Exp 3.2             RF_dfsrandom_5cv_recall  RandomForest  RUS 1:1
# 0    Exp 3.1             XGB_dfsbasic_5cv_recall           XGB  ROS 1:1
# 0    Exp 4.1  ASKLEARN_15_askbasic_Nonecv_recall   AutoSklearn  RUS 1:1
# 0    Exp 4.2  ASKLEARN_50_askbasic_Nonecv_recall   AutoSklearn  RUS 1:1
# 0    Exp 1.1                XGB_basic_5cv_recall           XGB  ROS 1:1
# 0    Exp 2.2                RF_random_5cv_recall  RandomForest  ROS 2:1
# 0    Exp 2.1                  RF_grid_5cv_recall  RandomForest  ROS 2:1
#
#    bal_acc  recall  precision time_budget  auroc  auprc  churn_cost
# 0    0.880   0.831      0.547          55  0.954  0.769      165039
# 0    0.871   0.815      0.534       9.356  0.951  0.752      170955
# 0    0.859   0.785      0.547      11.267  0.946  0.748      175189
# 0    0.826   0.799      0.357          15  0.898  0.645      226104
# 0    0.810   0.802      0.312          50  0.883  0.583      248339
# 0    0.810   0.742      0.384       2.677  0.881  0.624      224834
# 0    0.809   0.764      0.351      40.997  0.886  0.600      234120
# 0    0.806   0.739      0.377     100.315  0.887  0.605      227908

# %%
# exp_metrics[['label','classifier','sampling_method','accuracy','precision','recall','tp','tn','fp','fn']]

# %% [markdown]
# ### Summary performance statistics of classifiers over all sampling techniques

# %%
## Excludes LR and MLP as those produce bad classifiers

stats_summary = {'best':max,
                 'median':'median', 
                 'iqr':lambda x: np.percentile(x, 75, interpolation='higher') - np.percentile(x, 25, interpolation='lower'),
                 #'range':lambda x: max(x) - min(x)
                }
#[~exp_metrics.recall.isin([0.0, 1.0])]
summary = \
    top_metrics\
            .groupby(['exp_key'])\
            .agg({
                 'balanced_accuracy':stats_summary,
                 'recall':stats_summary,
                 'precision':stats_summary,
                 'model_churn_cost':{'best':min},
                 #'aucroc':stats_summary,
                 #'auprc':stats_summary,
                 'train_time':'median',
                 })\
            .reset_index()\
            .sort_values(('balanced_accuracy', 'best'), ascending=False)
summary
#print(summary.to_latex(index=False))
# Out:
# /home/anaconda/envs/py373/lib/python3.7/site-packages/pandas/core/groupby/generic.py:1315: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    exp_key balanced_accuracy              recall              precision  \
#                         best median   iqr   best median   iqr      best
# 7  Exp 4.3             0.880  0.880 0.000  0.831  0.831 0.000     0.547
# 4  Exp 3.2             0.871  0.871 0.000  0.815  0.815 0.000     0.534
# 3  Exp 3.1             0.859  0.859 0.000  0.785  0.785 0.000     0.547
# 5  Exp 4.1             0.826  0.826 0.000  0.799  0.799 0.000     0.357
# 6  Exp 4.2             0.810  0.810 0.000  0.802  0.802 0.000     0.312
# 0  Exp 1.1             0.810  0.810 0.000  0.742  0.742 0.000     0.384
# 2  Exp 2.2             0.809  0.809 0.000  0.764  0.764 0.000     0.351
# 1  Exp 2.1             0.806  0.806 0.000  0.739  0.739 0.000     0.377
#
#                model_churn_cost train_time
#   median   iqr             best     median
# 7  0.547 0.000           165039     64.786
# 4  0.534 0.000           170955      9.356
# 3  0.547 0.000           175189     11.267
# 5  0.357 0.000           226104     20.683
# 6  0.312 0.000           248339     58.546
# 0  0.384 0.000           224834      2.677
# 2  0.351 0.000           234120     40.997
# 1  0.377 0.000           227908    100.315

# %% [markdown]
# ### The best performing models by sampling method as measured by ....

# %%
# print("Getting results for {} / ordered ascending? {}".format(measure_by, measure_by_sort))
# # top_results = exp_metrics[(exp_metrics.recall > 0) & (exp_metrics.recall < 1)]\
#                     .sort_values(measure_by, ascending=measure_by_sort).groupby('sampling_method').head(1)
# top_results = top_results[measurements]
# top_results.sort_values('balanced_accuracy', ascending=False)

# %% [markdown]
# ### Classifier train time distribution by sampling method

# %%
fig, ax = plt.subplots(figsize=(10,8))
plt.ylabel('Seconds')
top_metrics.boxplot(column='train_time', by='sampling_method', ax=ax)
plt.title('Classifier Training Time Distribution\n', size=17)
plt.suptitle(' ')
plt.xlabel('Sampling Method')
# Out:
# Text(0.5, 0, 'Sampling Method')

# %% [markdown]
# ### Recall/Bal Acc performance over time_budgets or sampling_method

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16,8))

top_metrics.boxplot(column='recall', by='sampling_method', ax=axes[0])
plt.ylabel('')
#plt.title('Classifier Performance Distribution\n', size=17)
plt.suptitle(' ')
plt.xlabel('Sampling Method')


top_metrics.boxplot(column='recall', by='time_budget', ax=axes[1])
plt.ylabel('')
#plt.title('Classifier Performance Distribution\n', size=17)
plt.suptitle(' ')
plt.xlabel('Time Budget')

fig = axes[1].get_figure()
fig.suptitle('Classifier Performance Distribution\n', size=20)
# Out:
# Text(0.5, 0.98, 'Classifier Performance Distribution\n')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16,8))

top_metrics.boxplot(column='recall', by='sampling_method', ax=axes[0])
plt.ylabel('')
#plt.title('Classifier Performance Distribution\n', size=17)
plt.suptitle(' ')
plt.xlabel('Sampling Method')

## Plot the balanced_accuracy over time grouped by sampling_method
df = top_metrics.copy(deep=True)
fig, ax = plt.subplots(figsize=(10,8))
df.set_index('time_budget', inplace=True)
df.groupby('sampling_method')['recall'].plot(legend=True, ax=axes[1])
plt.ylabel('')
#plt.title('Classifier Performance Distribution\n', size=17)
plt.suptitle(' ')
plt.xlabel('Time Budget')

fig = axes[0].get_figure()
fig.suptitle('Classifier Performance Distribution - Recall\n', size=20)
# Out:
# Text(0.5, 0.98, 'Classifier Performance Distribution - Recall\n')

# %% [markdown]
# ### For this approach plot the best models by classifier

# %%
temp_metrics
# Out:
#                                 label              classifier sampling_method  \
# 0  ASKLEARN_55_askbasic_Nonecv_recall   AutoSklearnClassifier         RUS 1:1
# 0             RF_dfsrandom_5cv_recall  RandomForestClassifier         RUS 1:1
# 0             XGB_dfsbasic_5cv_recall           XGBClassifier         ROS 1:1
# 0  ASKLEARN_15_askbasic_Nonecv_recall   AutoSklearnClassifier         RUS 1:1
# 0  ASKLEARN_50_askbasic_Nonecv_recall   AutoSklearnClassifier         RUS 1:1
# 0                XGB_basic_5cv_recall           XGBClassifier         ROS 1:1
# 0                RF_random_5cv_recall  RandomForestClassifier         ROS 2:1
# 0                  RF_grid_5cv_recall  RandomForestClassifier         ROS 2:1
#
#        tn    fn     tp     fp  accuracy  precision  recall  ...  aucroc  \
# 0  216861  4071  19990  16565     0.920      0.547   0.831  ...   0.954
# 0  216325  4447  19614  17101     0.916      0.534   0.815  ...   0.951
# 0  217765  5172  18889  15661     0.919      0.547   0.785  ...   0.946
# 0  198852  4833  19228  34574     0.847      0.357   0.799  ...   0.898
# 0  190881  4757  19304  42545     0.816      0.312   0.802  ...   0.883
# 0  204794  6209  17852  28632     0.865      0.384   0.742  ...   0.881
# 0  199480  5681  18380  33946     0.846      0.351   0.764  ...   0.886
# 0  204030  6283  17778  29396     0.861      0.377   0.739  ...   0.887
#
#    auprc  balanced_accuracy  cv_score_mean  cv_score_std  model_churn_cost  \
# 0  0.769              0.880             -1            -1            165039
# 0  0.752              0.871          0.854         0.014            170955
# 0  0.748              0.859          0.647         0.039            175189
# 0  0.645              0.826             -1            -1            226104
# 0  0.583              0.810             -1            -1            248339
# 0  0.624              0.810          0.389         0.005            224834
# 0  0.600              0.809          0.740         0.010            234120
# 0  0.605              0.806          0.707         0.003            227908
#
#    sample  exp_key time_budget  \
# 0       0  Exp 4.3          55
# 0       0  Exp 3.2       9.356
# 0       0  Exp 3.1      11.267
# 0       0  Exp 4.1          15
# 0       0  Exp 4.2          50
# 0       0  Exp 1.1       2.677
# 0       0  Exp 2.2      40.997
# 0       0  Exp 2.1     100.315
#
#                                     classifier_label
# 0  AutoSklearnClassifier :: 0        55\n0     9....
# 0  RandomForestClassifier :: 0        55\n0     9...
# 0  XGBClassifier :: 0        55\n0     9.356\n0  ...
# 0  AutoSklearnClassifier :: 0        55\n0     9....
# 0  AutoSklearnClassifier :: 0        55\n0     9....
# 0  XGBClassifier :: 0        55\n0     9.356\n0  ...
# 0  RandomForestClassifier :: 0        55\n0     9...
# 0  RandomForestClassifier :: 0        55\n0     9...
#
# [8 rows x 25 columns]

# %%
top_results
# Out:
# [[('Exp 1.1 - XGBClassifier :: ROS 1:1',
#    ('XGB_basic_5cv_recall',
#     'XGBClassifier',
#     'ROS 1:1',
#         feat_importances               ordered_features
#     0              0.566           plan_list_price_mean
#     1              0.122            plan_lifetime_value
#     2              0.052           ohe_registered_via_3
#     3              0.052             is_auto_renew_mode
#     4              0.033  ohe_payment_method_id_mode_39
#     5              0.032         payment_plan_days_mean
#     6              0.031         registration_init_time
#     7              0.027         payment_plan_days_mode
#     8              0.015  ohe_payment_method_id_mode_37
#     9              0.013  ohe_payment_method_id_mode_35
#     10             0.010        payment_method_id_count
#     11             0.008      registration_init_time_dt
#     12             0.007  ohe_payment_method_id_mode_32
#     13             0.007  ohe_payment_method_id_mode_36
#     14             0.005  ohe_payment_method_id_mode_29
#     15             0.005  ohe_payment_method_id_mode_38
#     16             0.005  ohe_payment_method_id_mode_28
#     17             0.004                    total_order
#     18             0.004                             bd
#     19             0.002  ohe_payment_method_id_mode_34
#     20             0.001                     ohe_city_8
#     21             0.000  ohe_payment_method_id_mode_20
#     22             0.000                    ohe_city_10
#     23             0.000                    ohe_city_19
#     24             0.000                    ohe_city_18
#     25             0.000                    ohe_city_17
#     26             0.000                    ohe_city_16
#     27             0.000                    ohe_city_15
#     28             0.000                    ohe_city_14
#     29             0.000                    ohe_city_13
#     ..               ...                            ...
#     38             0.000  ohe_payment_method_id_mode_26
#     39             0.000  ohe_payment_method_id_mode_27
#     40             0.000  ohe_payment_method_id_mode_30
#     41             0.000  ohe_payment_method_id_mode_31
#     42             0.000  ohe_payment_method_id_mode_33
#     43             0.000                    ohe_city_20
#     44             0.000                    ohe_city_22
#     45             0.000  ohe_payment_method_id_mode_19
#     46             0.000   ohe_payment_method_id_mode_8
#     47             0.000  ohe_payment_method_id_mode_18
#     48             0.000  ohe_payment_method_id_mode_17
#     49             0.000  ohe_payment_method_id_mode_16
#     50             0.000  ohe_payment_method_id_mode_15
#     51             0.000  ohe_payment_method_id_mode_14
#     52             0.000  ohe_payment_method_id_mode_13
#     53             0.000  ohe_payment_method_id_mode_12
#     54             0.000  ohe_payment_method_id_mode_11
#     55             0.000  ohe_payment_method_id_mode_10
#     56             0.000   ohe_payment_method_id_mode_6
#     57             0.000                     ohe_city_3
#     58             0.000           ohe_registered_via_9
#     59             0.000           ohe_registered_via_7
#     60             0.000  ohe_payment_method_id_mode_21
#     61             0.000  ohe_payment_method_id_mode_22
#     62             0.000                     ohe_city_9
#     63             0.000                     ohe_city_7
#     64             0.000                     ohe_city_6
#     65             0.000                     ohe_city_5
#     66             0.000                     ohe_city_4
#     67             0.000           ohe_registered_via_4
#
#     [68 rows x 2 columns],
#     array([0.0000e+00, 4.1561e-05, 4.1561e-05, ..., 9.9996e-01, 9.9996e-01,
#            1.0000e+00]),
#     array([0.0000e+00, 0.0000e+00, 4.2840e-06, ..., 9.9687e-01, 9.9713e-01,
#            1.0000e+00]),
#     0.8812902278245336,
#     array([0.0934, 0.0937, 0.0937, ..., 0.5   , 1.    , 1.    ]),
#     array([1.0000e+00, 9.9996e-01, 9.9996e-01, ..., 4.1561e-05, 4.1561e-05,
#            0.0000e+00]),
#     0.6242916373086518))],
#  [('Exp 2.1 - RandomForestClassifier :: ROS 2:1',
#    ('RF_grid_5cv_recall',
#     'RandomForestClassifier',
#     'ROS 2:1',
#         feat_importances               ordered_features
#     0              0.111            total_actual_amount
#     1              0.109                   cancel_times
#     2              0.101         payment_plan_days_mode
#     3              0.063         payment_plan_days_mean
#     4              0.062             actual_amount_mean
#     5              0.062           plan_list_price_mean
#     6              0.059         registration_init_time
#     7              0.053              membership_months
#     8              0.052            plan_lifetime_value
#     9              0.050  ohe_payment_method_id_mode_37
#     10             0.049             is_auto_renew_mode
#     11             0.039        payment_method_id_count
#     12             0.034           ohe_registered_via_4
#     13             0.033  ohe_payment_method_id_mode_40
#     14             0.029                             bd
#     15             0.028                    total_order
#     16             0.005         transaction_date_delta
#     17             0.005                ohe_gender_male
#     18             0.004  ohe_payment_method_id_mode_38
#     19             0.004  ohe_payment_method_id_mode_31
#     20             0.004  ohe_payment_method_id_mode_36
#     21             0.004           ohe_registered_via_7
#     22             0.004  ohe_payment_method_id_mode_39
#     23             0.003                    ohe_city_12
#     24             0.003  ohe_payment_method_id_mode_34
#     25             0.003                     ohe_city_9
#     26             0.003                     ohe_city_4
#     27             0.003           ohe_registered_via_3
#     28             0.002                     ohe_city_3
#     29             0.002                    ohe_city_14
#     30             0.002  ohe_payment_method_id_mode_41
#     31             0.002  ohe_payment_method_id_mode_33
#     32             0.002                    ohe_city_21
#     33             0.002                     ohe_city_5
#     34             0.001                    ohe_city_13
#     35             0.001           ohe_registered_via_9
#     36             0.001  ohe_payment_method_id_mode_32
#     37             0.001                    ohe_city_11
#     38             0.001  ohe_payment_method_id_mode_30
#     39             0.001                     ohe_city_8
#     40             0.001                    ohe_city_10
#     41             0.001                     ohe_city_7
#     42             0.001                    ohe_city_17
#     43             0.000             ohe_gender_unknown
#     44             0.000                    ohe_city_16
#     45             0.000                    ohe_city_20
#     46             0.000                    ohe_city_22
#     47             0.000                     ohe_city_6
#     48             0.000                    ohe_city_15
#     49             0.000                    ohe_city_19
#     50             0.000                    ohe_city_18,
#     array([0.0000e+00, 4.1561e-05, 3.3249e-04, ..., 1.0000e+00, 1.0000e+00,
#            1.0000e+00]),
#     array([0.    , 0.    , 0.    , ..., 0.9999, 0.9999, 1.    ]),
#     0.8868450279857325,
#     array([0.0935, 0.0935, 0.0935, ..., 1.    , 1.    , 1.    ]),
#     array([1.0000e+00, 9.9996e-01, 9.9996e-01, ..., 8.3122e-05, 4.1561e-05,
#            0.0000e+00]),
#     0.6054547858527227))],
#  [('Exp 2.2 - RandomForestClassifier :: ROS 2:1',
#    ('RF_random_5cv_recall',
#     'RandomForestClassifier',
#     'ROS 2:1',
#         feat_importances               ordered_features
#     0              0.127            total_actual_amount
#     1              0.108         payment_plan_days_mode
#     2              0.094                   cancel_times
#     3              0.064         payment_plan_days_mean
#     4              0.062             actual_amount_mean
#     5              0.061           plan_list_price_mean
#     6              0.057  ohe_payment_method_id_mode_37
#     7              0.055              membership_months
#     8              0.052             is_auto_renew_mode
#     9              0.050            plan_lifetime_value
#     10             0.045        payment_method_id_count
#     11             0.045         registration_init_time
#     12             0.041           ohe_registered_via_4
#     13             0.039  ohe_payment_method_id_mode_40
#     14             0.029                    total_order
#     15             0.016                             bd
#     16             0.005  ohe_payment_method_id_mode_38
#     17             0.005  ohe_payment_method_id_mode_31
#     18             0.004  ohe_payment_method_id_mode_36
#     19             0.004                ohe_gender_male
#     20             0.004  ohe_payment_method_id_mode_39
#     21             0.003           ohe_registered_via_7
#     22             0.003  ohe_payment_method_id_mode_34
#     23             0.003           ohe_registered_via_3
#     24             0.003                     ohe_city_9
#     25             0.002  ohe_payment_method_id_mode_33
#     26             0.002         transaction_date_delta
#     27             0.002  ohe_payment_method_id_mode_41
#     28             0.002                    ohe_city_12
#     29             0.001                     ohe_city_4
#     30             0.001                     ohe_city_3
#     31             0.001           ohe_registered_via_9
#     32             0.001                    ohe_city_14
#     33             0.001                    ohe_city_21
#     34             0.001                     ohe_city_5
#     35             0.001  ohe_payment_method_id_mode_32
#     36             0.001  ohe_payment_method_id_mode_30
#     37             0.001                    ohe_city_13
#     38             0.001                    ohe_city_11
#     39             0.001                     ohe_city_8
#     40             0.000                    ohe_city_10
#     41             0.000                     ohe_city_7
#     42             0.000                    ohe_city_17
#     43             0.000             ohe_gender_unknown
#     44             0.000                    ohe_city_16
#     45             0.000                    ohe_city_20
#     46             0.000                    ohe_city_22
#     47             0.000                     ohe_city_6
#     48             0.000                    ohe_city_15
#     49             0.000                    ohe_city_19
#     50             0.000                    ohe_city_18,
#     array([0.0000e+00, 4.1561e-05, 3.3249e-04, ..., 1.0000e+00, 1.0000e+00,
#            1.0000e+00]),
#     array([0., 0., 0., ..., 1., 1., 1.]),
#     0.8862156537676861,
#     array([0.0935, 0.0935, 0.0935, ..., 1.    , 1.    , 1.    ]),
#     array([1.0000e+00, 9.9996e-01, 9.9996e-01, ..., 8.3122e-05, 4.1561e-05,
#            0.0000e+00]),
#     0.5995070289923121))],
#  [('Exp 3.1 - XGBClassifier :: ROS 1:1',
#    ('XGB_dfsbasic_5cv_recall',
#     'XGBClassifier',
#     'ROS 1:1',
#          feat_importances                                  ordered_features
#     0               0.330              LAST(transactions.payment_method_id)
#     1               0.066                  LAST(transactions.is_auto_renew)
#     2               0.064             LAST(transactions.actual_amount_paid)
#     3               0.049       MEAN(transactions.DIFF(actual_amount_paid))
#     4               0.047          STD(transactions.DIFF(transaction_date))
#     5               0.038       LAST(transactions.DIFF(actual_amount_paid))
#     6               0.029               MAX(transactions.DIFF(daily_price))
#     7               0.026               LAST(transactions.price_difference)
#     8               0.021             SUM(transactions.planned_daily_price)
#     9               0.018                    DAY(registration_init_time_dt)
#     10              0.017              STD(transactions.actual_amount_paid)
#     11              0.015              SUM(transactions.actual_amount_paid)
#     12              0.014              MIN(transactions.actual_amount_paid)
#     13              0.014                SUM(transactions.transaction_date)
#     14              0.012         MEAN(transactions.DIFF(transaction_date))
#     15              0.011                SUM(transactions.price_difference)
#     16              0.010             MEAN(transactions.actual_amount_paid)
#     17              0.010               LAST(transactions.transaction_date)
#     18              0.010            LAST(transactions.planned_daily_price)
#     19              0.009                 SUM(transactions.plan_list_price)
#     20              0.009               SUM(transactions.payment_plan_days)
#     21              0.009          MIN(transactions.DIFF(transaction_date))
#     22              0.008                MAX(transactions.transaction_date)
#     23              0.008              LAST(transactions.DIFF(daily_price))
#     24              0.008                MIN(transactions.transaction_date)
#     25              0.007                LAST(transactions.plan_list_price)
#     26              0.006              LAST(transactions.payment_plan_days)
#     27              0.006               SUM(transactions.DIFF(daily_price))
#     28              0.006         SUM(transactions.DIFF(payment_plan_days))
#     29              0.006              MEAN(transactions.payment_plan_days)
#     ..                ...                                               ...
#     157             0.000    MAX(transactions.DIFF(membership_expire_date))
#     158             0.000       DIFF(SUM(transactions.planned_daily_price))
#     159             0.000        MAX(transactions.DIFF(actual_amount_paid))
#     160             0.000           MAX(transactions.DIFF(plan_list_price))
#     161             0.000              MEAN(transactions.DIFF(daily_price))
#     162             0.000                              ohe_registered_via_4
#     163             0.000         MEAN(transactions.DIFF(price_difference))
#     164             0.000   MEAN(transactions.DIFF(membership_expire_date))
#     165             0.000        MEAN(transactions.DIFF(payment_plan_days))
#     166             0.000          DIFF(SUM(transactions.transaction_date))
#     167             0.000               DIFF(SUM(transactions.daily_price))
#     168             0.000   DIFF(MEAN(transactions.membership_expire_date))
#     169             0.000          DIFF(LAST(transactions.plan_list_price))
#     170             0.000         DIFF(MEAN(transactions.transaction_date))
#     171             0.000          DIFF(MEAN(transactions.plan_list_price))
#     172             0.000        DIFF(MEAN(transactions.payment_plan_days))
#     173             0.000              DIFF(LAST(transactions.daily_price))
#     174             0.000      DIFF(LAST(transactions.planned_daily_price))
#     175             0.000         DIFF(LAST(transactions.price_difference))
#     176             0.000   DIFF(LAST(transactions.membership_expire_date))
#     177             0.000        DIFF(LAST(transactions.payment_plan_days))
#     178             0.000  DIFF(NUM_UNIQUE(transactions.payment_method_id))
#     179             0.000               DIFF(MIN(transactions.daily_price))
#     180             0.000       DIFF(MIN(transactions.planned_daily_price))
#     181             0.000          DIFF(MIN(transactions.price_difference))
#     182             0.000    DIFF(MIN(transactions.membership_expire_date))
#     183             0.000          DIFF(MIN(transactions.transaction_date))
#     184             0.000           DIFF(MIN(transactions.plan_list_price))
#     185             0.000         DIFF(MIN(transactions.payment_plan_days))
#     186             0.000                                                bd
#
#     [187 rows x 2 columns],
#     array([0.0000e+00, 4.1561e-05, 1.2468e-04, ..., 1.0000e+00, 1.0000e+00,
#            1.0000e+00]),
#     array([0.    , 0.    , 0.    , ..., 0.9999, 1.    , 1.    ]),
#     0.9458030511802966,
#     array([0.0935, 0.0937, 0.0937, ..., 1.    , 1.    , 1.    ]),
#     array([1.0000e+00, 9.9996e-01, 9.9996e-01, ..., 8.3122e-05, 4.1561e-05,
#            0.0000e+00]),
#     0.7484340556848194))],
#  [('Exp 3.2 - RandomForestClassifier :: RUS 1:1',
#    ('RF_dfsrandom_5cv_recall',
#     'RandomForestClassifier',
#     'RUS 1:1',
#          feat_importances                                 ordered_features
#     0               0.076             LAST(transactions.payment_method_id)
#     1               0.076                   MEAN(transactions.daily_price)
#     2               0.054      MEAN(transactions.DIFF(actual_amount_paid))
#     3               0.048             MAX(transactions.actual_amount_paid)
#     4               0.046            LAST(transactions.actual_amount_paid)
#     5               0.045       SUM(transactions.DIFF(actual_amount_paid))
#     6               0.042      LAST(transactions.DIFF(actual_amount_paid))
#     7               0.040       MAX(transactions.DIFF(actual_amount_paid))
#     8               0.036                    SUM(transactions.daily_price)
#     9               0.032        LAST(transactions.DIFF(transaction_date))
#     10              0.026       DIFF(MAX(transactions.actual_amount_paid))
#     11              0.025       STD(transactions.DIFF(actual_amount_paid))
#     12              0.024                 LAST(transactions.is_auto_renew)
#     13              0.019      DIFF(LAST(transactions.actual_amount_paid))
#     14              0.018             DIFF(MEAN(transactions.daily_price))
#     15              0.015                   LAST(transactions.daily_price)
#     16              0.015              LAST(transactions.transaction_date)
#     17              0.013        MEAN(transactions.DIFF(transaction_date))
#     18              0.012         MAX(transactions.DIFF(transaction_date))
#     19              0.011        DIFF(LAST(transactions.transaction_date))
#     20              0.010         SUM(transactions.DIFF(transaction_date))
#     21              0.010             SUM(transactions.actual_amount_paid)
#     22              0.010         MIN(transactions.DIFF(transaction_date))
#     23              0.010           LAST(transactions.planned_daily_price)
#     24              0.010             STD(transactions.actual_amount_paid)
#     25              0.009         STD(transactions.DIFF(transaction_date))
#     26              0.009               SUM(transactions.transaction_date)
#     27              0.008                    MIN(transactions.daily_price)
#     28              0.008                      ALL(transactions.is_cancel)
#     29              0.007              MEAN(transactions.price_difference)
#     ..                ...                                              ...
#     157             0.000                                  ohe_gender_male
#     158             0.000  DIFF(LAST(transactions.membership_expire_date))
#     159             0.000              DIFF(STD(transactions.daily_price))
#     160             0.000                                       ohe_city_9
#     161             0.000                                       ohe_city_4
#     162             0.000         MIN(transactions.membership_expire_date)
#     163             0.000   DIFF(MIN(transactions.membership_expire_date))
#     164             0.000                                      ohe_city_12
#     165             0.000                                      ohe_city_21
#     166             0.000                                       ohe_city_3
#     167             0.000                                      ohe_city_14
#     168             0.000       NUM_UNIQUE(transactions.payment_method_id)
#     169             0.000                                       ohe_city_5
#     170             0.000   MIN(transactions.DIFF(membership_expire_date))
#     171             0.000                                      ohe_city_13
#     172             0.000                                         DIFF(bd)
#     173             0.000                                      ohe_city_10
#     174             0.000                               ohe_gender_unknown
#     175             0.000                                      ohe_city_16
#     176             0.000                                      ohe_city_11
#     177             0.000                                      ohe_city_22
#     178             0.000                                      ohe_city_20
#     179             0.000                                       ohe_city_8
#     180             0.000                                      ohe_city_17
#     181             0.000                                       ohe_city_7
#     182             0.000                                       ohe_city_6
#     183             0.000                                      ohe_city_18
#     184             0.000                                      ohe_city_15
#     185             0.000                                      ohe_city_19
#     186             0.000                  ALL(transactions.is_auto_renew)
#
#     [187 rows x 2 columns],
#     array([0.0000e+00, 5.8185e-04, 6.6498e-04, ..., 1.0000e+00, 1.0000e+00,
#            1.0000e+00]),
#     array([0.    , 0.    , 0.    , ..., 0.9994, 0.9996, 1.    ]),
#     0.9509169928321148,
#     array([0.0946, 0.0946, 0.0946, ..., 1.    , 1.    , 1.    ]),
#     array([1.0000e+00, 9.9996e-01, 9.9996e-01, ..., 6.2342e-04, 5.8185e-04,
#            0.0000e+00]),
#     0.7517161098207243))],
#  [('Exp 4.1 - AutoSklearnClassifier :: RUS 1:1',
#    ('ASKLEARN_15_askbasic_Nonecv_recall',
#     'AutoSklearnClassifier',
#     'RUS 1:1',
#     None,
#     array([0.    , 0.    , 0.0011, ..., 1.    , 1.    , 1.    ]),
#     array([0.0000e+00, 4.2840e-06, 4.2840e-06, ..., 9.9879e-01, 9.9928e-01,
#            1.0000e+00]),
#     0.8977263371214532,
#     array([0.0934, 0.0935, 0.0935, ..., 0.5   , 0.    , 1.    ]),
#     array([1.0000e+00, 9.9996e-01, 9.9996e-01, ..., 4.1561e-05, 0.0000e+00,
#            0.0000e+00]),
#     0.6448521457315657))],
#  [('Exp 4.2 - AutoSklearnClassifier :: RUS 1:1',
#    ('ASKLEARN_50_askbasic_Nonecv_recall',
#     'AutoSklearnClassifier',
#     'RUS 1:1',
#     None,
#     array([0.0000e+00, 4.1561e-05, 1.3715e-03, ..., 1.0000e+00, 1.0000e+00,
#            1.0000e+00]),
#     array([0., 0., 0., ..., 1., 1., 1.]),
#     0.8834615828268544,
#     array([0.0935, 0.0935, 0.0935, ..., 1.    , 1.    , 1.    ]),
#     array([1.0000e+00, 9.9996e-01, 9.9996e-01, ..., 8.3122e-05, 4.1561e-05,
#            0.0000e+00]),
#     0.5833991049008814))],
#  [('Exp 4.3 - AutoSklearnClassifier :: RUS 1:1',
#    ('ASKLEARN_55_askbasic_Nonecv_recall',
#     'AutoSklearnClassifier',
#     'RUS 1:1',
#     None,
#     array([0.0000e+00, 4.1561e-05, 1.2468e-04, ..., 1.0000e+00, 1.0000e+00,
#            1.0000e+00]),
#     array([0.    , 0.    , 0.    , ..., 0.9999, 0.9999, 1.    ]),
#     0.9542834556837584,
#     array([0.094, 0.094, 0.094, ..., 1.   , 1.   , 1.   ]),
#     array([1.0000e+00, 9.9996e-01, 9.9996e-01, ..., 8.3122e-05, 4.1561e-05,
#            0.0000e+00]),
#     0.7688024953011958))]]

# %%
print("Getting best results by classifier based on {} / ordered ascending? {}".format(measure_by, measure_by_sort))

temp_metrics = temp = top_metrics.sort_values(measure_by, ascending=measure_by_sort).copy()

plot_results = temp_metrics.sort_values(measure_by, ascending=measure_by_sort)

plot_data = prepare_plot_data(top_results)

plot_roc_prc(plot_data, ' ')
# Out:
# Getting best results by classifier based on ['balanced_accuracy', 'recall', 'model_churn_cost'] / ordered ascending? [False, False, True]

# %%
top_metrics
# Out:
#                                 label              classifier sampling_method  \
# 0                XGB_basic_5cv_recall           XGBClassifier         ROS 1:1
# 0                  RF_grid_5cv_recall  RandomForestClassifier         ROS 2:1
# 0                RF_random_5cv_recall  RandomForestClassifier         ROS 2:1
# 0             XGB_dfsbasic_5cv_recall           XGBClassifier         ROS 1:1
# 0             RF_dfsrandom_5cv_recall  RandomForestClassifier         RUS 1:1
# 0  ASKLEARN_15_askbasic_Nonecv_recall   AutoSklearnClassifier         RUS 1:1
# 0  ASKLEARN_50_askbasic_Nonecv_recall   AutoSklearnClassifier         RUS 1:1
# 0  ASKLEARN_55_askbasic_Nonecv_recall   AutoSklearnClassifier         RUS 1:1
#
#        tn    fn     tp     fp  accuracy  precision  recall  ...  cv_time  \
# 0  204794  6209  17852  28632     0.865      0.384   0.742  ...    0.691
# 0  204030  6283  17778  29396     0.861      0.377   0.739  ...    0.902
# 0  199480  5681  18380  33946     0.846      0.351   0.764  ...    0.704
# 0  217765  5172  18889  15661     0.919      0.547   0.785  ...    2.677
# 0  216325  4447  19614  17101     0.916      0.534   0.815  ...    2.634
# 0  198852  4833  19228  34574     0.847      0.357   0.799  ...    0.000
# 0  190881  4757  19304  42545     0.816      0.312   0.802  ...    0.000
# 0  216861  4071  19990  16565     0.920      0.547   0.831  ...    0.000
#
#    aucroc  auprc  balanced_accuracy  cv_score_mean  cv_score_std  \
# 0   0.881  0.624              0.810          0.389         0.005
# 0   0.887  0.605              0.806          0.707         0.003
# 0   0.886  0.600              0.809          0.740         0.010
# 0   0.946  0.748              0.859          0.647         0.039
# 0   0.951  0.752              0.871          0.854         0.014
# 0   0.898  0.645              0.826             -1            -1
# 0   0.883  0.583              0.810             -1            -1
# 0   0.954  0.769              0.880             -1            -1
#
#    model_churn_cost  sample  exp_key time_budget
# 0            224834       0  Exp 1.1       2.677
# 0            227908       0  Exp 2.1     100.315
# 0            234120       0  Exp 2.2      40.997
# 0            175189       0  Exp 3.1      11.267
# 0            170955       0  Exp 3.2       9.356
# 0            226104       0  Exp 4.1          15
# 0            248339       0  Exp 4.2          50
# 0            165039       0  Exp 4.3          55
#
# [8 rows x 24 columns]

# %%
top_results
# Out:
#                                 label              classifier sampling_method  \
# 0  ASKLEARN_55_askbasic_Nonecv_recall   AutoSklearnClassifier         RUS 1:1
# 0             RF_dfsrandom_5cv_recall  RandomForestClassifier         RUS 1:1
# 0             XGB_dfsbasic_5cv_recall           XGBClassifier         ROS 1:1
# 0  ASKLEARN_15_askbasic_Nonecv_recall   AutoSklearnClassifier         RUS 1:1
# 0  ASKLEARN_50_askbasic_Nonecv_recall   AutoSklearnClassifier         RUS 1:1
# 0                XGB_basic_5cv_recall           XGBClassifier         ROS 1:1
# 0                RF_random_5cv_recall  RandomForestClassifier         ROS 2:1
# 0                  RF_grid_5cv_recall  RandomForestClassifier         ROS 2:1
#
#        tn    fn     tp     fp  accuracy  precision  recall  ...  cv_time  \
# 0  216861  4071  19990  16565     0.920      0.547   0.831  ...    0.000
# 0  216325  4447  19614  17101     0.916      0.534   0.815  ...    2.634
# 0  217765  5172  18889  15661     0.919      0.547   0.785  ...    2.677
# 0  198852  4833  19228  34574     0.847      0.357   0.799  ...    0.000
# 0  190881  4757  19304  42545     0.816      0.312   0.802  ...    0.000
# 0  204794  6209  17852  28632     0.865      0.384   0.742  ...    0.691
# 0  199480  5681  18380  33946     0.846      0.351   0.764  ...    0.704
# 0  204030  6283  17778  29396     0.861      0.377   0.739  ...    0.902
#
#    aucroc  auprc  balanced_accuracy  cv_score_mean  cv_score_std  \
# 0   0.954  0.769              0.880             -1            -1
# 0   0.951  0.752              0.871          0.854         0.014
# 0   0.946  0.748              0.859          0.647         0.039
# 0   0.898  0.645              0.826             -1            -1
# 0   0.883  0.583              0.810             -1            -1
# 0   0.881  0.624              0.810          0.389         0.005
# 0   0.886  0.600              0.809          0.740         0.010
# 0   0.887  0.605              0.806          0.707         0.003
#
#    model_churn_cost  sample  exp_key time_budget
# 0            165039       0  Exp 4.3          55
# 0            170955       0  Exp 3.2       9.356
# 0            175189       0  Exp 3.1      11.267
# 0            226104       0  Exp 4.1          15
# 0            248339       0  Exp 4.2          50
# 0            224834       0  Exp 1.1       2.677
# 0            234120       0  Exp 2.2      40.997
# 0            227908       0  Exp 2.1     100.315
#
# [8 rows x 24 columns]

# %% [markdown]
# ### Choosing the best model and appending to overall ....

# %%
top_models

# %%
top_results

# %%
top_models

# %%
from scipy import stats
import scikit_posthocs as sp

xgb = plot_data[0][-2]
rf = plot_data[1][-2]
dt = plot_data[2][-2]
gnb = plot_data[3][-2]
lr = plot_data[4][-2]
mlp = plot_data[5][-2]

data = [xgb, rf, dt, gnb, lr, mlp]

stats.kruskal(*data)

# %%
sp.posthoc_conover(data)

# %%
#all_metrics[all_metrics.recall < 1.0].sort_values(['recall'], ascending=[False])

# %%
#all_metrics.sort_values(['recall','precision'], ascending=[False, False])

# %%
print(top_results.to_latex(index=False)) # doctest: +NORMALIZE_WHITESPACE

# %%
import scipy.stats as ss
import statsmodels.api as sa
import scikit_posthocs as sp
import statsmodels.formula.api as sfa

df = sa.datasets.get_rdataset('iris').data
data = [df.loc[ids, 'Sepal.Width'].values for ids in df.groupby('Species').groups.values()]

# %%
H, p = ss.kruskal(*data)
print(H, p)

# %%
sp.posthoc_conover(df, val_col='Sepal.Width', group_col='Species', p_adjust = 'holm')

# %%
df.columns = ['Sepal_Length', 'Sepal_Width', 'Petal_Length', 'Petal_Width', 'Species']

# %%
lm = sfa.ols('Sepal_Width ~ C(Species)', data=df).fit()
anova = sa.stats.anova_lm(lm)
print(anova)

# %%
sp.posthoc_ttest(df, val_col='Sepal_Width', group_col='Species', p_adjust='holm')
