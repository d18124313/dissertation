# %%
## @see https://www.kaggle.com/toorkp/churn-wsdm/data

# %%
# %load_ext autoreload
# %autoreload

# %%
import numpy as np
import pandas as pd
import time
import gc; gc.enable()
import time
import sys

from sklearn import model_selection
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_curve, auc, confusion_matrix, f1_score, log_loss, confusion_matrix

from collections import Counter
from numpy.random import RandomState
from imblearn.over_sampling import SMOTENC
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

pd.options.display.float_format = "{:.2f}".format
np.set_printoptions(precision=4)

import matplotlib.pyplot as plt
# %matplotlib inline

sys.path.append('modules')

from shared_functions import *
import pickle
from datetime import datetime
# Out:
# /home/anaconda/envs/py373/lib/python3.7/site-packages/pyparsing.py:2927: FutureWarning: Possible set intersection at position 3
#   self.re = re.compile( self.reString )
# /home/anaconda/envs/py373/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
# Load the pre-split data

store = pd.HDFStore('/home/dissertation/data/base_abt_split.h5')
X_train, X_test, y_train, y_test = store['X_train'], store['X_test'], store['y_train'], store['y_test']
store.close()

# Drop msno from the dataset
X_train.drop(['msno', 'registration_init_time', 'registration_init_time_dt'], inplace=True, axis=1)
X_test.drop(['msno', 'registration_init_time', 'registration_init_time_dt'], inplace=True, axis=1)

print("Train Shape:", X_train.shape, y_train.shape)
print("Train Shape:", X_test.shape, y_test.shape)
X_train.head()
# Out:
# Train Shape: (600803, 13) (600803,)
# Train Shape: (257487, 13) (257487,)
#        city  bd registered_via  total_order  payment_method_id_mode  \
# 703741    4  32              3           22                      33
# 228194   13  33              3           19                      39
# 735733   15  22              3           17                      40
# 774256    1   0              7           26                      41
# 282188    1   0              7           27                      41
#
#         payment_method_id_count  payment_plan_days_mode  \
# 703741                        1                      30
# 228194                        1                      30
# 735733                        3                      30
# 774256                        1                      30
# 282188                        1                      30
#
#         payment_plan_days_mean  plan_list_price_mean  plan_lifetime_value  \
# 703741                   21.82                108.36              2384.00
# 228194                   28.58                141.16              2682.00
# 735733                   30.00                158.12              2688.00
# 774256                   28.85                143.27              3725.00
# 282188                   28.89                132.00              3564.00
#
#         is_auto_renew_mode  transaction_date_max  cancel_times
# 703741                True              20170228             0
# 228194                True              20170131             0
# 735733                True              20170210             4
# 774256                True              20170205             0
# 282188                True              20170216             1

# %%
RANDOM_STATE = 42 
CV_ITER = None
SCORING_METRIC = autosklearn.metrics.recall
BASE_NAME = "askbasic_" + str(CV_ITER) + "cv_" + str(SCORING_METRIC)
N_JOBS = 4
## Time periods to train for in minutes
# TIME_PERIODS = [0.25, 0.5, 1, 2, 3, 4]
TIME_PERIODS = [10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60]

## Set the list of the categorical columns in the dataset
cat_col = ['city', 'registered_via', 'payment_method_id_mode']

df_cols = X_train.columns
feat_types =  ['Categorical' if col in cat_col else 'Numerical' for col in df_cols]

classifiers = []

## Each entry in the list is a Tuple of
##   [ModelName, Model, HyperParams, ScoringMetric]    
for period in TIME_PERIODS:
    classifiers.append(
        ('ASKLEARN_{}_'.format(str(period)) + BASE_NAME,                        ## ModelName
         autosklearn.classification.AutoSklearnClassifier(                      ## Model  
                time_left_for_this_task=int(60*period), 
                n_jobs=N_JOBS,
                include_estimators=["random_forest", "decision_tree", "adaboost", "gaussian_nb",
                                    "liblinear_svc", "xgradient_boosting"], 
                exclude_estimators=None,
                include_preprocessors=["no_preprocessing", ], 
                exclude_preprocessors=None,
                ml_memory_limit = 3072*9,
                initial_configurations_via_metalearning = 0), 
         {},                                                                    ## HyperParams
         SCORING_METRIC)                                                        ## ScoringMetric 
    )

# %%
all_metrics = pd.DataFrame()
all_results = list()

# %%
# with open('/tmp/asklearn_all_metrics.pickle', 'rb') as f:
#     # The protocol version used is detected automatically, so we do not
#     # have to specify it.
#     all_metrics = pickle.load(f)

# with open('/tmp/asklearn_all_results.pickle', 'rb') as f:
#     # The protocol version used is detected automatically, so we do not
#     # have to specify it.
#     all_results = pickle.load(f)

# %%
# # Write (overwrite) the file to store the experiment results
# with open('/tmp/asklearn_all_metrics.pickle', 'wb') as f:
#     # Pickle the 'data' dictionary using the highest protocol available.
#     print("Writing results to", f.name)
#     pickle.dump(all_metrics, f, pickle.HIGHEST_PROTOCOL)
    
# # Write (overwrite) the file to store the experiment results
# with open('/tmp/asklearn_all_results.pickle', 'wb') as f:
#     # Pickle the 'data' dictionary using the highest protocol available.
#     print("Writing results to", f.name)
#     pickle.dump(all_results, f, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### Experiment 1.1 Baseline - Default Settings - No sampling

# %%
# %%time
start = time.time()

sampler = ('None', DummySampler())

exp_metrics, model_results = perform_experiment(X_train, X_test, y_train, y_test, classifiers, sampler, 1, \
                                                cv_iter=CV_ITER, cat_col=cat_col, auto_ml = False)

all_metrics = all_metrics.append(exp_metrics)
all_results.append((sampler[0]+"_"+BASE_NAME, exp_metrics, model_results))

log("basic, autosklearn, {0}, {1}".format(sampler[0], time.time()-start), 'Basic_Autosklearn.log')

# %%
all_metrics[['sampling_method']].drop_duplicates()
# Out:
#   sampling_method
# 0         ROS 1:1
# 0            None
# 0         RUS 1:1
# 0         ROS 3:1
# 0        SMOTE_NC
# 0         ROS 2:1
# 0         ROS 3:2

# %%
all_metrics[['label','sampling_method']].groupby(['sampling_method']).count()

# %%
all_metrics
# Out:
#                                  label             classifier sampling_method  \
# 0   ASKLEARN_10_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 1:1
# 0   ASKLEARN_15_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 1:1
# 0   ASKLEARN_20_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 1:1
# 0   ASKLEARN_25_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 1:1
# 0   ASKLEARN_30_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 1:1
# 0   ASKLEARN_35_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 1:1
# 0   ASKLEARN_40_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 1:1
# 0   ASKLEARN_45_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 1:1
# 0   ASKLEARN_50_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 1:1
# 0   ASKLEARN_55_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 1:1
# 0   ASKLEARN_60_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 1:1
# 0   ASKLEARN_10_askbasic_Nonecv_recall  AutoSklearnClassifier            None
# 0   ASKLEARN_15_askbasic_Nonecv_recall  AutoSklearnClassifier            None
# 0   ASKLEARN_20_askbasic_Nonecv_recall  AutoSklearnClassifier            None
# 0   ASKLEARN_25_askbasic_Nonecv_recall  AutoSklearnClassifier            None
# 0   ASKLEARN_30_askbasic_Nonecv_recall  AutoSklearnClassifier            None
# 0   ASKLEARN_35_askbasic_Nonecv_recall  AutoSklearnClassifier            None
# 0   ASKLEARN_40_askbasic_Nonecv_recall  AutoSklearnClassifier            None
# 0   ASKLEARN_45_askbasic_Nonecv_recall  AutoSklearnClassifier            None
# 0   ASKLEARN_50_askbasic_Nonecv_recall  AutoSklearnClassifier            None
# 0   ASKLEARN_55_askbasic_Nonecv_recall  AutoSklearnClassifier            None
# 0   ASKLEARN_60_askbasic_Nonecv_recall  AutoSklearnClassifier            None
# 0   ASKLEARN_10_askbasic_Nonecv_recall  AutoSklearnClassifier         RUS 1:1
# 0   ASKLEARN_15_askbasic_Nonecv_recall  AutoSklearnClassifier         RUS 1:1
# 0   ASKLEARN_20_askbasic_Nonecv_recall  AutoSklearnClassifier         RUS 1:1
# 0   ASKLEARN_25_askbasic_Nonecv_recall  AutoSklearnClassifier         RUS 1:1
# 0   ASKLEARN_30_askbasic_Nonecv_recall  AutoSklearnClassifier         RUS 1:1
# 0   ASKLEARN_35_askbasic_Nonecv_recall  AutoSklearnClassifier         RUS 1:1
# 0   ASKLEARN_40_askbasic_Nonecv_recall  AutoSklearnClassifier         RUS 1:1
# 0   ASKLEARN_45_askbasic_Nonecv_recall  AutoSklearnClassifier         RUS 1:1
# ..                                 ...                    ...             ...
# 0   ASKLEARN_25_askbasic_Nonecv_recall  AutoSklearnClassifier        SMOTE_NC
# 0   ASKLEARN_30_askbasic_Nonecv_recall  AutoSklearnClassifier        SMOTE_NC
# 0   ASKLEARN_35_askbasic_Nonecv_recall  AutoSklearnClassifier        SMOTE_NC
# 0   ASKLEARN_40_askbasic_Nonecv_recall  AutoSklearnClassifier        SMOTE_NC
# 0   ASKLEARN_45_askbasic_Nonecv_recall  AutoSklearnClassifier        SMOTE_NC
# 0   ASKLEARN_50_askbasic_Nonecv_recall  AutoSklearnClassifier        SMOTE_NC
# 0   ASKLEARN_55_askbasic_Nonecv_recall  AutoSklearnClassifier        SMOTE_NC
# 0   ASKLEARN_60_askbasic_Nonecv_recall  AutoSklearnClassifier        SMOTE_NC
# 0   ASKLEARN_10_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 2:1
# 0   ASKLEARN_15_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 2:1
# 0   ASKLEARN_20_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 2:1
# 0   ASKLEARN_25_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 2:1
# 0   ASKLEARN_30_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 2:1
# 0   ASKLEARN_35_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 2:1
# 0   ASKLEARN_40_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 2:1
# 0   ASKLEARN_45_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 2:1
# 0   ASKLEARN_50_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 2:1
# 0   ASKLEARN_55_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 2:1
# 0   ASKLEARN_60_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 2:1
# 0   ASKLEARN_10_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 3:2
# 0   ASKLEARN_15_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 3:2
# 0   ASKLEARN_20_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 3:2
# 0   ASKLEARN_25_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 3:2
# 0   ASKLEARN_30_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 3:2
# 0   ASKLEARN_35_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 3:2
# 0   ASKLEARN_40_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 3:2
# 0   ASKLEARN_45_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 3:2
# 0   ASKLEARN_50_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 3:2
# 0   ASKLEARN_55_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 3:2
# 0   ASKLEARN_60_askbasic_Nonecv_recall  AutoSklearnClassifier         ROS 3:2
#
#         tn     fn     tp     fp  accuracy  precision  recall  ...  log_loss  \
# 0   209239   8023  16038  24187      0.87       0.40    0.67  ...      4.32
# 0   203971   7320  16741  29455      0.86       0.36    0.70  ...      4.93
# 0   209201   7351  16710  24225      0.88       0.41    0.69  ...      4.24
# 0   209201   7351  16710  24225      0.88       0.41    0.69  ...      4.24
# 0   212013   9157  14904  21413      0.88       0.41    0.62  ...      4.10
# 0   203685   6984  17077  29741      0.86       0.36    0.71  ...      4.93
# 0   211860   9145  14916  21566      0.88       0.41    0.62  ...      4.12
# 0   212707   9203  14858  20719      0.88       0.42    0.62  ...      4.01
# 0   204715   7093  16968  28711      0.86       0.37    0.71  ...      4.80
# 0   202032   6439  17622  31394      0.85       0.36    0.73  ...      5.07
# 0      2123.00     0.00    0.87   0.57               0.72             -1
# 0      2422.88     0.00    0.87   0.58               0.74             -1
# 0      2725.54     0.00    0.87   0.57               0.72             -1
# 0      3023.19     0.00    0.87   0.58               0.73             -1
# 0      3326.25     0.00    0.87   0.60               0.74             -1
# 0      3622.92     0.00    0.87   0.57               0.72             -1
# 0       629.35     0.00    0.86   0.59               0.76             -1
# 0       927.81     0.00    0.87   0.57               0.74             -1
# 0      1226.83     0.00    0.87   0.61               0.75             -1
# 0      1531.54     0.00    0.87   0.60               0.76             -1
# 0      1827.63     0.00    0.87   0.58               0.75             -1
# 0      2122.11     0.00    0.88   0.60               0.77             -1
# 0      2431.55     0.00    0.87   0.60               0.75             -1
# 0      2720.43     0.00    0.89   0.62               0.81             -1
# 0      3019.25     0.00    0.89   0.62               0.80             -1
# 0      3330.50     0.00    0.87   0.59               0.76             -1
# 0      3625.76     0.00    0.87   0.61               0.75             -1
#
#     cv_score_std model_churn_cost sample
# 0             -1          8034000      0
# 0             -1          8279600      0
# 0             -1          7769000      0
# 0             -1          7769000      0
# 0             -1          8210200      0
# 0             -1          8173800      0
# 0             -1          8220700      0
# 0             -1          8159200      0
# 0             -1          8114400      0
# 0             -1          8121100      0
# 0             -1          8055600      0
# 0             -1          8440200      0
# 0             -1          8318800      0
# 0             -1          8421000      0
# 0             -1          8326900      0
# 0             -1          8300900      0
# 0             -1          8234800      0
# 0             -1          8383800      0
# 0             -1          8275600      0
# 0             -1          8358100      0
# 0             -1          8390700      0
# 0             -1          8358100      0
# 0             -1          7813500      0
# 0             -1          7796700      0
# 0             -1          7800200      0
# 0             -1          7821400      0
# 0             -1          7831800      0
# 0             -1          7844100      0
# 0             -1          7807400      0
# 0             -1          7769100      0
# ..           ...              ...    ...
# 0             -1          7732000      0
# 0             -1          7810800      0
# 0             -1          7936700      0
# 0             -1          7773500      0
# 0             -1          7798800      0
# 0             -1          7818300      0
# 0             -1          7842600      0
# 0             -1          8225100      0
# 0             -1          8453000      0
# 0             -1          8276300      0
# 0             -1          8018700      0
# 0             -1          8134600      0
# 0             -1          8007200      0
# 0             -1          8132100      0
# 0             -1          7954700      0
# 0             -1          8132100      0
# 0             -1          8013800      0
# 0             -1          7840400      0
# 0             -1          8133200      0
# 0             -1          7756300      0
# 0             -1          7893400      0
# 0             -1          7801300      0
# 0             -1          7789600      0
# 0             -1          7860800      0
# 0             -1          7977900      0
# 0             -1          7809300      0
# 0             -1          7561300      0
# 0             -1          7522500      0
# 0             -1          7777900      0
# 0             -1          7795800      0
#
# [77 rows x 22 columns]

# %% [markdown]
# ### Experiment 1.2 Baseline - Default Settings - Oversampled training set 100%

# %%
# %%time
start = time.time()

sampler = ('ROS 1:1', RandomOverSampler(random_state=RANDOM_STATE))

exp_metrics, model_results = perform_experiment(X_train, X_test, y_train, y_test, classifiers, sampler, 1, \
                                                cv_iter=CV_ITER, cat_col=cat_col, auto_ml = False)

all_metrics = all_metrics.append(exp_metrics)
all_results.append((sampler[0]+"_"+BASE_NAME, exp_metrics, model_results))

log("basic, autosklearn, {0}, {1}".format(sampler[0], time.time()-start), 'Basic_Autosklearn.log')

# %%
all_metrics

# %% [markdown]
# ### Experiment 1.3 Baseline - Default Settings - Undersampled training set

# %%
# %%time
start = time.time()

sampler = ('RUS 1:1', RandomUnderSampler(random_state=RANDOM_STATE))

exp_metrics, model_results = perform_experiment(X_train, X_test, y_train, y_test, classifiers, sampler, 1, \
                                                cv_iter=CV_ITER, cat_col=cat_col, auto_ml = False)

all_metrics = all_metrics.append(exp_metrics)
all_results.append((sampler[0]+"_"+BASE_NAME, exp_metrics, model_results))

log("basic, autosklearn, {0}, {1}".format(sampler[0], time.time()-start), 'Basic_Autosklearn.log')

# %%
# sys.getsizeof(model)
# model = all_results[0][2][0][-1]
# print(model.sprint_statistics())
# print(model.show_models())

# %% [markdown]
# ### Experiment 1.4 Baseline - Default Settings - Over sampling - 33% of majority size

# %%
# %%time
start = time.time()

sampler = ('ROS 3:1', RandomOverSampler(random_state=RANDOM_STATE, sampling_strategy = 1/3))

exp_metrics, model_results = perform_experiment(X_train, X_test, y_train, y_test, classifiers, sampler, 1, \
                                                cv_iter=CV_ITER, cat_col=cat_col, auto_ml = False)

all_metrics = all_metrics.append(exp_metrics)
all_results.append((sampler[0]+"_"+BASE_NAME, exp_metrics, model_results))

log("basic, autosklearn, {0}, {1}".format(sampler[0], time.time()-start), 'Basic_Autosklearn.log')

# %%
all_metrics.sampling_method.value_counts()

# %% [markdown]
# ### Experiment 1.5 Baseline - Default Settings - Over sampling - 66% of majority size

# %%
# %%time
start = time.time()

sampler = ('ROS 3:2', RandomOverSampler(random_state=RANDOM_STATE, sampling_strategy = 2/3))

exp_metrics, model_results = perform_experiment(X_train, X_test, y_train, y_test, classifiers, sampler, 1, \
                                                cv_iter=CV_ITER, cat_col=cat_col, auto_ml = False)

all_metrics = all_metrics.append(exp_metrics)
all_results.append((sampler[0]+"_"+BASE_NAME, exp_metrics, model_results))

log("basic, autosklearn, {0}, {1}".format(sampler[0], time.time()-start), 'Basic_Autosklearn.log')
# Out:
# Model Build Iteration 0
# PRE-SAMPLING: (600803, 13) (600803,) Counter({0: 544661, 1: 56142})
# POST-SAMPLING: (907768, 13) (907768,) Counter({0: 544661, 1: 363107})
# Set the train df types correctly based on the test set
# Applying normalisation to train and test sets
# Categorical columns in dataset ['city', 'registered_via', 'payment_method_id_mode']
# Categorical columns in dataset ['city', 'registered_via', 'payment_method_id_mode']
# X_train:  (907768, 68) (907768, 1)
# X_test:  (257487, 68) (257487, 1)
# Training ASKLEARN_10_askbasic_Nonecv_recall classifier
# No params set, using Standard training
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# [WARNING] [2019-08-13 09:23:42,232:EnsembleBuilder(1791095845):5041361ce42d9f58f067ec0b48e073ff] No models better than random - using Dummy Score!
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# [WARNING] [2019-08-13 09:23:42,367:EnsembleBuilder(1791095845):5041361ce42d9f58f067ec0b48e073ff] No models better than random - using Dummy Score!
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# [WARNING] [2019-08-13 09:23:44,411:EnsembleBuilder(1791095845):5041361ce42d9f58f067ec0b48e073ff] No models better than random - using Dummy Score!
# [WARNING] [2019-08-13 09:23:46,418:EnsembleBuilder(1791095845):5041361ce42d9f58f067ec0b48e073ff] No models better than random - using Dummy Score!
# [WARNING] [2019-08-13 09:23:48,425:EnsembleBuilder(1791095845):5041361ce42d9f58f067ec0b48e073ff] No models better than random - using Dummy Score!
# [WARNING] [2019-08-13 09:23:50,431:EnsembleBuilder(1791095845):5041361ce42d9f58f067ec0b48e073ff] No models better than random - using Dummy Score!
# [WARNING] [2019-08-13 09:23:52,443:EnsembleBuilder(1791095845):5041361ce42d9f58f067ec0b48e073ff] No models better than random - using Dummy Score!
# [WARNING] [2019-08-13 09:23:54,495:EnsembleBuilder(1791095845):5041361ce42d9f58f067ec0b48e073ff] No models better than random - using Dummy Score!
# [WARNING] [2019-08-13 09:23:56,520:EnsembleBuilder(1791095845):5041361ce42d9f58f067ec0b48e073ff] No models better than random - using Dummy Score!
# [WARNING] [2019-08-13 09:23:58,527:EnsembleBuilder(1791095845):5041361ce42d9f58f067ec0b48e073ff] No models better than random - using Dummy Score!
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# [WARNING] [2019-08-13 09:31:35,772:EnsembleBuilder(1791095845):5041361ce42d9f58f067ec0b48e073ff] Memory Exception -- restart with less ensemle_nbest: 25
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# -1
# ['/tmp/autosklearn_tmp_3976_9297/.auto-sklearn/ensembles/1791095845.0000000000.ensemble', '/tmp/autosklearn_tmp_3976_9297/.auto-sklearn/ensembles/1791095845.0000000001.ensemble', '/tmp/autosklearn_tmp_3976_9297/.auto-sklearn/ensembles/1791095845.0000000002.ensemble', '/tmp/autosklearn_tmp_3976_9297/.auto-sklearn/ensembles/1791095845.0000000003.ensemble', '/tmp/autosklearn_tmp_3976_9297/.auto-sklearn/ensembles/1791095845.0000000004.ensemble', '/tmp/autosklearn_tmp_3976_9297/.auto-sklearn/ensembles/1791095845.0000000005.ensemble', '/tmp/autosklearn_tmp_3976_9297/.auto-sklearn/ensembles/1791095845.0000000006.ensemble', '/tmp/autosklearn_tmp_3976_9297/.auto-sklearn/ensembles/1791095845.0000000007.ensemble', '/tmp/autosklearn_tmp_3976_9297/.auto-sklearn/ensembles/1791095845.0000000008.ensemble', '/tmp/autosklearn_tmp_3976_9297/.auto-sklearn/ensembles/1791095845.0000000009.ensemble']
# Generating test scores for ASKLEARN_10_askbasic_Nonecv_recall classifier
# Training ASKLEARN_15_askbasic_Nonecv_recall classifier
# No params set, using Standard training
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# [WARNING] [2019-08-13 09:34:13,978:EnsembleBuilder(1791095845):5041361ce42d9f58f067ec0b48e073ff] No models better than random - using Dummy Score!
# [WARNING] [2019-08-13 09:34:14,026:EnsembleBuilder(1791095845):5041361ce42d9f58f067ec0b48e073ff] No models better than random - using Dummy Score!
# [WARNING] [2019-08-13 09:34:16,033:EnsembleBuilder(1791095845):5041361ce42d9f58f067ec0b48e073ff] No models better than random - using Dummy Score!
# [WARNING] [2019-08-13 09:34:18,045:EnsembleBuilder(1791095845):5041361ce42d9f58f067ec0b48e073ff] No models better than random - using Dummy Score!
# [WARNING] [2019-08-13 09:34:20,053:EnsembleBuilder(1791095845):5041361ce42d9f58f067ec0b48e073ff] No models better than random - using Dummy Score!
# [WARNING] [2019-08-13 09:34:22,080:EnsembleBuilder(1791095845):5041361ce42d9f58f067ec0b48e073ff] No models better than random - using Dummy Score!
# [WARNING] [2019-08-13 09:34:24,109:EnsembleBuilder(1791095845):5041361ce42d9f58f067ec0b48e073ff] No models better than random - using Dummy Score!
# [WARNING] [2019-08-13 09:34:26,116:EnsembleBuilder(1791095845):5041361ce42d9f58f067ec0b48e073ff] No models better than random - using Dummy Score!
# [WARNING] [2019-08-13 09:34:28,124:EnsembleBuilder(1791095845):5041361ce42d9f58f067ec0b48e073ff] No models better than random - using Dummy Score!
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/anaconda/envs/py373/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)

# %% [markdown]
# ### Experiment 1.6 Baseline - Default Settings - Over sampling - 50% of majority size

# %%
# %%time
start = time.time()

## 20190812 REMOVED :  random_state=RANDOM_STATE, 
sampler = ('ROS 2:1', RandomOverSampler(sampling_strategy = 1/2))

exp_metrics, model_results = perform_experiment(X_train, X_test, y_train, y_test, classifiers, sampler, 1, \
                                                cv_iter=CV_ITER, cat_col=cat_col, auto_ml = False)

all_metrics = all_metrics.append(exp_metrics)
all_results.append((sampler[0]+"_"+BASE_NAME, exp_metrics, model_results))

log("basic, autosklearn, {0}, {1}".format(sampler[0], time.time()-start), 'Basic_Autosklearn.log')

# %%
exp_metrics

# %%
"test"

# %% [markdown]
# ### Experiment 1.7 Baseline Default Settings SMOTE-NC

# %%
# %%time
start = time.time()
X_train
sampler = ('SMOTE_NC', SMOTENC(random_state=RANDOM_STATE, categorical_features=[0,1,2,4,6,10,12], n_jobs=8))

## Keep the following, essentially dropping the dt columns
cols = ['is_churn', 'city', 'bd', 'registered_via', 'total_order',
       'payment_method_id_mode', 'payment_method_id_count',
       'payment_plan_days_mode', 'payment_plan_days_mean',
       'plan_list_price_mean', 'plan_lifetime_value', 'actual_amount_mean',
       'total_actual_amount', 'is_auto_renew_mode', 'cancel_times']

exp_metrics, model_results = perform_experiment(X_train, X_test, y_train, y_test, classifiers, sampler, 1, \
                                                cv_iter=CV_ITER, cat_col=cat_col, auto_ml = True)

all_metrics = all_metrics.append(exp_metrics)
all_results.append((sampler[0]+"_"+BASE_NAME, exp_metrics, model_results))

log("basic, autosklearn, {0}, {1}".format(sampler[0], time.time()-start), 'Basic_Autosklearn.log')

# %%
all_metrics

# %%
all_metrics.sort_values('recall', ascending=False).head(15)

# %%
#store(all_results, 'Asklearn_Default_Undersample.pickle')

# Write (overwrite) the file to store the experiment results
with open('Basic_Asklearn_20190813.pickle', 'wb') as f:
    # Pickle the 'data' dictionary using the highest protocol available.
    print("Writing results to", f.name)
    pickle.dump(all_results, f, pickle.HIGHEST_PROTOCOL)
# Out:
# Writing results to Basic_Asklearn_20190813.pickle

# %%
## Just try an SVM 
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier

# %%
# %%time
model_train_results = train_model(base_dataset, sampling_method = 'under', classifiers = [('SGDClassifier', SGDClassifier(loss='log'))])

# %%
## Print the feature importance 

feature_index = np.flip(np.argsort(model.feature_importances_), axis=0)
ordered_features = []
column_names = X_test.columns

for i in feature_index[0:10]:
    print(np.round(model.feature_importances_[i], 3), ' --> ', column_names[i])
    ordered_features.append(column_names[i])

# %%
## Print the permutation importance 

import eli5
from eli5.sklearn import PermutationImportance

_, X_test, _, y_test = prepare_train_test_split(model_dataset, 0)

perm = PermutationImportance(model, random_state=1).fit(X_test, y_test)

eli5.show_weights(perm, feature_names = X_test.columns.tolist())

# %%
#model_name, model = model_train_results[1][2]

for model_name, model in model_train_results[1]:
    probs = model.predict_proba(X_test)[:, 1]
    pr_data = plot_precision_recall(
        y_test, probs, title='PR Curve for {0}'.format(model_name))

# %%
probs = model.predict_proba(X_test)[:, 1]
pr_data = plot_precision_recall(
    y_test, probs, title='PR Curve for {0}'.format(model_name))

# %%
pr_data = plot_roc(
    y_test, probs, title='ROC Curve for {0}'.format(model_name))

# %%
print(plt.style.available)

# %%
model_dataset.head()

# %%
print("Original Data distribution")
print(model_dataset['is_churn'].value_counts())

# %%
# Display new class counts
print('Sci-Kit Learn : resample : Down Sampled data set')
train_downsample = undersampled_dataset(model_dataset, 'is_churn')

print(train_downsample['is_churn'].value_counts())
print("Num records = ", train_downsample.shape[0])
train_downsample.is_churn.value_counts().plot(kind='bar', title='Count (target)')

# %%
# Display new class counts
print('Sci-Kit Learn : resample : Up Sampled data set')
train_upsample = oversampled_dataset(model_dataset, 'is_churn')

print(train_upsample['is_churn'].value_counts())
print("Num records = ", train_upsample.shape[0])
train_upsample.is_churn.value_counts().plot(kind='bar', title='Count (target)')

# %%
probs = model.predict_proba(X_test)[:, 1]
pr_data = plot_precision_recall(
    y_test, probs, title='Precision-Recall Curve for Random Forest')

# %%
precision_above = pr_data.loc[pr_data['precision'] >= 0.25].copy()
precision_above.sort_values('recall', ascending=False, inplace=True)
precision_above.head()

# %%
threshold_required = 0.5
# Make predictions where probability is above threshold
preds = np.zeros(len(y_test))
preds[probs >= threshold_required] = 1

# Make and plot confusion matrix
cm = confusion_matrix(y_test, preds)
plot_confusion_matrix(cm, classes=['No Churn', 'Churn'],
                      title='Churn Confusion Matrix')

# %%
model_dataset.head()

# %%
fi = pd.DataFrame({'importance': model.feature_importances_}, index=model_dataset.iloc[:, 1:].columns).\
    sort_values('importance', ascending=False)
fi.head(10)
