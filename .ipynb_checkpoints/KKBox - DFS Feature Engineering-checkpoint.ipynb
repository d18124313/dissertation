# %%
# %load_ext autoreload
# %autoreload

import pandas as pd
import numpy as np

pd.options.display.float_format = "{:.2f}".format
np.set_printoptions(precision=4)

from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
# %matplotlib inline

import featuretools as ft
import featuretools.variable_types as vtypes

# %%
train = pd.read_csv('/home/dissertation/data/train_v2.csv', 
                          dtype = {'msno' : 'category'})

members = pd.read_csv('/home/dissertation/data/members_v3.csv',
                            dtype={'registered_via' : np.uint8,
                                   'gender' : str,
                                   'city' : 'category',
                                   'registered_via' : 'category'})

members['registration_init_time_dt'] = pd.to_datetime(members['registration_init_time'], 
                                                            format='%Y%m%d', errors='ignore')

## Next load in the transactions data
transactions = pd.read_csv('/home/dissertation/data/transactions.csv',
                                 dtype = {'payment_method' : 'category',
                                          'payment_plan_days' : np.uint8,
                                          'plan_list_price' : np.uint8,
                                          'actual_amount_paid': np.uint8,
                                          'is_auto_renew' : np.bool,
                                          'is_cancel' : np.bool})

# Difference between listing price and price paid
transactions['price_difference'] = transactions['plan_list_price'] - transactions['actual_amount_paid']

### IS THIS OK?
transactions.loc[transactions.payment_plan_days == 0, 'payment_plan_days'] = 30

# Planned price per day
transactions['planned_daily_price'] = transactions['plan_list_price'] / transactions['payment_plan_days']

# Actual price per day
transactions['daily_price'] = transactions['actual_amount_paid'] / transactions['payment_plan_days']

# %%
train = train.sample(1000)
len(train)
# Out:
# 1000

# %%
train.head(10)
# Out:
#                                                 msno  is_churn
# 674620  rJePjF6P7DG9iSphHHZ6j7t1vKpFwDcL4QpSpcDhyWw=         0
# 947099  TRFVvmb8ccIcsf+HBDymxX5/A0VFKAaYkdbUxMLV4s4=         0
# 720272  kAOVKqjwrvYTYZDx25aV25omU+ojmIy+XFlLtDxgtP4=         0
# 709280  MOq8xsXOrCmiedQAvzw8mCvZwXVJ2YCkRqvxIEGgpyg=         0
# 167379  1tQGzEn277q6uW4G67HHwuKXgu6OqmBcyrwNb/SioAE=         0
# 736835  zbYpQ96fryGLrWLs4vRUARtmmPwCO9SNmq7sWg+bHro=         0
# 344759  alwU/7yBhfC3EMlhJY5Uj/HwxdPJklCCirJDNgJU+Z4=         0
# 889597  bMQo/IrBeMDLfkaILY+QNEWFKvzeiyQWw13431mdLuM=         0
# 582112  yjm7ElQ5OfaviJTJ+dsgHQcA7Yymae4jf5QiiGGMdvo=         0
# 488803  eKVEBXLNUn32aeHDItZN5PVTSoGitl27cMkvKVa09kQ=         0

# %%
### Before progressing, split the train msno's into train/test

# %%
## Finally generate the train-test splits
X_train, X_test, y_train, y_test = train_test_split(train, 
                                                    train['is_churn'],
                                                    train_size = 0.7, 
                                                    stratify = train['is_churn'],
                                                    random_state = 42)

print(X_train.shape, y_train.shape, np.mean(y_train))
print(X_test.shape, y_test.shape, np.mean(y_test))

train_set = X_train
train_set['is_churn'] = y_train
test_set = X_test
test_set['is_churn'] = y_test
# Out:
# (700, 2) (700,) 0.09857142857142857
# (300, 2) (300,) 0.09666666666666666

# %%
## Set up the training entityset

# %%
train_input = pd.merge(left=train_set, right=members, how='inner', on=['msno'])
train_input.drop(['is_churn'], axis=1, inplace=True)

train_input['gender'] = train_input['gender'].fillna(value='unknown')
train_input.gender.value_counts(normalize=True).plot(kind='bar')

## Set this index so I can re-sort the output of DFS to be in the same order post feature enginering
train_input.reset_index(inplace=True)

train_input.reset_index(drop=True, inplace=True)
print(len(train_input))
train_input.head()
# Out:
# 628
#    index                                          msno city  bd   gender  \
# 0      0  YxW3KnnTxGLb7uqUPEN1aNx3QKrCSkzBvBfhzGNgoUo=    1   0  unknown
# 1      1  Roj4/ACKWkpp4aUosRdSFXSUhupSSlGC7XtrraWUwag=    1   0  unknown
# 2      2  pv2A7bZGN61apcR2mXk1DiozM4xT7Rz3PfQzFplBHCA=    1   0  unknown
# 3      3  vZYZR/0W19Io+rxivh25ri0q8FB7kXY5KvuUbIu4TnI=    1   0  unknown
# 4      4  7U/abxetP1KZI8Ao1LEp0ViiDhZ7TxDib1J4rjFKbTs=    1   0  unknown
#
#   registered_via  registration_init_time registration_init_time_dt
# 0              3                20140711                2014-07-11
# 1              4                20161225                2016-12-25
# 2              7                20110615                2011-06-15
# 3              7                20161115                2016-11-15
# 4              7                20130619                2013-06-19

# %%
test_input = pd.merge(left=test_set, right=members, how='inner', on=['msno'])
test_input.drop(['is_churn'], axis=1, inplace=True)

test_input['gender'] = test_input['gender'].fillna(value='unknown')
test_input.gender.value_counts(normalize=True).plot(kind='bar')

test_input.reset_index(inplace=True)

print(len(test_input))
test_input.head()
# Out:
# 261
#    index                                          msno city  bd   gender  \
# 0      0  Mw5uZl5ZKJCqTFQlLLehnYl2LzhzgF6qkAc3y7NajVs=   13  23     male
# 1      1  N1HwZQAKYSVfyGBS+6latdiXvlKuJfq2GSE+BtIOjnA=   22  21     male
# 2      2  fYLWFwunLHQ6WGW/qcfZISZHXwftXsU2docCBIl+DzQ=   15  38     male
# 3      3  uwwPnQ0lSB19hRLt864RXK8TtfkGsNOIYq00aqCC94o=    1   0  unknown
# 4      4  bM95R6iOH0JJ+Tdxr/vncTdqgIylEO8TsgkuJRQo21o=    1   0  unknown
#
#   registered_via  registration_init_time registration_init_time_dt
# 0              9                20060818                2006-08-18
# 1              3                20141003                2014-10-03
# 2              7                20160320                2016-03-20
# 3              7                20151017                2015-10-17
# 4              7                20160102                2016-01-02

# %%
# Reduce the transactions dataset down to ust those members present in the train set ..
transactions_train = pd.merge(train_set['msno'], transactions, on='msno', how='inner')
#transactions_train.reset_index(drop=True, inplace=True)

# Reduce the transactions dataset down to ust those members present in the train set ..
transactions_test = pd.merge(test_set['msno'], transactions, on='msno', how='inner')
#transactions_test.reset_index(drop=True, inplace=True)

print(len(transactions_train), len(transactions_test))
transactions_train.head()
# Out:
# 10699 4653
#                                            msno  payment_method_id  \
# 0  YxW3KnnTxGLb7uqUPEN1aNx3QKrCSkzBvBfhzGNgoUo=                 38
# 1  YxW3KnnTxGLb7uqUPEN1aNx3QKrCSkzBvBfhzGNgoUo=                 38
# 2  YxW3KnnTxGLb7uqUPEN1aNx3QKrCSkzBvBfhzGNgoUo=                 38
# 3  YxW3KnnTxGLb7uqUPEN1aNx3QKrCSkzBvBfhzGNgoUo=                 38
# 4  YxW3KnnTxGLb7uqUPEN1aNx3QKrCSkzBvBfhzGNgoUo=                 38
#
#    payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 0                 30              149                 149          False
# 1                 30              149                 149          False
# 2                 30              149                 149          False
# 3                 30              149                 149          False
# 4                 30              149                 149          False
#
#    transaction_date  membership_expire_date  is_cancel  price_difference  \
# 0          20161022                20161121      False                 0
# 1          20161224                20170123      False                 0
# 2          20160327                20160426      False                 0
# 3          20160115                20160214      False                 0
# 4          20160508                20160607      False                 0
#
#    planned_daily_price  daily_price
# 0                 4.97         4.97
# 1                 4.97         4.97
# 2                 4.97         4.97
# 3                 4.97         4.97
# 4                 4.97         4.97

# %%
transactions.head()
# Out:
#                                            msno  payment_method_id  \
# 0  YyO+tlZtAXYXoZhNr3Vg3+dfVQvrBVGO8j1mfqe4ZHc=                 41
# 1  AZtu6Wl0gPojrEQYB8Q3vBSmE2wnZ3hi1FbK1rQQ0A4=                 41
# 2  UkDFI97Qb6+s2LWcijVVv4rMAsORbVDT2wNXF0aVbns=                 41
# 3  M1C56ijxozNaGD0t2h68PnH2xtx5iO5iR2MVYQB6nBI=                 39
# 4  yvj6zyBUaqdbUQSrKsrZ+xNDVM62knauSZJzakS9OW4=                 39
#
#    payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 0                 30              129                 129           True
# 1                 30              149                 149           True
# 2                 30              129                 129           True
# 3                 30              149                 149           True
# 4                 30              149                 149           True
#
#    transaction_date  membership_expire_date  is_cancel  price_difference  \
# 0          20150930                20151101      False                 0
# 1          20150930                20151031      False                 0
# 2          20150930                20160427      False                 0
# 3          20150930                20151128      False                 0
# 4          20150930                20151121      False                 0
#
#    planned_daily_price  daily_price
# 0                 4.30         4.30
# 1                 4.97         4.97
# 2                 4.30         4.30
# 3                 4.97         4.97
# 4                 4.97         4.97

# %%
transactions_train.head()
# Out:
#                                            msno  payment_method_id  \
# 0  YxW3KnnTxGLb7uqUPEN1aNx3QKrCSkzBvBfhzGNgoUo=                 38
# 1  YxW3KnnTxGLb7uqUPEN1aNx3QKrCSkzBvBfhzGNgoUo=                 38
# 2  YxW3KnnTxGLb7uqUPEN1aNx3QKrCSkzBvBfhzGNgoUo=                 38
# 3  YxW3KnnTxGLb7uqUPEN1aNx3QKrCSkzBvBfhzGNgoUo=                 38
# 4  YxW3KnnTxGLb7uqUPEN1aNx3QKrCSkzBvBfhzGNgoUo=                 38
#
#    payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 0                 30              149                 149          False
# 1                 30              149                 149          False
# 2                 30              149                 149          False
# 3                 30              149                 149          False
# 4                 30              149                 149          False
#
#    transaction_date  membership_expire_date  is_cancel  price_difference  \
# 0          20161022                20161121      False                 0
# 1          20161224                20170123      False                 0
# 2          20160327                20160426      False                 0
# 3          20160115                20160214      False                 0
# 4          20160508                20160607      False                 0
#
#    planned_daily_price  daily_price
# 0                 4.97         4.97
# 1                 4.97         4.97
# 2                 4.97         4.97
# 3                 4.97         4.97
# 4                 4.97         4.97

# %%
# Specify aggregation primitives
agg_primitives = ['sum', 'time_since_last', 'avg_time_between', 'all', 'mode', 'num_unique', 'min', 'last', 
                  'mean', 'percent_true', 'max', 'std', 'count']
# Specify transformation primitives
trans_primitives = ['day', 'month', 'diff', 'time_since_previous']
# Specify where primitives
where_primitives = ['sum', 'mean']#, 'percent_true', 'all', 'any']

# %%
# Make empty entityset
es_train = ft.EntitySet(id = 'train_set')

# Create entity from members
es_train.entity_from_dataframe(entity_id='members', dataframe=train_input,
                               index = 'msno', time_index = 'registration_init_time', 
                               variable_types = {'city': vtypes.Categorical, 
                                                 'gender': vtypes.Categorical,
                                                 'registered_via': vtypes.Categorical})

# Create entity from transactions
es_train.entity_from_dataframe(entity_id='transactions', dataframe=transactions_train,
                         index = 'transactions_index', make_index = True,
                         time_index = 'transaction_date', 
                         variable_types = {'payment_method_id': vtypes.Categorical, 
                                           'is_auto_renew': vtypes.Boolean, 
                                           'is_cancel': vtypes.Boolean})

# Relationships (parent, child)
r_member_transactions = ft.Relationship(es_train['members']['msno'], 
                                        es_train['transactions']['msno'])

es_train.add_relationships([r_member_transactions])
# Out:
# Entityset: train_set
#   Entities:
#     members [Rows: 628, Columns: 8]
#     transactions [Rows: 10699, Columns: 13]
#   Relationships:
#     transactions.msno -> members.msno

# %%
feature_matrix, feature_defs = ft.dfs(entityset=es_train,
                                      target_entity="members",
                                      agg_primitives = agg_primitives,
                                      trans_primitives = trans_primitives,
                                      where_primitives = where_primitives,
                                      max_depth=2, n_jobs = 1, chunk_size = 1000, verbose = 1, 
                                      ignore_variables={'members':['msno', 'Id', 'index'], 'transactions':['msno', 'Id', 'index', 'transactions_index']})
# Out:
# Built 165 features
# Elapsed: 00:00 | Remaining: 00:00 | Progress: 100%|██████████| Calculated: 1/1 chunks

# %%
X_train = feature_matrix.copy()
X_train.head(10)
# Out:
#                                               bd  registration_init_time city  \
# msno
# +3ZFu2GGxVN8jvOU0sVk0dPePB8niKRK4wQjzPjdvqY=   0                20140423   22
# +E8eH0WkZv924AdQWUXg6eSO2TN6q+AJWLYPILdwA0Y=   0                20160507    1
# +UG39wI7s3we3aL7Te+avr5tMAbFDYL7bI6+QOV98hg=   0                20160121    1
# +UrLeq4/x03r/8pLgTGIE6HPghsB/iOnhPZBitfKUCo=  27                20131226    5
# +UsO0C/ACykNrxGtqYrSa+3cP91u/Pv4VTL4l2hQHtQ=   0                20120226    1
# +Yx5VJrcy/UlV9y4OtkecNsru2i5EkBoF+K7Xw5CdR4=   0                20151114    6
# +cslisdRTtNzQyFnebbggrwyN73nw0lzqxvmgc1oNV4=   0                20151012    1
# +iEftSf10pAXRy9ex42b/BXbPTF5yLYq2sexOg4V9Qg=   0                20140409    1
# +iz30Nm1c+4V8DAVMWAbH2zeMN4Jto8FWJD2BGnjqw8=  35                20100727    6
# +np27pt3zzbyHfPa7INhSs1tS+6eIyV0/FaKVGKVYEk=   0                20140413    1
#
#                                                gender registered_via  \
# msno
# +3ZFu2GGxVN8jvOU0sVk0dPePB8niKRK4wQjzPjdvqY=  unknown              3
# +E8eH0WkZv924AdQWUXg6eSO2TN6q+AJWLYPILdwA0Y=  unknown              7
# +UG39wI7s3we3aL7Te+avr5tMAbFDYL7bI6+QOV98hg=  unknown              7
# +UrLeq4/x03r/8pLgTGIE6HPghsB/iOnhPZBitfKUCo=   female              7
# +UsO0C/ACykNrxGtqYrSa+3cP91u/Pv4VTL4l2hQHtQ=  unknown              7
# +Yx5VJrcy/UlV9y4OtkecNsru2i5EkBoF+K7Xw5CdR4=  unknown              9
# +cslisdRTtNzQyFnebbggrwyN73nw0lzqxvmgc1oNV4=  unknown              7
# +iEftSf10pAXRy9ex42b/BXbPTF5yLYq2sexOg4V9Qg=  unknown              7
# +iz30Nm1c+4V8DAVMWAbH2zeMN4Jto8FWJD2BGnjqw8=     male              7
# +np27pt3zzbyHfPa7INhSs1tS+6eIyV0/FaKVGKVYEk=  unknown              7
#
#                                               SUM(transactions.payment_plan_days)  \
# msno
# +3ZFu2GGxVN8jvOU0sVk0dPePB8niKRK4wQjzPjdvqY=                                  480
# +E8eH0WkZv924AdQWUXg6eSO2TN6q+AJWLYPILdwA0Y=                                  300
# +UG39wI7s3we3aL7Te+avr5tMAbFDYL7bI6+QOV98hg=                                  420
# +UrLeq4/x03r/8pLgTGIE6HPghsB/iOnhPZBitfKUCo=                                  210
# +UsO0C/ACykNrxGtqYrSa+3cP91u/Pv4VTL4l2hQHtQ=                                  780
# +Yx5VJrcy/UlV9y4OtkecNsru2i5EkBoF+K7Xw5CdR4=                                  300
# +cslisdRTtNzQyFnebbggrwyN73nw0lzqxvmgc1oNV4=                                  510
# +iEftSf10pAXRy9ex42b/BXbPTF5yLYq2sexOg4V9Qg=                                  930
# +iz30Nm1c+4V8DAVMWAbH2zeMN4Jto8FWJD2BGnjqw8=                                  810
# +np27pt3zzbyHfPa7INhSs1tS+6eIyV0/FaKVGKVYEk=                                  900
#
#                                               SUM(transactions.plan_list_price)  \
# msno
# +3ZFu2GGxVN8jvOU0sVk0dPePB8niKRK4wQjzPjdvqY=                            2235.00
# +E8eH0WkZv924AdQWUXg6eSO2TN6q+AJWLYPILdwA0Y=                             990.00
# +UG39wI7s3we3aL7Te+avr5tMAbFDYL7bI6+QOV98hg=                            1386.00
# +UrLeq4/x03r/8pLgTGIE6HPghsB/iOnhPZBitfKUCo=                             693.00
# +UsO0C/ACykNrxGtqYrSa+3cP91u/Pv4VTL4l2hQHtQ=                            3725.00
# +Yx5VJrcy/UlV9y4OtkecNsru2i5EkBoF+K7Xw5CdR4=                            1490.00
# +cslisdRTtNzQyFnebbggrwyN73nw0lzqxvmgc1oNV4=                            1683.00
# +iEftSf10pAXRy9ex42b/BXbPTF5yLYq2sexOg4V9Qg=                            3940.00
# +iz30Nm1c+4V8DAVMWAbH2zeMN4Jto8FWJD2BGnjqw8=                            3724.00
# +np27pt3zzbyHfPa7INhSs1tS+6eIyV0/FaKVGKVYEk=                            4041.00
#
#                                               SUM(transactions.actual_amount_paid)  \
# msno
# +3ZFu2GGxVN8jvOU0sVk0dPePB8niKRK4wQjzPjdvqY=                               2384.00
# +E8eH0WkZv924AdQWUXg6eSO2TN6q+AJWLYPILdwA0Y=                                990.00
# +UG39wI7s3we3aL7Te+avr5tMAbFDYL7bI6+QOV98hg=                               1386.00
# +UrLeq4/x03r/8pLgTGIE6HPghsB/iOnhPZBitfKUCo=                                693.00
# +UsO0C/ACykNrxGtqYrSa+3cP91u/Pv4VTL4l2hQHtQ=                               3874.00
# +Yx5VJrcy/UlV9y4OtkecNsru2i5EkBoF+K7Xw5CdR4=                               1490.00
# +cslisdRTtNzQyFnebbggrwyN73nw0lzqxvmgc1oNV4=                               1683.00
# +iEftSf10pAXRy9ex42b/BXbPTF5yLYq2sexOg4V9Qg=                               3939.00
# +iz30Nm1c+4V8DAVMWAbH2zeMN4Jto8FWJD2BGnjqw8=                               3873.00
# +np27pt3zzbyHfPa7INhSs1tS+6eIyV0/FaKVGKVYEk=                               4080.00
#
#                                               SUM(transactions.transaction_date)  \
# msno
# +3ZFu2GGxVN8jvOU0sVk0dPePB8niKRK4wQjzPjdvqY=                           322522050
# +E8eH0WkZv924AdQWUXg6eSO2TN6q+AJWLYPILdwA0Y=                           201627170
# +UG39wI7s3we3aL7Te+avr5tMAbFDYL7bI6+QOV98hg=                           282268394
# +UrLeq4/x03r/8pLgTGIE6HPghsB/iOnhPZBitfKUCo=                           141145489
# +UsO0C/ACykNrxGtqYrSa+3cP91u/Pv4VTL4l2hQHtQ=                           524076550
# +Yx5VJrcy/UlV9y4OtkecNsru2i5EkBoF+K7Xw5CdR4=                           201598465
# +cslisdRTtNzQyFnebbggrwyN73nw0lzqxvmgc1oNV4=                           342721588
# +iEftSf10pAXRy9ex42b/BXbPTF5yLYq2sexOg4V9Qg=                           624860924
# +iz30Nm1c+4V8DAVMWAbH2zeMN4Jto8FWJD2BGnjqw8=                           544237704
# +np27pt3zzbyHfPa7INhSs1tS+6eIyV0/FaKVGKVYEk=                           604699485
#
#                                               SUM(transactions.membership_expire_date)  \
# msno
# +3ZFu2GGxVN8jvOU0sVk0dPePB8niKRK4wQjzPjdvqY=                                 322531992
# +E8eH0WkZv924AdQWUXg6eSO2TN6q+AJWLYPILdwA0Y=                                 201636970
# +UG39wI7s3we3aL7Te+avr5tMAbFDYL7bI6+QOV98hg=                                 282278594
# +UrLeq4/x03r/8pLgTGIE6HPghsB/iOnhPZBitfKUCo=                                 141154989
# +UsO0C/ACykNrxGtqYrSa+3cP91u/Pv4VTL4l2hQHtQ=                                 524096802
# +Yx5VJrcy/UlV9y4OtkecNsru2i5EkBoF+K7Xw5CdR4=                                 201626570
# +cslisdRTtNzQyFnebbggrwyN73nw0lzqxvmgc1oNV4=                                 342740887
# +iEftSf10pAXRy9ex42b/BXbPTF5yLYq2sexOg4V9Qg=                                 624881421
# +iz30Nm1c+4V8DAVMWAbH2zeMN4Jto8FWJD2BGnjqw8=                                 544257929
# +np27pt3zzbyHfPa7INhSs1tS+6eIyV0/FaKVGKVYEk=                                 604728881
#
#                                               ...  \
# msno                                          ...
# +3ZFu2GGxVN8jvOU0sVk0dPePB8niKRK4wQjzPjdvqY=  ...
# +E8eH0WkZv924AdQWUXg6eSO2TN6q+AJWLYPILdwA0Y=  ...
# +UG39wI7s3we3aL7Te+avr5tMAbFDYL7bI6+QOV98hg=  ...
# +UrLeq4/x03r/8pLgTGIE6HPghsB/iOnhPZBitfKUCo=  ...
# +UsO0C/ACykNrxGtqYrSa+3cP91u/Pv4VTL4l2hQHtQ=  ...
# +Yx5VJrcy/UlV9y4OtkecNsru2i5EkBoF+K7Xw5CdR4=  ...
# +cslisdRTtNzQyFnebbggrwyN73nw0lzqxvmgc1oNV4=  ...
# +iEftSf10pAXRy9ex42b/BXbPTF5yLYq2sexOg4V9Qg=  ...
# +iz30Nm1c+4V8DAVMWAbH2zeMN4Jto8FWJD2BGnjqw8=  ...
# +np27pt3zzbyHfPa7INhSs1tS+6eIyV0/FaKVGKVYEk=  ...
#
#                                               DIFF(MAX(transactions.planned_daily_price))  \
# msno
# +3ZFu2GGxVN8jvOU0sVk0dPePB8niKRK4wQjzPjdvqY=                                         0.00
# +E8eH0WkZv924AdQWUXg6eSO2TN6q+AJWLYPILdwA0Y=                                        -1.00
# +UG39wI7s3we3aL7Te+avr5tMAbFDYL7bI6+QOV98hg=                                         0.00
# +UrLeq4/x03r/8pLgTGIE6HPghsB/iOnhPZBitfKUCo=                                         0.00
# +UsO0C/ACykNrxGtqYrSa+3cP91u/Pv4VTL4l2hQHtQ=                                         0.00
# +Yx5VJrcy/UlV9y4OtkecNsru2i5EkBoF+K7Xw5CdR4=                                         0.00
# +cslisdRTtNzQyFnebbggrwyN73nw0lzqxvmgc1oNV4=                                         0.00
# +iEftSf10pAXRy9ex42b/BXbPTF5yLYq2sexOg4V9Qg=                                         0.00
# +iz30Nm1c+4V8DAVMWAbH2zeMN4Jto8FWJD2BGnjqw8=                                         0.00
# +np27pt3zzbyHfPa7INhSs1tS+6eIyV0/FaKVGKVYEk=                                         0.00
#
#                                               DIFF(MAX(transactions.daily_price))  \
# msno
# +3ZFu2GGxVN8jvOU0sVk0dPePB8niKRK4wQjzPjdvqY=                                 0.00
# +E8eH0WkZv924AdQWUXg6eSO2TN6q+AJWLYPILdwA0Y=                                -1.00
# +UG39wI7s3we3aL7Te+avr5tMAbFDYL7bI6+QOV98hg=                                 0.00
# +UrLeq4/x03r/8pLgTGIE6HPghsB/iOnhPZBitfKUCo=                                 0.00
# +UsO0C/ACykNrxGtqYrSa+3cP91u/Pv4VTL4l2hQHtQ=                                 0.00
# +Yx5VJrcy/UlV9y4OtkecNsru2i5EkBoF+K7Xw5CdR4=                                 0.00
# +cslisdRTtNzQyFnebbggrwyN73nw0lzqxvmgc1oNV4=                                 0.00
# +iEftSf10pAXRy9ex42b/BXbPTF5yLYq2sexOg4V9Qg=                                 0.00
# +iz30Nm1c+4V8DAVMWAbH2zeMN4Jto8FWJD2BGnjqw8=                                 0.00
# +np27pt3zzbyHfPa7INhSs1tS+6eIyV0/FaKVGKVYEk=                                 0.00
#
#                                               DIFF(STD(transactions.payment_plan_days))  \
# msno
# +3ZFu2GGxVN8jvOU0sVk0dPePB8niKRK4wQjzPjdvqY=                                      -0.37
# +E8eH0WkZv924AdQWUXg6eSO2TN6q+AJWLYPILdwA0Y=                                       0.00
# +UG39wI7s3we3aL7Te+avr5tMAbFDYL7bI6+QOV98hg=                                       0.00
# +UrLeq4/x03r/8pLgTGIE6HPghsB/iOnhPZBitfKUCo=                                       0.00
# +UsO0C/ACykNrxGtqYrSa+3cP91u/Pv4VTL4l2hQHtQ=                                       0.00
# +Yx5VJrcy/UlV9y4OtkecNsru2i5EkBoF+K7Xw5CdR4=                                       0.00
# +cslisdRTtNzQyFnebbggrwyN73nw0lzqxvmgc1oNV4=                                       0.00
# +iEftSf10pAXRy9ex42b/BXbPTF5yLYq2sexOg4V9Qg=                                       0.00
# +iz30Nm1c+4V8DAVMWAbH2zeMN4Jto8FWJD2BGnjqw8=                                       0.00
# +np27pt3zzbyHfPa7INhSs1tS+6eIyV0/FaKVGKVYEk=                                       0.00
#
#                                               DIFF(STD(transactions.plan_list_price))  \
# msno
# +3ZFu2GGxVN8jvOU0sVk0dPePB8niKRK4wQjzPjdvqY=                                     3.07
# +E8eH0WkZv924AdQWUXg6eSO2TN6q+AJWLYPILdwA0Y=                                     0.00
# +UG39wI7s3we3aL7Te+avr5tMAbFDYL7bI6+QOV98hg=                                     0.00
# +UrLeq4/x03r/8pLgTGIE6HPghsB/iOnhPZBitfKUCo=                                     0.00
# +UsO0C/ACykNrxGtqYrSa+3cP91u/Pv4VTL4l2hQHtQ=                                    -5.54
# +Yx5VJrcy/UlV9y4OtkecNsru2i5EkBoF+K7Xw5CdR4=                                     0.00
# +cslisdRTtNzQyFnebbggrwyN73nw0lzqxvmgc1oNV4=                                     0.00
# +iEftSf10pAXRy9ex42b/BXbPTF5yLYq2sexOg4V9Qg=                                    29.11
# +iz30Nm1c+4V8DAVMWAbH2zeMN4Jto8FWJD2BGnjqw8=                                    21.17
# +np27pt3zzbyHfPa7INhSs1tS+6eIyV0/FaKVGKVYEk=                                    -1.78
#
#                                               DIFF(STD(transactions.actual_amount_paid))  \
# msno
# +3ZFu2GGxVN8jvOU0sVk0dPePB8niKRK4wQjzPjdvqY=                                        0.00
# +E8eH0WkZv924AdQWUXg6eSO2TN6q+AJWLYPILdwA0Y=                                        0.00
# +UG39wI7s3we3aL7Te+avr5tMAbFDYL7bI6+QOV98hg=                                        0.00
# +UrLeq4/x03r/8pLgTGIE6HPghsB/iOnhPZBitfKUCo=                                        0.00
# +UsO0C/ACykNrxGtqYrSa+3cP91u/Pv4VTL4l2hQHtQ=                                      -25.32
# +Yx5VJrcy/UlV9y4OtkecNsru2i5EkBoF+K7Xw5CdR4=                                        0.00
# +cslisdRTtNzQyFnebbggrwyN73nw0lzqxvmgc1oNV4=                                        0.00
# +iEftSf10pAXRy9ex42b/BXbPTF5yLYq2sexOg4V9Qg=                                       16.00
# +iz30Nm1c+4V8DAVMWAbH2zeMN4Jto8FWJD2BGnjqw8=                                        0.74
# +np27pt3zzbyHfPa7INhSs1tS+6eIyV0/FaKVGKVYEk=                                       -4.82
#
#                                               DIFF(STD(transactions.transaction_date))  \
# msno
# +3ZFu2GGxVN8jvOU0sVk0dPePB8niKRK4wQjzPjdvqY=                                    722.50
# +E8eH0WkZv924AdQWUXg6eSO2TN6q+AJWLYPILdwA0Y=                                      0.00
# +UG39wI7s3we3aL7Te+avr5tMAbFDYL7bI6+QOV98hg=                                      0.04
# +UrLeq4/x03r/8pLgTGIE6HPghsB/iOnhPZBitfKUCo=                                    114.88
# +UsO0C/ACykNrxGtqYrSa+3cP91u/Pv4VTL4l2hQHtQ=                                     91.26
# +Yx5VJrcy/UlV9y4OtkecNsru2i5EkBoF+K7Xw5CdR4=                                    507.53
# +cslisdRTtNzQyFnebbggrwyN73nw0lzqxvmgc1oNV4=                                     -0.11
# +iEftSf10pAXRy9ex42b/BXbPTF5yLYq2sexOg4V9Qg=                                   1182.09
# +iz30Nm1c+4V8DAVMWAbH2zeMN4Jto8FWJD2BGnjqw8=                                    -71.23
# +np27pt3zzbyHfPa7INhSs1tS+6eIyV0/FaKVGKVYEk=                                     92.69
#
#                                               DIFF(STD(transactions.membership_expire_date))  \
# msno
# +3ZFu2GGxVN8jvOU0sVk0dPePB8niKRK4wQjzPjdvqY=                                           56.15
# +E8eH0WkZv924AdQWUXg6eSO2TN6q+AJWLYPILdwA0Y=                                            0.00
# +UG39wI7s3we3aL7Te+avr5tMAbFDYL7bI6+QOV98hg=                                            0.00
# +UrLeq4/x03r/8pLgTGIE6HPghsB/iOnhPZBitfKUCo=                                          924.92
# +UsO0C/ACykNrxGtqYrSa+3cP91u/Pv4VTL4l2hQHtQ=                                          114.59
# +Yx5VJrcy/UlV9y4OtkecNsru2i5EkBoF+K7Xw5CdR4=                                         1233.92
# +cslisdRTtNzQyFnebbggrwyN73nw0lzqxvmgc1oNV4=                                            0.00
# +iEftSf10pAXRy9ex42b/BXbPTF5yLYq2sexOg4V9Qg=                                         1659.18
# +iz30Nm1c+4V8DAVMWAbH2zeMN4Jto8FWJD2BGnjqw8=                                         -124.72
# +np27pt3zzbyHfPa7INhSs1tS+6eIyV0/FaKVGKVYEk=                                          477.09
#
#                                               DIFF(STD(transactions.price_difference))  \
# msno
# +3ZFu2GGxVN8jvOU0sVk0dPePB8niKRK4wQjzPjdvqY=                                      2.20
# +E8eH0WkZv924AdQWUXg6eSO2TN6q+AJWLYPILdwA0Y=                                      0.00
# +UG39wI7s3we3aL7Te+avr5tMAbFDYL7bI6+QOV98hg=                                      0.00
# +UrLeq4/x03r/8pLgTGIE6HPghsB/iOnhPZBitfKUCo=                                      0.00
# +UsO0C/ACykNrxGtqYrSa+3cP91u/Pv4VTL4l2hQHtQ=                                      0.39
# +Yx5VJrcy/UlV9y4OtkecNsru2i5EkBoF+K7Xw5CdR4=                                      0.00
# +cslisdRTtNzQyFnebbggrwyN73nw0lzqxvmgc1oNV4=                                      0.00
# +iEftSf10pAXRy9ex42b/BXbPTF5yLYq2sexOg4V9Qg=                                     25.97
# +iz30Nm1c+4V8DAVMWAbH2zeMN4Jto8FWJD2BGnjqw8=                                      5.95
# +np27pt3zzbyHfPa7INhSs1tS+6eIyV0/FaKVGKVYEk=                                     -1.58
#
#                                               DIFF(STD(transactions.planned_daily_price))  \
# msno
# +3ZFu2GGxVN8jvOU0sVk0dPePB8niKRK4wQjzPjdvqY=                                         0.11
# +E8eH0WkZv924AdQWUXg6eSO2TN6q+AJWLYPILdwA0Y=                                         0.00
# +UG39wI7s3we3aL7Te+avr5tMAbFDYL7bI6+QOV98hg=                                         0.00
# +UrLeq4/x03r/8pLgTGIE6HPghsB/iOnhPZBitfKUCo=                                         0.00
# +UsO0C/ACykNrxGtqYrSa+3cP91u/Pv4VTL4l2hQHtQ=                                        -0.18
# +Yx5VJrcy/UlV9y4OtkecNsru2i5EkBoF+K7Xw5CdR4=                                         0.00
# +cslisdRTtNzQyFnebbggrwyN73nw0lzqxvmgc1oNV4=                                         0.00
# +iEftSf10pAXRy9ex42b/BXbPTF5yLYq2sexOg4V9Qg=                                         0.97
# +iz30Nm1c+4V8DAVMWAbH2zeMN4Jto8FWJD2BGnjqw8=                                         0.71
# +np27pt3zzbyHfPa7INhSs1tS+6eIyV0/FaKVGKVYEk=                                        -0.06
#
#                                               DIFF(STD(transactions.daily_price))
# msno
# +3ZFu2GGxVN8jvOU0sVk0dPePB8niKRK4wQjzPjdvqY=                                -0.06
# +E8eH0WkZv924AdQWUXg6eSO2TN6q+AJWLYPILdwA0Y=                                 0.00
# +UG39wI7s3we3aL7Te+avr5tMAbFDYL7bI6+QOV98hg=                                 0.00
# +UrLeq4/x03r/8pLgTGIE6HPghsB/iOnhPZBitfKUCo=                                 0.00
# +UsO0C/ACykNrxGtqYrSa+3cP91u/Pv4VTL4l2hQHtQ=                                -0.84
# +Yx5VJrcy/UlV9y4OtkecNsru2i5EkBoF+K7Xw5CdR4=                                 0.00
# +cslisdRTtNzQyFnebbggrwyN73nw0lzqxvmgc1oNV4=                                 0.00
# +iEftSf10pAXRy9ex42b/BXbPTF5yLYq2sexOg4V9Qg=                                 0.53
# +iz30Nm1c+4V8DAVMWAbH2zeMN4Jto8FWJD2BGnjqw8=                                 0.02
# +np27pt3zzbyHfPa7INhSs1tS+6eIyV0/FaKVGKVYEk=                                -0.16
#
# [10 rows x 165 columns]

# %%
X_train.head(10).filter(regex='index')
# Out:
# Empty DataFrame
# Columns: []
# Index: [+3ZFu2GGxVN8jvOU0sVk0dPePB8niKRK4wQjzPjdvqY=, +E8eH0WkZv924AdQWUXg6eSO2TN6q+AJWLYPILdwA0Y=, +UG39wI7s3we3aL7Te+avr5tMAbFDYL7bI6+QOV98hg=, +UrLeq4/x03r/8pLgTGIE6HPghsB/iOnhPZBitfKUCo=, +UsO0C/ACykNrxGtqYrSa+3cP91u/Pv4VTL4l2hQHtQ=, +Yx5VJrcy/UlV9y4OtkecNsru2i5EkBoF+K7Xw5CdR4=, +cslisdRTtNzQyFnebbggrwyN73nw0lzqxvmgc1oNV4=, +iEftSf10pAXRy9ex42b/BXbPTF5yLYq2sexOg4V9Qg=, +iz30Nm1c+4V8DAVMWAbH2zeMN4Jto8FWJD2BGnjqw8=, +np27pt3zzbyHfPa7INhSs1tS+6eIyV0/FaKVGKVYEk=]

# %%
# Make empty entityset
es_test = ft.EntitySet(id = 'test_set')

# Create entity from members
es_test.entity_from_dataframe(entity_id='members', dataframe=test_input,
                               index = 'msno', time_index = 'registration_init_time', 
                               variable_types = {'city': vtypes.Categorical, 
                                                 'gender': vtypes.Categorical,
                                                 'registered_via': vtypes.Categorical})

# Create entity from transactions
es_test.entity_from_dataframe(entity_id='transactions', dataframe=transactions_test,
                         index = 'transactions_index', make_index = True,
                         time_index = 'transaction_date', 
                         variable_types = {'payment_method_id': vtypes.Categorical, 
                                           'is_auto_renew': vtypes.Boolean, 
                                           'is_cancel': vtypes.Boolean})

# Relationships (parent, child)
r_member_transactions_tst = ft.Relationship(es_test['members']['msno'], 
                                        es_test['transactions']['msno'])

es_test.add_relationships([r_member_transactions_tst])

feature_matrix_tst = ft.calculate_feature_matrix(features=feature_defs, entityset=es_test)

# %%
X_test = feature_matrix_tst.copy()

# %%
all_p = ft.list_primitives()
trans_p = all_p.loc[all_p['type'] == 'transform'].copy()
agg_p = all_p.loc[all_p['type'] == 'aggregation'].copy()

pd.options.display.max_colwidth = 100
agg_p.head()

# %%
print(f'This will generate {len(feature_defs)} features.')

# %%
dfs_abt = pd.merge(train, feature_matrix, on = ['msno'], how = 'inner')

# %%
dfs_abt.head()

# %%
dfs_abt.to_hdf('/home/dissertation/data/dfs_dataset.h5', key='dfs_dataset', mode='w', format='table')
