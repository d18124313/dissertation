# %%
## @see https://www.kaggle.com/toorkp/churn-wsdm/data

# %%
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import pandas as pd
import time
import gc; gc.enable()
import time
import sys

from sklearn import model_selection
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_curve, auc, confusion_matrix, f1_score, log_loss, confusion_matrix
from sklearn.neural_network import MLPClassifier
import xgboost as xgb

from collections import Counter
from numpy.random import RandomState
from imblearn.over_sampling import SMOTENC
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

pd.options.display.float_format = "{:.2f}".format
np.set_printoptions(precision=4)

import matplotlib.pyplot as plt
# %matplotlib inline

sys.path.append('modules')

from shared_functions import *

# %%
base_dataset = pd.read_hdf('/home/dissertation/data/base_abt.h5', 'base_abt')

base_dataset['city'] = base_dataset.city.astype(str)
base_dataset['registered_via'] = base_dataset.registered_via.astype(str)

## Simple Data Prep 
base_dataset = base_dataset.drop(labels =['gender','msno'], axis=1)

## Simply drops records with NA 
base_dataset = clean_dataset(base_dataset)

print(base_dataset.shape)
base_dataset.head()
# Out:
# (858935, 19)
#    is_churn city  bd registered_via  registration_init_time  \
# 0         1    5  28              3                20131223
# 1         1   13  20              3                20131223
# 2         1   13  18              3                20131227
# 3         1    1   0              7                20140109
# 4         1   13  35              7                20140125
#
#   registration_init_time_dt  total_order  payment_method_id_mode  \
# 0                2013-12-23            6                   31.00
# 1                2013-12-23            5                   38.00
# 2                2013-12-27           18                   38.00
# 3                2014-01-09           19                   41.00
# 4                2014-01-25           24                   41.00
#
#    payment_method_id_count  payment_plan_days_mode  payment_plan_days_mean  \
# 0                     2.00                    0.00                   10.00
# 1                     3.00                   30.00                   25.40
# 2                     1.00                   30.00                   30.00
# 3                     2.00                   30.00                   25.63
# 4                     1.00                   30.00                   26.25
#
#    plan_list_price_mean  plan_lifetime_value  actual_amount_mean  \
# 0                 49.67               298.00              149.00
# 1                125.40               627.00              125.40
# 2                149.00              2682.00              149.00
# 3                125.47              2384.00              141.16
# 4                105.38              2529.00              123.17
#
#    total_actual_amount  is_auto_renew_mode  transaction_date_min  \
# 0               894.00                True           20150331.00
# 1               627.00               False           20160303.00
# 2              2682.00               False           20150819.00
# 3              2682.00                True           20150108.00
# 4              2956.00                True           20150124.00
#
#    transaction_date_max  cancel_times
# 0           20170228.00             1
# 1           20170210.00             0
# 2           20170130.00             0
# 3           20160225.00             3
# 4           20160901.00             2

# %%
RANDOM_STATE = 42 
CV_ITER = 3
SCORING_METRIC = None

## Each entry in the list is a Tuple of
##   [ModelName, Model, HyperParams, ScoringMetric]
classifiers = [
#     ('NB', GaussianNB(), {}, SCORING_METRIC),
#     ('DT', DecisionTreeClassifier(), {}, SCORING_METRIC),
#     ('RF', RandomForestClassifier(n_jobs =-1), {}, SCORING_METRIC),
#     ('LR', LogisticRegression(solver = 'liblinear'), {}, SCORING_METRIC),
#     ('AB', AdaBoostClassifier(), {}, SCORING_METRIC),
#     ('MLP', MLPClassifier(), {}, SCORING_METRIC),
    ('XGB', xgb.XGBClassifier(objective="binary:logistic", random_state=42), {}, SCORING_METRIC) 
]

# %%
all_metrics = pd.DataFrame()
all_metrics
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Experiment 1.1 Baseline - Default Settings - No sampling

# %%
# %%time

sampler = ('None', DummySampler())

exp_metrics = perform_experiment(base_dataset, classifiers, sampler, 1, RANDOM_STATE, cv_iter=CV_ITER)

all_metrics = all_metrics.append(exp_metrics)
# Out:
# Model Build Iteration 0
# PRE-SAMPLING: (601254, 18) (601254,) Counter({0: 545044, 1: 56210})
# POST-SAMPLING: (601254, 18) (601254,) Counter({0: 545044, 1: 56210})
# Set the train df types correctly based on the test set
# Applying normalisation to train and test sets
# Categorical columns in dataset ['city', 'registered_via']
# Categorical columns in dataset ['city', 'registered_via']
# X_train:  (601254, 40) (601254, 1)
# X_test:  (257681, 40) (257681, 1)
# Building XGB classifier
# No params set, using Standard training
# Performing 3-fold CV on test set using None metric
# P_Recall: 0.371; N_Recall: 0.992
# CPU times: user 1min 2s, sys: 991 ms, total: 1min 3s
# Wall time: 1min 17s

# %% [markdown]
# ### Experiment 1.2 Baseline - Default Settings - Oversampled training set 100%

# %%
# %%time

sampler = ('ROS 1:1', RandomOverSampler(random_state=RANDOM_STATE))

exp_metrics = perform_experiment(base_dataset, classifiers, sampler, 1, RANDOM_STATE, cv_iter=CV_ITER)

all_metrics = all_metrics.append(exp_metrics)
# Out:
# Model Build Iteration 0
# PRE-SAMPLING: (601254, 18) (601254,) Counter({0: 545044, 1: 56210})
# POST-SAMPLING: (1090088, 18) (1090088,) Counter({1: 545044, 0: 545044})
# Set the train df types correctly based on the test set
# Applying normalisation to train and test sets
# Categorical columns in dataset ['city', 'registered_via']
# Categorical columns in dataset ['city', 'registered_via']
# X_train:  (1090088, 40) (1090088, 1)
# X_test:  (257681, 40) (257681, 1)
# Building XGB classifier
# No params set, using Standard training
# Performing 3-fold CV on test set using None metric
# P_Recall: 0.731; N_Recall: 0.882
# CPU times: user 2min 14s, sys: 1.42 s, total: 2min 15s
# Wall time: 2min 29s

# %% [markdown]
# ### Experiment 1.3 Baseline - Default Settings - Undersampled training set

# %%
# %%time

sampler = ('RUS 1:1', RandomUnderSampler(random_state=RANDOM_STATE))

exp_metrics = perform_experiment(base_dataset, classifiers, sampler, 1, RANDOM_STATE, cv_iter=CV_ITER)

all_metrics = all_metrics.append(exp_metrics)
# Out:
# Model Build Iteration 0
# PRE-SAMPLING: (601254, 18) (601254,) Counter({0: 545044, 1: 56210})
# POST-SAMPLING: (112420, 18) (112420,) Counter({0: 56210, 1: 56210})
# Set the train df types correctly based on the test set
# Applying normalisation to train and test sets
# Categorical columns in dataset ['city', 'registered_via']
# Categorical columns in dataset ['city', 'registered_via']
# X_train:  (112420, 40) (112420, 1)
# X_test:  (257681, 40) (257681, 1)
# Building XGB classifier
# No params set, using Standard training
# Performing 3-fold CV on test set using None metric
# P_Recall: 0.735; N_Recall: 0.88
# CPU times: user 17.3 s, sys: 239 ms, total: 17.6 s
# Wall time: 31.5 s

# %% [markdown]
# ### Experiment 1.4 Baseline - Default Settings - Over sampling - 33% of majority size

# %%
# %%time

sampler = ('ROS 3:1', RandomOverSampler(random_state=RANDOM_STATE, sampling_strategy = 1/3))

exp_metrics = perform_experiment(base_dataset, classifiers, sampler, 1, RANDOM_STATE, cv_iter=CV_ITER)

all_metrics = all_metrics.append(exp_metrics)
# Out:
# Model Build Iteration 0
# PRE-SAMPLING: (601254, 18) (601254,) Counter({0: 545044, 1: 56210})
# POST-SAMPLING: (726725, 18) (726725,) Counter({0: 545044, 1: 181681})
# Set the train df types correctly based on the test set
# Applying normalisation to train and test sets
# Categorical columns in dataset ['city', 'registered_via']
# Categorical columns in dataset ['city', 'registered_via']
# X_train:  (726725, 40) (726725, 1)
# X_test:  (257681, 40) (257681, 1)
# Building XGB classifier
# No params set, using Standard training
# Performing 3-fold CV on test set using None metric
# P_Recall: 0.585; N_Recall: 0.953
# CPU times: user 1min 21s, sys: 632 ms, total: 1min 22s
# Wall time: 1min 35s

# %% [markdown]
# ### Experiment 1.5 Baseline - Default Settings - Over sampling - 66% of majority size

# %%
# %%time

sampler = ('ROS 3:2', RandomOverSampler(random_state=RANDOM_STATE, sampling_strategy = 2/3))

exp_metrics = perform_experiment(base_dataset, classifiers, sampler, 1, RANDOM_STATE, cv_iter=CV_ITER)

all_metrics = all_metrics.append(exp_metrics)
# Out:
# Model Build Iteration 0
# PRE-SAMPLING: (601254, 18) (601254,) Counter({0: 545044, 1: 56210})
# POST-SAMPLING: (908406, 18) (908406,) Counter({0: 545044, 1: 363362})
# Set the train df types correctly based on the test set
# Applying normalisation to train and test sets
# Categorical columns in dataset ['city', 'registered_via']
# Categorical columns in dataset ['city', 'registered_via']
# X_train:  (908406, 40) (908406, 1)
# X_test:  (257681, 40) (257681, 1)
# Building XGB classifier
# No params set, using Standard training
# Performing 3-fold CV on test set using None metric
# P_Recall: 0.702; N_Recall: 0.9
# CPU times: user 1min 47s, sys: 696 ms, total: 1min 48s
# Wall time: 2min 1s

# %% [markdown]
# ## Experiment 1.6 Baseline - Default Settings - Over sampling - 50% of majority size

# %%
# %%time

sampler = ('ROS 2:1', RandomOverSampler(random_state=RANDOM_STATE, sampling_strategy = 1/2))

exp_metrics = perform_experiment(base_dataset, classifiers, sampler, 1, RANDOM_STATE, cv_iter=CV_ITER)

all_metrics = all_metrics.append(exp_metrics)
# Out:
# Model Build Iteration 0
# PRE-SAMPLING: (601254, 18) (601254,) Counter({0: 545044, 1: 56210})
# POST-SAMPLING: (817566, 18) (817566,) Counter({0: 545044, 1: 272522})
# Set the train df types correctly based on the test set
# Applying normalisation to train and test sets
# Categorical columns in dataset ['city', 'registered_via']
# Categorical columns in dataset ['city', 'registered_via']
# X_train:  (817566, 40) (817566, 1)
# X_test:  (257681, 40) (257681, 1)
# Building XGB classifier
# No params set, using Standard training
# Performing 3-fold CV on test set using None metric
# P_Recall: 0.66; N_Recall: 0.922
# CPU times: user 1min 35s, sys: 712 ms, total: 1min 36s
# Wall time: 1min 48s

# %% [markdown]
# ### Experiment 1.7 Baseline Default Settings SMOTE-NC

# %%
# %%time

sampler = ('SMOTE_NC', SMOTENC(random_state=RANDOM_STATE, categorical_features=[0,1,2,3,4,5,6,7,12,13], n_jobs=8))

## Keep the following, essentially dropping the dt columns
cols = ['is_churn', 'city', 'bd', 'registered_via', 'total_order',
       'payment_method_id_mode', 'payment_method_id_count',
       'payment_plan_days_mode', 'payment_plan_days_mean',
       'plan_list_price_mean', 'plan_lifetime_value', 'actual_amount_mean',
       'total_actual_amount', 'is_auto_renew_mode', 'cancel_times']

exp_metrics = perform_experiment(base_dataset[cols], classifiers, sampler, 1, RANDOM_STATE, cv_iter=CV_ITER)

all_metrics = all_metrics.append(exp_metrics)
# Out:
# Model Build Iteration 0
# PRE-SAMPLING: (601254, 14) (601254,) Counter({0: 545044, 1: 56210})
# POST-SAMPLING: (1090088, 14) (1090088,) Counter({1: 545044, 0: 545044})
# Set the train df types correctly based on the test set
# Applying normalisation to train and test sets
# Categorical columns in dataset ['city', 'registered_via']
# Categorical columns in dataset ['city', 'registered_via']
# X_train:  (1090088, 36) (1090088, 1)
# X_test:  (257681, 36) (257681, 1)
# Building XGB classifier
# No params set, using Standard training
# Performing 3-fold CV on test set using None metric
# P_Recall: 0.715; N_Recall: 0.831
# CPU times: user 17min 31s, sys: 25.8 s, total: 17min 57s
# Wall time: 17min 39s

# %%
all_metrics.sort_values(['recall'], ascending=[False]).groupby('classifier').head(1)
# Out:
#                classifier sampling_method      tn     fn     tp      fp  \
# 0           MLPClassifier         ROS 1:1       0      0  24090  233591
# 0  RandomForestClassifier         RUS 1:1  194537   5452  18638   39054
# 0      AdaBoostClassifier         RUS 1:1  201708   6034  18056   31883
# 0  DecisionTreeClassifier         RUS 1:1  185739   6039  18051   47852
# 0           XGBClassifier         RUS 1:1  205647   6381  17709   27944
# 0      LogisticRegression        SMOTE_NC  196118   8550  15540   37473
# 0              GaussianNB        SMOTE_NC  196176  10435  13655   37415
#
#    accuracy  precision  recall  f1_score  log_loss  time_taken  aucroc  auprc  \
# 0      0.09       0.09    1.00      0.17     31.31      576.51    0.50   0.55
# 0      0.83       0.32    0.77      0.46      5.97        3.72    0.87   0.57
# 0      0.85       0.36    0.75      0.49      5.08       43.73    0.88   0.57
# 0      0.79       0.27    0.75      0.40      7.22        2.18    0.76   0.50
# 0      0.87       0.39    0.74      0.51      4.60       10.37    0.89   0.62
# 0      0.82       0.29    0.65      0.40      6.17       24.27    0.79   0.43
# 0      0.81       0.27    0.57      0.36      6.41        4.08    0.71   0.40
#
#    bal_acc  cv_score_mean  cv_score_std  model_churn_cost  sample
# 0     0.50           0.91          0.00       13486300.00       0
# 0     0.80           0.93          0.00        4713550.00       0
# 0     0.81           0.93          0.00        4456850.00       0
# 0     0.77           0.91          0.00        5256175.00       0
# 0     0.81           0.93          0.00        4320625.00       0
# 0     0.74           0.92          0.00        5176650.00       0
# 0     0.70           0.85          0.00        5503625.00       0

# %%
all_metrics.sort_values(['auprc', 'recall'], ascending=[False, False]).head(15)
# Out:
#                classifier sampling_method      tn     fn     tp     fp  \
# 0           XGBClassifier            None  231753  15141   8949   1838
# 0           XGBClassifier         ROS 3:1  222597   9991  14099  10994
# 0           XGBClassifier         ROS 2:1  215297   8181  15909  18294
# 0           XGBClassifier         ROS 3:2  210294   7187  16903  23297
# 0           XGBClassifier         RUS 1:1  205647   6381  17709  27944
# 0           XGBClassifier         ROS 1:1  206104   6491  17599  27487
# 0  RandomForestClassifier            None  229476  13720  10370   4115
# 0      AdaBoostClassifier            None  231541  15424   8666   2050
# 0      AdaBoostClassifier         ROS 3:1  224807  11577  12513   8784
# 0      AdaBoostClassifier         ROS 1:1  202643   6338  17752  30948
# 0      AdaBoostClassifier         RUS 1:1  201708   6034  18056  31883
# 0      AdaBoostClassifier         ROS 3:2  210037   7464  16626  23554
# 0  RandomForestClassifier         RUS 1:1  194537   5452  18638  39054
# 0      AdaBoostClassifier         ROS 2:1  215631   8743  15347  17960
# 0  RandomForestClassifier         ROS 3:1  226128  12330  11760   7463
#
#    accuracy  precision  recall  f1_score  log_loss  time_taken  aucroc  auprc  \
# 0      0.93       0.83    0.37      0.51      2.28       57.98    0.89   0.63
# 0      0.92       0.56    0.59      0.57      2.81       71.65    0.89   0.63
# 0      0.90       0.47    0.66      0.55      3.55       84.55    0.89   0.62
# 0      0.88       0.42    0.70      0.53      4.09       95.94    0.88   0.62
# 0      0.87       0.39    0.74      0.51      4.60       10.37    0.89   0.62
# 0      0.87       0.39    0.73      0.51      4.55      121.50    0.88   0.62
# 0      0.93       0.72    0.43      0.54      2.39       20.38    0.84   0.59
# 0      0.93       0.81    0.36      0.50      2.34      100.18    0.87   0.57
# 0      0.92       0.59    0.52      0.55      2.73      114.88    0.88   0.57
# 0      0.86       0.36    0.74      0.49      5.00      198.36    0.88   0.57
# 0      0.85       0.36    0.75      0.49      5.08       43.73    0.88   0.57
# 0      0.88       0.41    0.69      0.52      4.16      148.32    0.88   0.57
# 0      0.83       0.32    0.77      0.46      5.97        3.72    0.87   0.57
# 0      0.90       0.46    0.64      0.53      3.58      132.51    0.88   0.57
# 0      0.92       0.61    0.49      0.54      2.65       21.95    0.84   0.57
#
#    bal_acc  cv_score_mean  cv_score_std  model_churn_cost  sample
# 0     0.68           0.93          0.00        4548325.00       0
# 0     0.77           0.93          0.00        4104875.00       0
# 0     0.79           0.93          0.00        4153125.00       0
# 0     0.80           0.93          0.00        4229325.00       0
# 0     0.81           0.93          0.00        4320625.00       0
# 0     0.81           0.93          0.00        4317025.00       0
# 0     0.71           0.93          0.00        4413500.00       0
# 0     0.68           0.93          0.00        4608450.00       0
# 0     0.74           0.93          0.00        4271925.00       0
# 0     0.80           0.93          0.00        4463300.00       0
# 0     0.81           0.93          0.00        4456850.00       0
# 0     0.79           0.93          0.00        4290650.00       0
# 0     0.80           0.93          0.00        4713550.00       0
# 0     0.78           0.93          0.00        4234775.00       0
# 0     0.73           0.93          0.00        4337650.00       0

# %%
all_metrics.groupby(['classifier','sampling_method']).agg({})

# %%
## Just try an SVM 
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier

# %%
# %%time
model_train_results = train_model(base_dataset, sampling_method = 'under', classifiers = [('SGDClassifier', SGDClassifier(loss='log'))])

# %%
## Print the feature importance 

feature_index = np.flip(np.argsort(model.feature_importances_), axis=0)
ordered_features = []
column_names = X_test.columns

for i in feature_index[0:10]:
    print(np.round(model.feature_importances_[i], 3), ' --> ', column_names[i])
    ordered_features.append(column_names[i])

# %%
## Print the permutation importance 

import eli5
from eli5.sklearn import PermutationImportance

_, X_test, _, y_test = prepare_train_test_split(model_dataset, 0)

perm = PermutationImportance(model, random_state=1).fit(X_test, y_test)

eli5.show_weights(perm, feature_names = X_test.columns.tolist())

# %%
#model_name, model = model_train_results[1][2]

for model_name, model in model_train_results[1]:
    probs = model.predict_proba(X_test)[:, 1]
    pr_data = plot_precision_recall(
        y_test, probs, title='PR Curve for {0}'.format(model_name))

# %%
probs = model.predict_proba(X_test)[:, 1]
pr_data = plot_precision_recall(
    y_test, probs, title='PR Curve for {0}'.format(model_name))

# %%
pr_data = plot_roc(
    y_test, probs, title='ROC Curve for {0}'.format(model_name))

# %%
print(plt.style.available)

# %%
model_dataset.head()

# %%
print("Original Data distribution")
print(model_dataset['is_churn'].value_counts())

# %%
# Display new class counts
print('Sci-Kit Learn : resample : Down Sampled data set')
train_downsample = undersampled_dataset(model_dataset, 'is_churn')

print(train_downsample['is_churn'].value_counts())
print("Num records = ", train_downsample.shape[0])
train_downsample.is_churn.value_counts().plot(kind='bar', title='Count (target)')

# %%
# Display new class counts
print('Sci-Kit Learn : resample : Up Sampled data set')
train_upsample = oversampled_dataset(model_dataset, 'is_churn')

print(train_upsample['is_churn'].value_counts())
print("Num records = ", train_upsample.shape[0])
train_upsample.is_churn.value_counts().plot(kind='bar', title='Count (target)')

# %%
probs = model.predict_proba(X_test)[:, 1]
pr_data = plot_precision_recall(
    y_test, probs, title='Precision-Recall Curve for Random Forest')

# %%
precision_above = pr_data.loc[pr_data['precision'] >= 0.25].copy()
precision_above.sort_values('recall', ascending=False, inplace=True)
precision_above.head()

# %%
threshold_required = 0.5
# Make predictions where probability is above threshold
preds = np.zeros(len(y_test))
preds[probs >= threshold_required] = 1

# Make and plot confusion matrix
cm = confusion_matrix(y_test, preds)
plot_confusion_matrix(cm, classes=['No Churn', 'Churn'],
                      title='Churn Confusion Matrix')

# %%
model_dataset.head()

# %%
fi = pd.DataFrame({'importance': model.feature_importances_}, index=model_dataset.iloc[:, 1:].columns).\
    sort_values('importance', ascending=False)
fi.head(10)
