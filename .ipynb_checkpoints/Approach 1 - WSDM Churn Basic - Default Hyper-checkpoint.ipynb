# %%
## @see https://www.kaggle.com/toorkp/churn-wsdm/data

# %%
# %load_ext autoreload
# %autoreload

# %%
import numpy as np
import pandas as pd
import time
import gc; gc.enable()
import time
import sys

from sklearn import model_selection
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
#from sklearn.metrics import accuracy_score, roc_curve, auc, confusion_matrix, f1_score, log_loss, confusion_matrix
from sklearn.neural_network import MLPClassifier
import xgboost as xgb

from collections import Counter
from numpy.random import RandomState
from imblearn.over_sampling import SMOTENC
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

pd.options.display.float_format = "{:.2f}".format
np.set_printoptions(precision=4)

import matplotlib.pyplot as plt
# %matplotlib inline

sys.path.append('modules')

from shared_functions import *

# %%
import sklearn
import xgboost
import imblearn
import tpot
import autosklearn

print("NumPy Version:\t\t\t", np.__version__)
print("Pandas Version:\t\t\t", pd.__version__)
print("Scikit-learn Version:\t\t", sklearn.__version__)
print("XGBoost:\t\t\t", xgboost.__version__)
print("Imbalanced-learn:\t\t", imblearn.__version__)
print("TPOT:\t\t\t\t", tpot.__version__)
print("autosklearn:\t\t\t", autosklearn.__version__)
# Out:
# NumPy Version:			 1.16.4
# Pandas Version:			 0.24.2
# Scikit-learn Version:		 0.21.2
# XGBoost:			 0.90
# Imbalanced-learn:		 0.5.0
# TPOT:				 0.10.2
# autosklearn:			 0.5.2

# %%
# Load the pre-split data

store = pd.HDFStore('/home/dissertation/data/base_abt_split.h5')
X_train = store['X_train']
X_test = store['X_test']
y_train = store['y_train']
y_test = store['y_test']
store.close()

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
X_train.head()
# Out:
# (600810, 16) (600810,)
# (257491, 16) (257491,)
#        city  bd   gender registered_via  registration_init_time  \
# 519994    8  20     male              4                20151205
# 22604    12  24     male              9                20050303
# 417909    1   0  unknown              7                20111222
# 620194    1   0  unknown              7                20160719
# 616666    1   0  unknown              7                20161228
#
#        registration_init_time_dt  total_order  payment_method_id_mode  \
# 519994                2015-12-05            9                      39
# 22604                 2005-03-03           20                      34
# 417909                2011-12-22            1                      41
# 620194                2016-07-19            8                      41
# 616666                2016-12-28            3                      41
#
#         payment_method_id_count  payment_plan_days_mode  \
# 519994                        1                      30
# 22604                         1                      30
# 417909                        1                      30
# 620194                        1                      30
# 616666                        1                      30
#
#         payment_plan_days_mean  plan_list_price_mean  plan_lifetime_value  \
# 519994                   30.00                149.00              1341.00
# 22604                    21.00                104.30              2086.00
# 417909                   30.00                100.00               100.00
# 620194                   30.00                 99.00               792.00
# 616666                   30.00                 99.00               297.00
#
#         is_auto_renew_mode  transaction_date_max  cancel_times
# 519994                True              20170131             0
# 22604                 True              20161231             0
# 417909                True              20170224             0
# 620194                True              20170218             0
# 616666                True              20170227             0

# %%
## Create a list of the categorical columns in the dataset
cat_col = ['gender', 'city', 'registered_via', 'payment_method_id_mode']

# %%
RANDOM_STATE = 42 
CV_ITER = None
SCORING_METRIC = None


## Each entry in the list is a Tuple of
##   [ModelName, Model, HyperParams, ScoringMetric]
classifiers = [
    ('NB', GaussianNB(), {}, SCORING_METRIC),
    ('DT', DecisionTreeClassifier(), {}, SCORING_METRIC),
    ('RF', RandomForestClassifier(n_jobs =-1), {}, SCORING_METRIC),
    ('LR', LogisticRegression(solver = 'liblinear'), {}, SCORING_METRIC),
    ('AB', AdaBoostClassifier(), {}, SCORING_METRIC),
    ('MLP', MLPClassifier(), {}, SCORING_METRIC),
    ('XGB', xgb.XGBClassifier(objective="binary:logistic", random_state=42), {}, SCORING_METRIC) 
]

# %%
all_metrics = pd.DataFrame()
all_metrics
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Experiment 1.1 Baseline - Default Settings - No sampling

# %%
# %%time

sampler = ('None', DummySampler())

exp_metrics = perform_experiment(X_train, X_test, y_train, y_test, classifiers, sampler, 1, \
                                 RANDOM_STATE, cv_iter=CV_ITER, cat_col=cat_col)

all_metrics = all_metrics.append(exp_metrics)
# Out:
# Model Build Iteration 0
# PRE-SAMPLING: (600810, 16) (600810,) Counter({0: 544661, 1: 56149})
# POST-SAMPLING: (600810, 16) (600810,) Counter({0: 544661, 1: 56149})
# Set the train df types correctly based on the test set
# Applying normalisation to train and test sets
# Categorical columns in dataset ['gender', 'city', 'registered_via', 'payment_method_id_mode']
# Categorical columns in dataset ['gender', 'city', 'registered_via', 'payment_method_id_mode']
# X_train:  (600810, 50) (600810, 1)
# X_test:  (257491, 50) (257491, 1)
# Building NB classifier
# No params set, using Standard training

# %% [markdown]
# ### Experiment 1.2 Baseline - Default Settings - Oversampled training set 100%

# %%
# %%time

sampler = ('ROS 1:1', RandomOverSampler(random_state=RANDOM_STATE))

exp_metrics = perform_experiment(X_train, X_test, y_train, y_test, classifiers, sampler, 1, 
                                 RANDOM_STATE, cv_iter=CV_ITER, cat_col=cat_col)

all_metrics = all_metrics.append(exp_metrics)
# Out:
# Model Build Iteration 0
# PRE-SAMPLING: (600810, 16) (600810,) Counter({0: 544661, 1: 56149})
# POST-SAMPLING: (1089322, 16) (1089322,) Counter({1: 544661, 0: 544661})
# Set the train df types correctly based on the test set
# Applying normalisation to train and test sets
# Categorical columns in dataset ['gender', 'city', 'registered_via', 'payment_method_id_mode']
# Categorical columns in dataset ['gender', 'city', 'registered_via', 'payment_method_id_mode']
# X_train:  (1089322, 50) (1089322, 1)
# X_test:  (257491, 50) (257491, 1)
# Building NB classifier
# No params set, using Standard training
# CPU times: user 29.3 s, sys: 3.38 s, total: 32.7 s
# Wall time: 14.3 s

# %% [markdown]
# ### Experiment 1.3 Baseline - Default Settings - Undersampled training set

# %%
# %%time

sampler = ('RUS 1:1', RandomUnderSampler(random_state=RANDOM_STATE))

exp_metrics = perform_experiment(X_train, X_test, y_train, y_test, classifiers, sampler, 1, 
                                 RANDOM_STATE, cv_iter=CV_ITER, cat_col=cat_col)

all_metrics = all_metrics.append(exp_metrics)
# Out:
# Model Build Iteration 0
# PRE-SAMPLING: (600810, 16) (600810,) Counter({0: 544661, 1: 56149})
# POST-SAMPLING: (112298, 16) (112298,) Counter({0: 56149, 1: 56149})
# Set the train df types correctly based on the test set
# Applying normalisation to train and test sets
# Categorical columns in dataset ['gender', 'city', 'registered_via', 'payment_method_id_mode']
# Categorical columns in dataset ['gender', 'city', 'registered_via', 'payment_method_id_mode']
# X_train:  (112298, 50) (112298, 1)
# X_test:  (257491, 50) (257491, 1)
# Building NB classifier
# No params set, using Standard training
# CPU times: user 12.1 s, sys: 1.13 s, total: 13.2 s
# Wall time: 6.1 s

# %% [markdown]
# ### Experiment 1.4 Baseline - Default Settings - Over sampling - 33% of majority size

# %%
# %%time

sampler = ('ROS 3:1', RandomOverSampler(random_state=RANDOM_STATE, sampling_strategy = 1/3))

exp_metrics = perform_experiment(X_train, X_test, y_train, y_test, classifiers, sampler, 1, 
                                 RANDOM_STATE, cv_iter=CV_ITER, cat_col=cat_col)

all_metrics = all_metrics.append(exp_metrics)
# Out:
# Model Build Iteration 0
# PRE-SAMPLING: (600810, 16) (600810,) Counter({0: 544661, 1: 56149})
# POST-SAMPLING: (726214, 16) (726214,) Counter({0: 544661, 1: 181553})
# Set the train df types correctly based on the test set
# Applying normalisation to train and test sets
# Categorical columns in dataset ['gender', 'city', 'registered_via', 'payment_method_id_mode']
# Categorical columns in dataset ['gender', 'city', 'registered_via', 'payment_method_id_mode']
# X_train:  (726214, 50) (726214, 1)
# X_test:  (257491, 50) (257491, 1)
# Building NB classifier
# No params set, using Standard training
# CPU times: user 24.3 s, sys: 2.72 s, total: 27.1 s
# Wall time: 10.8 s

# %% [markdown]
# ### Experiment 1.5 Baseline - Default Settings - Over sampling - 66% of majority size

# %%
# %%time

sampler = ('ROS 3:2', RandomOverSampler(random_state=RANDOM_STATE, sampling_strategy = 2/3))

exp_metrics = perform_experiment(X_train, X_test, y_train, y_test, classifiers, sampler, 1, 
                                 RANDOM_STATE, cv_iter=CV_ITER, cat_col=cat_col)

all_metrics = all_metrics.append(exp_metrics)
# Out:
# Model Build Iteration 0
# PRE-SAMPLING: (600810, 16) (600810,) Counter({0: 544661, 1: 56149})
# POST-SAMPLING: (907768, 16) (907768,) Counter({0: 544661, 1: 363107})
# Set the train df types correctly based on the test set
# Applying normalisation to train and test sets
# Categorical columns in dataset ['gender', 'city', 'registered_via', 'payment_method_id_mode']
# Categorical columns in dataset ['gender', 'city', 'registered_via', 'payment_method_id_mode']
# X_train:  (907768, 50) (907768, 1)
# X_test:  (257491, 50) (257491, 1)
# Building NB classifier
# No params set, using Standard training
# CPU times: user 27 s, sys: 2.97 s, total: 29.9 s
# Wall time: 12.5 s

# %% [markdown]
# ## Experiment 1.6 Baseline - Default Settings - Over sampling - 50% of majority size

# %%
# %%time

sampler = ('ROS 2:1', RandomOverSampler(random_state=RANDOM_STATE, sampling_strategy = 1/2))

exp_metrics = perform_experiment(X_train, X_test, y_train, y_test, classifiers, sampler, 1, 
                                 RANDOM_STATE, cv_iter=CV_ITER, cat_col=cat_col)

all_metrics = all_metrics.append(exp_metrics)
# Out:
# Model Build Iteration 0
# PRE-SAMPLING: (600810, 16) (600810,) Counter({0: 544661, 1: 56149})
# POST-SAMPLING: (816991, 16) (816991,) Counter({0: 544661, 1: 272330})
# Set the train df types correctly based on the test set
# Applying normalisation to train and test sets
# Categorical columns in dataset ['gender', 'city', 'registered_via', 'payment_method_id_mode']
# Categorical columns in dataset ['gender', 'city', 'registered_via', 'payment_method_id_mode']
# X_train:  (816991, 50) (816991, 1)
# X_test:  (257491, 50) (257491, 1)
# Building NB classifier
# No params set, using Standard training
# CPU times: user 25.7 s, sys: 2.8 s, total: 28.5 s
# Wall time: 11.7 s

# %% [markdown]
# ### Experiment 1.7 Baseline Default Settings SMOTE-NC

# %%
# %%time

sampler = ('SMOTE_NC', SMOTENC(random_state=RANDOM_STATE, categorical_features=[0,1,2,3,4,5,6,7,12,13], n_jobs=8))

## Keep the following, essentially dropping the dt columns
cols = ['is_churn', 'city', 'bd', 'registered_via', 'total_order',
       'payment_method_id_mode', 'payment_method_id_count',
       'payment_plan_days_mode', 'payment_plan_days_mean',
       'plan_list_price_mean', 'plan_lifetime_value', 'actual_amount_mean',
       'total_actual_amount', 'is_auto_renew_mode', 'cancel_times']

exp_metrics = perform_experiment(X_train, X_test, y_train, y_test, classifiers, sampler, 1, 
                                 RANDOM_STATE, cv_iter=CV_ITER, cat_col=cat_col)

all_metrics = all_metrics.append(exp_metrics)
# Out:
# Model Build Iteration 0
# PRE-SAMPLING: (600810, 16) (600810,) Counter({0: 544661, 1: 56149})
# POST-SAMPLING: (1089322, 16) (1089322,) Counter({1: 544661, 0: 544661})
# Set the train df types correctly based on the test set
# Applying normalisation to train and test sets
# Categorical columns in dataset ['gender', 'city', 'registered_via', 'payment_method_id_mode']
# Categorical columns in dataset ['gender', 'city', 'registered_via', 'payment_method_id_mode']
# X_train:  (1089322, 50) (1089322, 1)
# X_test:  (257491, 50) (257491, 1)
# Building NB classifier
# No params set, using Standard training
# CPU times: user 18min 29s, sys: 31.3 s, total: 19min
# Wall time: 17min 52s

# %%
all_metrics.sort_values(['recall'], ascending=[False]).groupby('classifier').head(1)
# Out:
#    classifier sampling_method      tn    fn     tp     fp  accuracy  \
# 0  GaussianNB        SMOTE_NC  206696  8617  15447  26731      0.86
#
#    precision  recall  neg_recall  f1_score  log_loss  time_taken  aucroc  \
# 0       0.37    0.64        0.89      0.47      4.74        5.31    0.81
#
#    auprc  balanced_accuracy cv_score_mean cv_score_std  model_churn_cost  \
# 0   0.55               0.76            -1           -1        4649325.00
#
#    sample
# 0       0

# %%
all_metrics.sort_values(['auprc', 'recall'], ascending=[False, False]).head(15)

# %%
all_metrics.groupby(['classifier','sampling_method']).agg({})

# %%
## Just try an SVM 
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier

# %%
# %%time
model_train_results = train_model(base_dataset, sampling_method = 'under', classifiers = [('SGDClassifier', SGDClassifier(loss='log'))])

# %%
## Print the feature importance 

feature_index = np.flip(np.argsort(model.feature_importances_), axis=0)
ordered_features = []
column_names = X_test.columns

for i in feature_index[0:10]:
    print(np.round(model.feature_importances_[i], 3), ' --> ', column_names[i])
    ordered_features.append(column_names[i])

# %%
## Print the permutation importance 

import eli5
from eli5.sklearn import PermutationImportance

_, X_test, _, y_test = prepare_train_test_split(model_dataset, 0)

perm = PermutationImportance(model, random_state=1).fit(X_test, y_test)

eli5.show_weights(perm, feature_names = X_test.columns.tolist())

# %%
#model_name, model = model_train_results[1][2]

for model_name, model in model_train_results[1]:
    probs = model.predict_proba(X_test)[:, 1]
    pr_data = plot_precision_recall(
        y_test, probs, title='PR Curve for {0}'.format(model_name))

# %%
probs = model.predict_proba(X_test)[:, 1]
pr_data = plot_precision_recall(
    y_test, probs, title='PR Curve for {0}'.format(model_name))

# %%
pr_data = plot_roc(
    y_test, probs, title='ROC Curve for {0}'.format(model_name))

# %%
print(plt.style.available)

# %%
model_dataset.head()

# %%
print("Original Data distribution")
print(model_dataset['is_churn'].value_counts())

# %%
# Display new class counts
print('Sci-Kit Learn : resample : Down Sampled data set')
train_downsample = undersampled_dataset(model_dataset, 'is_churn')

print(train_downsample['is_churn'].value_counts())
print("Num records = ", train_downsample.shape[0])
train_downsample.is_churn.value_counts().plot(kind='bar', title='Count (target)')

# %%
# Display new class counts
print('Sci-Kit Learn : resample : Up Sampled data set')
train_upsample = oversampled_dataset(model_dataset, 'is_churn')

print(train_upsample['is_churn'].value_counts())
print("Num records = ", train_upsample.shape[0])
train_upsample.is_churn.value_counts().plot(kind='bar', title='Count (target)')

# %%
probs = model.predict_proba(X_test)[:, 1]
pr_data = plot_precision_recall(
    y_test, probs, title='Precision-Recall Curve for Random Forest')

# %%
precision_above = pr_data.loc[pr_data['precision'] >= 0.25].copy()
precision_above.sort_values('recall', ascending=False, inplace=True)
precision_above.head()

# %%
threshold_required = 0.5
# Make predictions where probability is above threshold
preds = np.zeros(len(y_test))
preds[probs >= threshold_required] = 1

# Make and plot confusion matrix
cm = confusion_matrix(y_test, preds)
plot_confusion_matrix(cm, classes=['No Churn', 'Churn'],
                      title='Churn Confusion Matrix')

# %%
model_dataset.head()

# %%
fi = pd.DataFrame({'importance': model.feature_importances_}, index=model_dataset.iloc[:, 1:].columns).\
    sort_values('importance', ascending=False)
fi.head(10)
