# %%
# %load_ext autoreload
# %autoreload

import pandas as pd
import numpy as np

pd.options.display.float_format = "{:.2f}".format
np.set_printoptions(precision=4)

import matplotlib.pyplot as plt
# %matplotlib inline

import featuretools as ft

# %%
train = pd.read_csv('/home/dissertation/data/train_v2.csv', 
                          dtype = {'msno' : 'category'})

members = pd.read_csv('/home/dissertation/data/members_v3.csv',
                            dtype={'registered_via' : np.uint8,
                                   'gender' : str,
                                   'city' : 'category',
                                   'registered_via' : 'category'})

members['registration_init_time_dt'] = pd.to_datetime(members['registration_init_time'], 
                                                            format='%Y%m%d', errors='ignore')

## Next load in the transactions data
transactions = pd.read_csv('/home/dissertation/data/transactions.csv',
                                 dtype = {'payment_method' : 'category',
                                          'payment_plan_days' : np.uint8,
                                          'plan_list_price' : np.uint8,
                                          'actual_amount_paid': np.uint8,
                                          'is_auto_renew' : np.bool,
                                          'is_cancel' : np.bool})

# %%
merged_input = pd.merge(left=train, right=members, how='inner', on=['msno'])
merged_input.drop(['is_churn'], axis=1, inplace=True)
merged_input.head()
# Out:
#                                            msno city  bd  gender  \
# 0  ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=    5  28    male
# 1  f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=   13  20    male
# 2  zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=   13  18    male
# 3  8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=    1   0     NaN
# 4  K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=   13  35  female
#
#   registered_via  registration_init_time registration_init_time_dt
# 0              3                20131223                2013-12-23
# 1              3                20131223                2013-12-23
# 2              3                20131227                2013-12-27
# 3              7                20140109                2014-01-09
# 4              7                20140125                2014-01-25

# %%
import featuretools.variable_types as vtypes

# Make empty entityset
es = ft.EntitySet(id = 'customers')

# %%
# Create entity from members
es.entity_from_dataframe(entity_id='members', dataframe=merged_input,
                         index = 'msno', time_index = 'registration_init_time', 
                         variable_types = {'city': vtypes.Categorical, 
                                           'registered_via': vtypes.Categorical})
# Out:
# Entityset: customers
#   Entities:
#     members [Rows: 860967, Columns: 7]
#   Relationships:
#     No relationships

# %%
# Difference between listing price and price paid
transactions['price_difference'] = transactions['plan_list_price'] - transactions['actual_amount_paid']

# Planned price per day
transactions['planned_daily_price'] = transactions['plan_list_price'] / transactions['payment_plan_days']

# Actual price per day
transactions['daily_price'] = transactions['actual_amount_paid'] / transactions['payment_plan_days']

# %%
# Create entity from transactions
es.entity_from_dataframe(entity_id='transactions', dataframe=transactions,
                         index = 'transactions_index', make_index = True,
                         time_index = 'transaction_date', 
                         variable_types = {'payment_method_id': vtypes.Categorical, 
                                           'is_auto_renew': vtypes.Boolean, 'is_cancel': vtypes.Boolean})
# Out:
# Entityset: customers
#   Entities:
#     members [Rows: 860967, Columns: 7]
#     transactions [Rows: 21547746, Columns: 13]
#   Relationships:
#     No relationships

# %%
# Relationships (parent, child)
r_member_transactions = ft.Relationship(es['members']['msno'], es['transactions']['msno'])

es.add_relationships([r_member_transactions])
# Out:
# Entityset: customers
#   Entities:
#     members [Rows: 860967, Columns: 7]
#     transactions [Rows: 21547746, Columns: 13]
#   Relationships:
#     transactions.msno -> members.msno

# %%
feature_defs = ft.dfs(entityset=es, target_entity='members', 
                      where_primitives = ['sum', 'mean'],
                      max_depth=2, features_only=True)

# %%
print(f'This will generate {len(feature_defs)} features.')
# Out:
# This will generate 62 features.

# %%
import random; random.seed(42)

random.sample(feature_defs, 10)
# Out:
# [<Feature: MIN(transactions.transaction_date)>,
#  <Feature: SUM(transactions.actual_amount_paid)>,
#  <Feature: gender>,
#  <Feature: MEAN(transactions.actual_amount_paid)>,
#  <Feature: STD(transactions.membership_expire_date)>,
#  <Feature: STD(transactions.actual_amount_paid)>,
#  <Feature: STD(transactions.plan_list_price)>,
#  <Feature: SUM(transactions.transaction_date)>,
#  <Feature: DAY(registration_init_time_dt)>,
#  <Feature: SUM(transactions.plan_list_price)>]

# %%
all_p = ft.list_primitives()
trans_p = all_p.loc[all_p['type'] == 'transform'].copy()
agg_p = all_p.loc[all_p['type'] == 'aggregation'].copy()

pd.options.display.max_colwidth = 100
agg_p.head()
# Out:
#             name         type  \
# 0         median  aggregation
# 1  n_most_common  aggregation
# 2       num_true  aggregation
# 3           mean  aggregation
# 4            max  aggregation
#
#                                              description
# 0  Determines the middlemost number in a list of values.
# 1               Determines the `n` most common elements.
# 2                    Counts the number of `True` values.
# 3             Computes the average for a list of values.
# 4   Calculates the highest value, ignoring `NaN` values.

# %%
# Specify aggregation primitives
agg_primitives = ['sum', 'time_since_last', 'avg_time_between', 'all', 'mode', 'num_unique', 'min', 'last', 
                  'mean', 'percent_true', 'max', 'std', 'count']

# %%
# Specify transformation primitives
trans_primitives = ['cum_sum', 'day', 'month', 'diff', 'time_since_previous']

# %%
# Specify where primitives
where_primitives = ['sum', 'mean', 'percent_true', 'all', 'any']

# %%
feature_defs = ft.dfs(entityset=es, target_entity='members', 
                      agg_primitives = agg_primitives,
                      trans_primitives = trans_primitives,
                      where_primitives = where_primitives,
                      cutoff_time_in_index = True,
                      max_depth = 2, features_only = True)

# %%
print(f'This will generate {len(feature_defs)} features.')
# Out:
# This will generate 62 features.

# %%
random.sample(feature_defs, 15)
# Out:
# [<Feature: MIN(transactions.planned_daily_price)>,
#  <Feature: MEAN(transactions.actual_amount_paid)>,
#  <Feature: MODE(transactions.payment_method_id)>,
#  <Feature: SKEW(transactions.price_difference)>,
#  <Feature: SUM(transactions.payment_plan_days)>,
#  <Feature: MIN(transactions.payment_plan_days)>,
#  <Feature: MAX(transactions.planned_daily_price)>,
#  <Feature: registration_init_time>,
#  <Feature: gender>,
#  <Feature: YEAR(registration_init_time_dt)>,
#  <Feature: STD(transactions.payment_plan_days)>,
#  <Feature: STD(transactions.plan_list_price)>,
#  <Feature: SKEW(transactions.transaction_date)>,
#  <Feature: MIN(transactions.plan_list_price)>,
#  <Feature: COUNT(transactions)>]

# %%
from timeit import default_timer as timer

start = timer()
feature_matrix, feature_defs = ft.dfs(entityset=es, target_entity='members', 
#                                       agg_primitives = agg_primitives,
#                                       trans_primitives = trans_primitives,
#                                       where_primitives = where_primitives,
                                      where_primitives = ['sum', 'mean'],
                                      max_depth = 2, features_only = False,
                                      verbose = 1, chunk_size = 1000,  
                                      n_jobs = 1,
                                      cutoff_time_in_index = True)
end = timer()
print(f'{round(end - start)} seconds elapsed.')
# Out:
# Built 62 features
#
#
#
# Elapsed: 00:00 | Remaining: ? | Progress:   0%|          | Calculated: 0/861 chunks
#
#
# Elapsed: 00:05 | Remaining: 1:13:14 | Progress:   0%|          | Calculated: 1/861 chunks
#
#
# Elapsed: 00:08 | Remaining: 1:04:50 | Progress:   0%|          | Calculated: 2/861 chunks
#
#
# Elapsed: 00:11 | Remaining: 58:56 | Progress:   0%|          | Calculated: 3/861 chunks
#
#
# Elapsed: 00:14 | Remaining: 54:43 | Progress:   0%|          | Calculated: 4/861 chunks
#
#
# Elapsed: 00:17 | Remaining: 51:46 | Progress:   1%|          | Calculated: 5/861 chunks
#
#
# Elapsed: 00:20 | Remaining: 49:39 | Progress:   1%|          | Calculated: 6/861 chunks
#
#
# Elapsed: 00:24 | Remaining: 48:09 | Progress:   1%|          | Calculated: 7/861 chunks
#
#
# Elapsed: 00:27 | Remaining: 47:03 | Progress:   1%|          | Calculated: 8/861 chunks
#
#
# Elapsed: 00:30 | Remaining: 46:20 | Progress:   1%|          | Calculated: 9/861 chunks
#
#
# Elapsed: 00:33 | Remaining: 45:50 | Progress:   1%|          | Calculated: 10/861 chunks
#
#
# Elapsed: 00:36 | Remaining: 45:37 | Progress:   1%|▏         | Calculated: 11/861 chunks
#
#
# Elapsed: 00:39 | Remaining: 45:31 | Progress:   1%|▏         | Calculated: 12/861 chunks
#
#
# Elapsed: 00:43 | Remaining: 45:19 | Progress:   2%|▏         | Calculated: 13/861 chunks
#
#
# Elapsed: 00:46 | Remaining: 45:08 | Progress:   2%|▏         | Calculated: 14/861 chunks
#
#
# Elapsed: 00:49 | Remaining: 45:02 | Progress:   2%|▏         | Calculated: 15/861 chunks
#
#
# Elapsed: 00:52 | Remaining: 44:51 | Progress:   2%|▏         | Calculated: 16/861 chunks
#
#
# Elapsed: 00:55 | Remaining: 44:48 | Progress:   2%|▏         | Calculated: 17/861 chunks
#
#
# Elapsed: 00:58 | Remaining: 44:42 | Progress:   2%|▏         | Calculated: 18/861 chunks
#
#
# Elapsed: 01:02 | Remaining: 44:38 | Progress:   2%|▏         | Calculated: 19/861 chunks
#
#
# Elapsed: 01:05 | Remaining: 44:45 | Progress:   2%|▏         | Calculated: 20/861 chunks
#
#
# Elapsed: 01:08 | Remaining: 44:33 | Progress:   2%|▏         | Calculated: 21/861 chunks
#
#
# Elapsed: 01:11 | Remaining: 44:31 | Progress:   3%|▎         | Calculated: 22/861 chunks
#
#
# Elapsed: 01:14 | Remaining: 44:19 | Progress:   3%|▎         | Calculated: 23/861 chunks
#
#
# Elapsed: 01:18 | Remaining: 44:10 | Progress:   3%|▎         | Calculated: 24/861 chunks
#
#
# Elapsed: 01:21 | Remaining: 43:59 | Progress:   3%|▎         | Calculated: 25/861 chunks
#
#
# Elapsed: 01:24 | Remaining: 43:55 | Progress:   3%|▎         | Calculated: 26/861 chunks
#
#
# Elapsed: 01:27 | Remaining: 43:50 | Progress:   3%|▎         | Calculated: 27/861 chunks
#
#
# Elapsed: 01:30 | Remaining: 43:53 | Progress:   3%|▎         | Calculated: 28/861 chunks
#
#
# Elapsed: 01:33 | Remaining: 43:55 | Progress:   3%|▎         | Calculated: 29/861 chunks
#
#
# Elapsed: 01:36 | Remaining: 43:48 | Progress:   3%|▎         | Calculated: 30/861 chunks
#
#
# Elapsed: 01:40 | Remaining: 43:48 | Progress:   4%|▎         | Calculated: 31/861 chunks
#
#
# Elapsed: 01:43 | Remaining: 43:44 | Progress:   4%|▎         | Calculated: 32/861 chunks
#
#
# Elapsed: 01:46 | Remaining: 43:40 | Progress:   4%|▍         | Calculated: 33/861 chunks
#
#
# Elapsed: 01:49 | Remaining: 43:39 | Progress:   4%|▍         | Calculated: 34/861 chunks
#
#
# Elapsed: 01:52 | Remaining: 43:37 | Progress:   4%|▍         | Calculated: 35/861 chunks
#
#
# Elapsed: 01:56 | Remaining: 43:38 | Progress:   4%|▍         | Calculated: 36/861 chunks
#
#
# Elapsed: 01:59 | Remaining: 43:43 | Progress:   4%|▍         | Calculated: 37/861 chunks
#
#
# Elapsed: 02:02 | Remaining: 44:17 | Progress:   4%|▍         | Calculated: 38/861 chunks
#
#
# Elapsed: 02:05 | Remaining: 44:12 | Progress:   5%|▍         | Calculated: 39/861 chunks
#
#
# Elapsed: 02:09 | Remaining: 44:11 | Progress:   5%|▍         | Calculated: 40/861 chunks
#
#
# Elapsed: 02:12 | Remaining: 44:02 | Progress:   5%|▍         | Calculated: 41/861 chunks
#
#
# Elapsed: 02:15 | Remaining: 43:47 | Progress:   5%|▍         | Calculated: 42/861 chunks
#
#
# Elapsed: 02:18 | Remaining: 44:10 | Progress:   5%|▍         | Calculated: 43/861 chunks
#
#
# Elapsed: 02:21 | Remaining: 43:54 | Progress:   5%|▌         | Calculated: 44/861 chunks
#
#
# Elapsed: 02:25 | Remaining: 43:35 | Progress:   5%|▌         | Calculated: 45/861 chunks
#
#
# Elapsed: 02:28 | Remaining: 43:31 | Progress:   5%|▌         | Calculated: 46/861 chunks
#
#
# Elapsed: 02:31 | Remaining: 43:12 | Progress:   5%|▌         | Calculated: 47/861 chunks
#
#
# Elapsed: 02:34 | Remaining: 43:08 | Progress:   6%|▌         | Calculated: 48/861 chunks
#
#
# Elapsed: 02:37 | Remaining: 42:58 | Progress:   6%|▌         | Calculated: 49/861 chunks
#
#
# Elapsed: 02:40 | Remaining: 42:55 | Progress:   6%|▌         | Calculated: 50/861 chunks
#
#
# Elapsed: 02:44 | Remaining: 42:49 | Progress:   6%|▌         | Calculated: 51/861 chunks
#
#
# Elapsed: 02:47 | Remaining: 42:48 | Progress:   6%|▌         | Calculated: 52/861 chunks
#
#
# Elapsed: 02:50 | Remaining: 42:47 | Progress:   6%|▌         | Calculated: 53/861 chunks
#
#
# Elapsed: 02:53 | Remaining: 42:47 | Progress:   6%|▋         | Calculated: 54/861 chunks
#
#
# Elapsed: 02:56 | Remaining: 42:43 | Progress:   6%|▋         | Calculated: 55/861 chunks
#
#
# Elapsed: 02:59 | Remaining: 42:41 | Progress:   7%|▋         | Calculated: 56/861 chunks
#
#
# Elapsed: 03:03 | Remaining: 42:35 | Progress:   7%|▋         | Calculated: 57/861 chunks
#
#
# Elapsed: 03:06 | Remaining: 42:32 | Progress:   7%|▋         | Calculated: 58/861 chunks
#
#
# Elapsed: 03:09 | Remaining: 42:25 | Progress:   7%|▋         | Calculated: 59/861 chunks
#
#
# Elapsed: 03:12 | Remaining: 42:23 | Progress:   7%|▋         | Calculated: 60/861 chunks
#
#
# Elapsed: 03:15 | Remaining: 42:19 | Progress:   7%|▋         | Calculated: 61/861 chunks
#
#
# Elapsed: 03:19 | Remaining: 42:17 | Progress:   7%|▋         | Calculated: 62/861 chunks
#
#
# Elapsed: 03:22 | Remaining: 42:20 | Progress:   7%|▋         | Calculated: 63/861 chunks
#
#
# Elapsed: 03:25 | Remaining: 42:28 | Progress:   7%|▋         | Calculated: 64/861 chunks
#
#
# Elapsed: 03:28 | Remaining: 42:30 | Progress:   8%|▊         | Calculated: 65/861 chunks
#
#
# Elapsed: 03:31 | Remaining: 42:27 | Progress:   8%|▊         | Calculated: 66/861 chunks
#
#
# Elapsed: 03:35 | Remaining: 42:21 | Progress:   8%|▊         | Calculated: 67/861 chunks
#
#
# Elapsed: 03:38 | Remaining: 42:13 | Progress:   8%|▊         | Calculated: 68/861 chunks
#
#
# Elapsed: 03:41 | Remaining: 43:41 | Progress:   8%|▊         | Calculated: 69/861 chunks
#
#
# Elapsed: 03:45 | Remaining: 43:11 | Progress:   8%|▊         | Calculated: 70/861 chunks
#
#
# Elapsed: 03:48 | Remaining: 42:47 | Progress:   8%|▊         | Calculated: 71/861 chunks
#
#
# Elapsed: 03:51 | Remaining: 42:32 | Progress:   8%|▊         | Calculated: 72/861 chunks
#
#
# Elapsed: 03:54 | Remaining: 42:23 | Progress:   8%|▊         | Calculated: 73/861 chunks
#
#
# Elapsed: 03:57 | Remaining: 42:17 | Progress:   9%|▊         | Calculated: 74/861 chunks
#
#
# Elapsed: 04:01 | Remaining: 42:07 | Progress:   9%|▊         | Calculated: 75/861 chunks
#
#
# Elapsed: 04:04 | Remaining: 41:58 | Progress:   9%|▉         | Calculated: 76/861 chunks
#
#
# Elapsed: 04:07 | Remaining: 41:47 | Progress:   9%|▉         | Calculated: 77/861 chunks
#
#
# Elapsed: 04:10 | Remaining: 41:42 | Progress:   9%|▉         | Calculated: 78/861 chunks
#
#
# Elapsed: 04:13 | Remaining: 41:44 | Progress:   9%|▉         | Calculated: 79/861 chunks
#
#
# Elapsed: 04:17 | Remaining: 41:52 | Progress:   9%|▉         | Calculated: 80/861 chunks
# Elapsed: 04:20 | Remaining: 41:53 | Progress:   9%|▉         | Calculated: 81/861 chunks
#
#
# Elapsed: 04:23 | Remaining: 41:39 | Progress:  10%|▉         | Calculated: 82/861 chunks
#
#
# Elapsed: 04:26 | Remaining: 41:31 | Progress:  10%|▉         | Calculated: 83/861 chunks
#
#
# Elapsed: 04:29 | Remaining: 41:17 | Progress:  10%|▉         | Calculated: 84/861 chunks
#
#
# Elapsed: 04:33 | Remaining: 41:18 | Progress:  10%|▉         | Calculated: 85/861 chunks
#
#
# Elapsed: 04:36 | Remaining: 41:13 | Progress:  10%|▉         | Calculated: 86/861 chunks
#
#
# Elapsed: 04:39 | Remaining: 41:07 | Progress:  10%|█         | Calculated: 87/861 chunks
#
#
# Elapsed: 04:42 | Remaining: 40:54 | Progress:  10%|█         | Calculated: 88/861 chunks
#
#
# Elapsed: 04:45 | Remaining: 40:59 | Progress:  10%|█         | Calculated: 89/861 chunks
#
#
# Elapsed: 04:48 | Remaining: 40:58 | Progress:  10%|█         | Calculated: 90/861 chunks
#
#
# Elapsed: 04:52 | Remaining: 40:49 | Progress:  11%|█         | Calculated: 91/861 chunks
#
#
# Elapsed: 04:55 | Remaining: 40:46 | Progress:  11%|█         | Calculated: 92/861 chunks
#
#
# Elapsed: 04:58 | Remaining: 40:43 | Progress:  11%|█         | Calculated: 93/861 chunks
#
#
# Elapsed: 05:01 | Remaining: 40:37 | Progress:  11%|█         | Calculated: 94/861 chunks
#
#
# Elapsed: 05:04 | Remaining: 40:35 | Progress:  11%|█         | Calculated: 95/861 chunks
#
#
# Elapsed: 05:08 | Remaining: 40:43 | Progress:  11%|█         | Calculated: 96/861 chunks
#
#
# Elapsed: 05:11 | Remaining: 40:34 | Progress:  11%|█▏        | Calculated: 97/861 chunks
#
#
# Elapsed: 05:14 | Remaining: 40:27 | Progress:  11%|█▏        | Calculated: 98/861 chunks
#
#
# Elapsed: 05:17 | Remaining: 40:29 | Progress:  11%|█▏        | Calculated: 99/861 chunks
#
#
# Elapsed: 05:20 | Remaining: 40:26 | Progress:  12%|█▏        | Calculated: 100/861 chunks
#
#
# Elapsed: 05:23 | Remaining: 40:20 | Progress:  12%|█▏        | Calculated: 101/861 chunks
#
#
# Elapsed: 05:27 | Remaining: 40:16 | Progress:  12%|█▏        | Calculated: 102/861 chunks
#
#
# Elapsed: 05:30 | Remaining: 40:09 | Progress:  12%|█▏        | Calculated: 103/861 chunks
#
#
# Elapsed: 05:33 | Remaining: 40:07 | Progress:  12%|█▏        | Calculated: 104/861 chunks
#
#
# Elapsed: 05:36 | Remaining: 40:07 | Progress:  12%|█▏        | Calculated: 105/861 chunks
#
#
# Elapsed: 05:39 | Remaining: 40:00 | Progress:  12%|█▏        | Calculated: 106/861 chunks
#
#
# Elapsed: 05:43 | Remaining: 39:59 | Progress:  12%|█▏        | Calculated: 107/861 chunks
#
#
# Elapsed: 05:46 | Remaining: 39:54 | Progress:  13%|█▎        | Calculated: 108/861 chunks
#
#
# Elapsed: 05:49 | Remaining: 39:53 | Progress:  13%|█▎        | Calculated: 109/861 chunks
#
#
# Elapsed: 05:52 | Remaining: 39:52 | Progress:  13%|█▎        | Calculated: 110/861 chunks
#
#
# Elapsed: 05:55 | Remaining: 39:52 | Progress:  13%|█▎        | Calculated: 111/861 chunks
#
#
# Elapsed: 05:58 | Remaining: 39:45 | Progress:  13%|█▎        | Calculated: 112/861 chunks
#
#
# Elapsed: 06:02 | Remaining: 39:45 | Progress:  13%|█▎        | Calculated: 113/861 chunks
#
#
# Elapsed: 06:05 | Remaining: 39:46 | Progress:  13%|█▎        | Calculated: 114/861 chunks
#
#
# Elapsed: 06:08 | Remaining: 39:50 | Progress:  13%|█▎        | Calculated: 115/861 chunks
#
#
# Elapsed: 06:11 | Remaining: 39:43 | Progress:  13%|█▎        | Calculated: 116/861 chunks
#
#
# Elapsed: 06:14 | Remaining: 39:36 | Progress:  14%|█▎        | Calculated: 117/861 chunks
#
#
# Elapsed: 06:18 | Remaining: 39:36 | Progress:  14%|█▎        | Calculated: 118/861 chunks
#
#
# Elapsed: 06:21 | Remaining: 39:37 | Progress:  14%|█▍        | Calculated: 119/861 chunks
#
#
# Elapsed: 06:24 | Remaining: 39:29 | Progress:  14%|█▍        | Calculated: 120/861 chunks
#
#
# Elapsed: 06:27 | Remaining: 39:22 | Progress:  14%|█▍        | Calculated: 121/861 chunks
#
#
# Elapsed: 06:30 | Remaining: 39:19 | Progress:  14%|█▍        | Calculated: 122/861 chunks
#
#
# Elapsed: 06:34 | Remaining: 39:17 | Progress:  14%|█▍        | Calculated: 123/861 chunks
#
#
# Elapsed: 06:37 | Remaining: 39:13 | Progress:  14%|█▍        | Calculated: 124/861 chunks
#
#
# Elapsed: 06:40 | Remaining: 39:13 | Progress:  15%|█▍        | Calculated: 125/861 chunks
#
#
# Elapsed: 06:43 | Remaining: 39:11 | Progress:  15%|█▍        | Calculated: 126/861 chunks
#
#
# Elapsed: 06:46 | Remaining: 39:03 | Progress:  15%|█▍        | Calculated: 127/861 chunks
#
#
# Elapsed: 06:50 | Remaining: 39:03 | Progress:  15%|█▍        | Calculated: 128/861 chunks
#
#
# Elapsed: 06:53 | Remaining: 38:59 | Progress:  15%|█▍        | Calculated: 129/861 chunks
#
#
# Elapsed: 06:56 | Remaining: 38:56 | Progress:  15%|█▌        | Calculated: 130/861 chunks
#
#
# Elapsed: 06:59 | Remaining: 38:53 | Progress:  15%|█▌        | Calculated: 131/861 chunks
#
#
# Elapsed: 07:02 | Remaining: 38:54 | Progress:  15%|█▌        | Calculated: 132/861 chunks
#
#
# Elapsed: 07:06 | Remaining: 38:46 | Progress:  15%|█▌        | Calculated: 133/861 chunks
#
#
# Elapsed: 07:09 | Remaining: 38:47 | Progress:  16%|█▌        | Calculated: 134/861 chunks
#
#
# Elapsed: 07:12 | Remaining: 38:43 | Progress:  16%|█▌        | Calculated: 135/861 chunks
#
#
# Elapsed: 07:15 | Remaining: 38:40 | Progress:  16%|█▌        | Calculated: 136/861 chunks
#
#
# Elapsed: 07:18 | Remaining: 38:36 | Progress:  16%|█▌        | Calculated: 137/861 chunks
#
#
# Elapsed: 07:22 | Remaining: 38:33 | Progress:  16%|█▌        | Calculated: 138/861 chunks
#
#
# Elapsed: 07:25 | Remaining: 38:23 | Progress:  16%|█▌        | Calculated: 139/861 chunks
#
#
# Elapsed: 07:28 | Remaining: 38:17 | Progress:  16%|█▋        | Calculated: 140/861 chunks
#
#
# Elapsed: 07:31 | Remaining: 38:12 | Progress:  16%|█▋        | Calculated: 141/861 chunks
#
#
# Elapsed: 07:34 | Remaining: 38:15 | Progress:  16%|█▋        | Calculated: 142/861 chunks
#
#
# Elapsed: 07:38 | Remaining: 38:11 | Progress:  17%|█▋        | Calculated: 143/861 chunks
#
#
# Elapsed: 07:41 | Remaining: 38:07 | Progress:  17%|█▋        | Calculated: 144/861 chunks
#
#
# Elapsed: 07:44 | Remaining: 38:02 | Progress:  17%|█▋        | Calculated: 145/861 chunks
#
#
# Elapsed: 07:47 | Remaining: 38:00 | Progress:  17%|█▋        | Calculated: 146/861 chunks
#
#
# Elapsed: 07:50 | Remaining: 37:58 | Progress:  17%|█▋        | Calculated: 147/861 chunks
#
#
# Elapsed: 07:54 | Remaining: 37:48 | Progress:  17%|█▋        | Calculated: 148/861 chunks
#
#
# Elapsed: 07:57 | Remaining: 37:43 | Progress:  17%|█▋        | Calculated: 149/861 chunks
#
#
# Elapsed: 08:00 | Remaining: 37:40 | Progress:  17%|█▋        | Calculated: 150/861 chunks
#
#
# Elapsed: 08:03 | Remaining: 37:41 | Progress:  18%|█▊        | Calculated: 151/861 chunks
#
#
# Elapsed: 08:06 | Remaining: 37:50 | Progress:  18%|█▊        | Calculated: 152/861 chunks
#
#
# Elapsed: 08:10 | Remaining: 37:50 | Progress:  18%|█▊        | Calculated: 153/861 chunks
#
#
# Elapsed: 08:13 | Remaining: 37:54 | Progress:  18%|█▊        | Calculated: 154/861 chunks
#
#
# Elapsed: 08:16 | Remaining: 37:54 | Progress:  18%|█▊        | Calculated: 155/861 chunks
#
#
# Elapsed: 08:19 | Remaining: 37:51 | Progress:  18%|█▊        | Calculated: 156/861 chunks
#
#
# Elapsed: 08:22 | Remaining: 37:50 | Progress:  18%|█▊        | Calculated: 157/861 chunks
#
#
# Elapsed: 08:26 | Remaining: 37:47 | Progress:  18%|█▊        | Calculated: 158/861 chunks
#
#
# Elapsed: 08:29 | Remaining: 37:42 | Progress:  18%|█▊        | Calculated: 159/861 chunks
#
#
# Elapsed: 08:32 | Remaining: 37:42 | Progress:  19%|█▊        | Calculated: 160/861 chunks
#
#
# Elapsed: 08:35 | Remaining: 37:35 | Progress:  19%|█▊        | Calculated: 161/861 chunks
# Elapsed: 08:39 | Remaining: 37:27 | Progress:  19%|█▉        | Calculated: 162/861 chunks
#
#
# Elapsed: 08:42 | Remaining: 37:25 | Progress:  19%|█▉        | Calculated: 163/861 chunks
#
#
# Elapsed: 08:45 | Remaining: 37:21 | Progress:  19%|█▉        | Calculated: 164/861 chunks
#
#
# Elapsed: 08:48 | Remaining: 37:23 | Progress:  19%|█▉        | Calculated: 165/861 chunks
#
#
# Elapsed: 08:51 | Remaining: 37:20 | Progress:  19%|█▉        | Calculated: 166/861 chunks
#
#
# Elapsed: 08:55 | Remaining: 37:12 | Progress:  19%|█▉        | Calculated: 167/861 chunks
#
#
# Elapsed: 08:58 | Remaining: 37:02 | Progress:  20%|█▉        | Calculated: 168/861 chunks
#
#
# Elapsed: 09:01 | Remaining: 36:57 | Progress:  20%|█▉        | Calculated: 169/861 chunks
#
#
# Elapsed: 09:04 | Remaining: 36:58 | Progress:  20%|█▉        | Calculated: 170/861 chunks
#
#
# Elapsed: 09:07 | Remaining: 36:56 | Progress:  20%|█▉        | Calculated: 171/861 chunks
#
#
# Elapsed: 09:11 | Remaining: 37:03 | Progress:  20%|█▉        | Calculated: 172/861 chunks
#
#
# Elapsed: 09:14 | Remaining: 37:02 | Progress:  20%|██        | Calculated: 173/861 chunks
#
#
# Elapsed: 09:17 | Remaining: 37:09 | Progress:  20%|██        | Calculated: 174/861 chunks
#
#
# Elapsed: 09:20 | Remaining: 37:08 | Progress:  20%|██        | Calculated: 175/861 chunks
#
#
# Elapsed: 09:24 | Remaining: 36:53 | Progress:  20%|██        | Calculated: 176/861 chunks
#
#
# Elapsed: 09:27 | Remaining: 36:44 | Progress:  21%|██        | Calculated: 177/861 chunks
#
#
# Elapsed: 09:30 | Remaining: 36:37 | Progress:  21%|██        | Calculated: 178/861 chunks
#
#
# Elapsed: 09:33 | Remaining: 36:37 | Progress:  21%|██        | Calculated: 179/861 chunks
#
#
# Elapsed: 09:37 | Remaining: 36:34 | Progress:  21%|██        | Calculated: 180/861 chunks
#
#
# Elapsed: 09:40 | Remaining: 36:32 | Progress:  21%|██        | Calculated: 181/861 chunks
#
#
# Elapsed: 09:43 | Remaining: 36:40 | Progress:  21%|██        | Calculated: 182/861 chunks
#
#
# Elapsed: 09:46 | Remaining: 36:40 | Progress:  21%|██▏       | Calculated: 183/861 chunks
#
#
# Elapsed: 09:50 | Remaining: 36:31 | Progress:  21%|██▏       | Calculated: 184/861 chunks
#
#
# Elapsed: 09:53 | Remaining: 36:31 | Progress:  21%|██▏       | Calculated: 185/861 chunks
#
#
# Elapsed: 09:56 | Remaining: 36:21 | Progress:  22%|██▏       | Calculated: 186/861 chunks
#
#
# Elapsed: 09:59 | Remaining: 36:19 | Progress:  22%|██▏       | Calculated: 187/861 chunks
#
#
# Elapsed: 10:03 | Remaining: 36:32 | Progress:  22%|██▏       | Calculated: 188/861 chunks
#
#
# Elapsed: 10:06 | Remaining: 36:30 | Progress:  22%|██▏       | Calculated: 189/861 chunks
#
#
# Elapsed: 10:09 | Remaining: 36:17 | Progress:  22%|██▏       | Calculated: 190/861 chunks
#
#
# Elapsed: 10:12 | Remaining: 36:05 | Progress:  22%|██▏       | Calculated: 191/861 chunks
#
#
# Elapsed: 10:15 | Remaining: 36:02 | Progress:  22%|██▏       | Calculated: 192/861 chunks
#
#
# Elapsed: 10:19 | Remaining: 35:59 | Progress:  22%|██▏       | Calculated: 193/861 chunks
#
#
# Elapsed: 10:22 | Remaining: 36:02 | Progress:  23%|██▎       | Calculated: 194/861 chunks
#
#
# Elapsed: 10:26 | Remaining: 37:06 | Progress:  23%|██▎       | Calculated: 195/861 chunks
#
#
# Elapsed: 10:29 | Remaining: 38:13 | Progress:  23%|██▎       | Calculated: 196/861 chunks
#
#
# Elapsed: 10:33 | Remaining: 38:57 | Progress:  23%|██▎       | Calculated: 197/861 chunks
#
#
# Elapsed: 10:36 | Remaining: 39:02 | Progress:  23%|██▎       | Calculated: 198/861 chunks
#
#
# Elapsed: 10:40 | Remaining: 38:04 | Progress:  23%|██▎       | Calculated: 199/861 chunks
#
#
# Elapsed: 10:43 | Remaining: 37:24 | Progress:  23%|██▎       | Calculated: 200/861 chunks
#
#
# Elapsed: 10:46 | Remaining: 36:46 | Progress:  23%|██▎       | Calculated: 201/861 chunks
#
#
# Elapsed: 10:50 | Remaining: 37:08 | Progress:  23%|██▎       | Calculated: 202/861 chunks
#
#
# Elapsed: 10:53 | Remaining: 36:49 | Progress:  24%|██▎       | Calculated: 203/861 chunks
#
#
# Elapsed: 10:56 | Remaining: 36:27 | Progress:  24%|██▎       | Calculated: 204/861 chunks
#
#
# Elapsed: 10:59 | Remaining: 36:06 | Progress:  24%|██▍       | Calculated: 205/861 chunks
#
#
# Elapsed: 11:03 | Remaining: 35:54 | Progress:  24%|██▍       | Calculated: 206/861 chunks
#
#
# Elapsed: 11:06 | Remaining: 35:42 | Progress:  24%|██▍       | Calculated: 207/861 chunks
#
#
# Elapsed: 11:09 | Remaining: 35:33 | Progress:  24%|██▍       | Calculated: 208/861 chunks
#
#
# Elapsed: 11:12 | Remaining: 35:21 | Progress:  24%|██▍       | Calculated: 209/861 chunks
#
#
# Elapsed: 11:16 | Remaining: 35:12 | Progress:  24%|██▍       | Calculated: 210/861 chunks
#
#
# Elapsed: 11:19 | Remaining: 35:04 | Progress:  25%|██▍       | Calculated: 211/861 chunks
#
#
# Elapsed: 11:22 | Remaining: 35:11 | Progress:  25%|██▍       | Calculated: 212/861 chunks
#
#
# Elapsed: 11:25 | Remaining: 35:15 | Progress:  25%|██▍       | Calculated: 213/861 chunks
#
#
# Elapsed: 11:29 | Remaining: 35:00 | Progress:  25%|██▍       | Calculated: 214/861 chunks
#
#
# Elapsed: 11:32 | Remaining: 34:55 | Progress:  25%|██▍       | Calculated: 215/861 chunks
#
#
# Elapsed: 11:35 | Remaining: 34:47 | Progress:  25%|██▌       | Calculated: 216/861 chunks
#
#
# Elapsed: 11:38 | Remaining: 34:41 | Progress:  25%|██▌       | Calculated: 217/861 chunks
#
#
# Elapsed: 11:42 | Remaining: 34:35 | Progress:  25%|██▌       | Calculated: 218/861 chunks
#
#
# Elapsed: 11:45 | Remaining: 34:30 | Progress:  25%|██▌       | Calculated: 219/861 chunks
#
#
# Elapsed: 11:48 | Remaining: 34:25 | Progress:  26%|██▌       | Calculated: 220/861 chunks
#
#
# Elapsed: 11:51 | Remaining: 34:14 | Progress:  26%|██▌       | Calculated: 221/861 chunks
#
#
# Elapsed: 11:54 | Remaining: 34:24 | Progress:  26%|██▌       | Calculated: 222/861 chunks
#
#
# Elapsed: 11:58 | Remaining: 34:13 | Progress:  26%|██▌       | Calculated: 223/861 chunks
#
#
# Elapsed: 12:01 | Remaining: 34:17 | Progress:  26%|██▌       | Calculated: 224/861 chunks
#
#
# Elapsed: 12:04 | Remaining: 34:09 | Progress:  26%|██▌       | Calculated: 225/861 chunks
#
#
# Elapsed: 12:07 | Remaining: 34:04 | Progress:  26%|██▌       | Calculated: 226/861 chunks
#
#
# Elapsed: 12:11 | Remaining: 34:07 | Progress:  26%|██▋       | Calculated: 227/861 chunks
#
#
# Elapsed: 12:14 | Remaining: 33:56 | Progress:  26%|██▋       | Calculated: 228/861 chunks
#
#
# Elapsed: 12:17 | Remaining: 33:51 | Progress:  27%|██▋       | Calculated: 229/861 chunks
#
#
# Elapsed: 12:20 | Remaining: 34:03 | Progress:  27%|██▋       | Calculated: 230/861 chunks
#
#
# Elapsed: 12:24 | Remaining: 33:52 | Progress:  27%|██▋       | Calculated: 231/861 chunks
#
#
# Elapsed: 12:27 | Remaining: 33:49 | Progress:  27%|██▋       | Calculated: 232/861 chunks
#
#
# Elapsed: 12:30 | Remaining: 33:44 | Progress:  27%|██▋       | Calculated: 233/861 chunks
#
#
# Elapsed: 12:33 | Remaining: 33:35 | Progress:  27%|██▋       | Calculated: 234/861 chunks
#
#
# Elapsed: 12:36 | Remaining: 33:28 | Progress:  27%|██▋       | Calculated: 235/861 chunks
#
#
# Elapsed: 12:40 | Remaining: 33:29 | Progress:  27%|██▋       | Calculated: 236/861 chunks

# %%
feature_matrix.head()
